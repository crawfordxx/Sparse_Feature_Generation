# %% [markdown]
# # FIT5196 Assessment 2
# #### Student Name: Jianhan Ma & Yi Hsiao
# #### Student ID: 29332885 & 29360595
# #### Group ID: 023
# Date: 10/09/2019
#
# Version: 2.0
#
# Environment: Python 3.6.0 and Anaconda 4.3.0 (64-bit)
#
# Libraries used:
# * pdfminer (for parsing PDF file, included in Anaconda Python 3.6)
# * pandas 0.19.2 (for data frame, included in Anaconda Python 3.6)
# * re 2.2.1 (for regular expression, included in Anaconda Python 3.6)
# * nltk 3.2.2 (Natural Language Toolkit, included in Anaconda Python 3.6)
# * nltk.collocations (for finding bigrams, included in Anaconda Python 3.6)
# * nltk.tokenize (for tokenization, included in Anaconda Python 3.6)
# * nltk.corpus (for stop words, not included in Anaconda)
# * nltk.stem.porter(for extraction of stem)
#
# ## 1. Introduction
#
# This task provide a data-set containing 200 URLs for papers published in a popular AI conference. extracting data from nonstructured format and converting the extracted data into a proper format suitable for a downstream modelling task is the main goal of this assignemnt.
#
# More details for each task will be given in the following sections.

# %% [markdown]
# ## 2.  Import libraries

# %%
import requests
import re
import os
import pdfminer
import nltk
from nltk.tokenize import RegexpTokenizer 
from nltk.tokenize import MWETokenizer
from nltk.stem.porter import PorterStemmer
from nltk.corpus import gutenberg
from nltk.tokenize.punkt import PunktSentenceTokenizer, PunktTrainer
from nltk.collocations import *
import collections
from collections import *
import pandas as pd
from itertools import chain
import itertools
nltk.download('gutenberg') ##sentence segmentation
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\xxxx\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %% [markdown]
# ## 3. Extract pdf file and get the URLs

# %% [markdown]
# As a first step, the file `Group023.pdf` will be converted to txt file so its can be readable.

# %%
##convert pdf to txt
# !pdf2txt.py -o Group023.txt Group023.pdf
# Out:
# Active code page: 65001

# %% [markdown]
# ## 4. Sparse Feature Generation

# %% [markdown]
# ### 4.1 Download all paper and transfer them to txt file

# %% [markdown]
# After getting the txt file, the `paper ID` and `URL` should be extracted

# %%
##read stop word file
pdfTxtFile = 'Group023.txt'
with open(pdfTxtFile, 'r',encoding='UTF-8') as pdf_txt:
    inputfile = []
    useless = 'filename|url|\s' ##remove irrevelant elements
    # loop over all the lines
    for line in pdf_txt.readlines():
        line = line.strip('\n')
        line = re.sub(useless,'',line)
        inputfile.append(line)
    while '' in inputfile:
        inputfile.remove('') ##remove blank elements
inputfile[0]
# Out:
# 'PP3164.pdfhttps://drive.google.com/uc?export=download&id=1KGospAeT509Iy4az0wnZc1aNNEF44Lfb'

# %% [markdown]
# In the next three steps, we use three similar but different groups to extract url, pdf name ,and txt name(txt name is for following steps)

# %%
##get the url from list
def get_url(url):
    url_pattern = 'PP.*pdf(https.*)'
    url = re.match(url_pattern,url)
    if url != None:
        url = url.group(1)
        return url
get_url(inputfile[0])
# Out:
# 'https://drive.google.com/uc?export=download&id=1KGospAeT509Iy4az0wnZc1aNNEF44Lfb'

# %%
def get_pdf_name(url):
    name_pattern = '(PP.*pdf)https.*'
    name = re.match(name_pattern,url)
    if name != None:
        name = name.group(1)
        return name
get_pdf_name(inputfile[0])
# Out:
# 'PP3164.pdf'

# %%
def get_txt_name(url):
    txt_pattern = '(PP.*).pdfhttps.*'
    name = re.match(txt_pattern,url)
    if name != None:
        name = name.group(1)
        return name +'.txt'
get_txt_name(inputfile[3])
# Out:
# 'PP3249.txt'

# %% [markdown]
# Then we define `download` function by using `requests.get()` method and the input parameter is url we got from previous step. And the for loop is to call the `download` function to download all the paper as pdf version.(it may spend a quite long time)

# %%
def download(filename, url):
    res = requests.get(url)##use request package to read url
    fp  = open(filename, "wb")
    content = res.content ##While .content can access to the raw bytes of the response payload
    fp.write(content)
    fp.close()

# %%
##download all the pdf file
for i in range(len(inputfile)):
    filename = get_pdf_name(inputfile[i])
    url = get_url(inputfile[i])
    download(filename, url)
# Out:
# '\nfor i in range(len(inputfile)):\n    filename = get_pdf_name(inputfile[i])\n    url = get_url(inputfile[i])\n    download(filename, url)\n'

# %% [markdown]
# This part is for converting all paper to txt file. `$` symbol is to call the value which is in the variable.

# %%
##convert all pdf file to txt
for i in range(len(inputfile)):    
    pdfname = get_pdf_name(inputfile[i])
    txtname = get_txt_name(inputfile[i])
    # !pdf2txt.py -o $txtname $pdfname ##use '$' to get the value(shell script)
# Out:
# '\nfor i in range(len(inputfile)):    \n    pdfname = get_pdf_name(inputfile[i])\n    txtname = get_txt_name(inputfile[i])\n    !pdf2txt.py -o $txtname $pdfname\n'

# %% [markdown]
# ### 4.2 Get paper body and tokenization

# %% [markdown]
# For this part, we use `re` package to extract body from a paper and replace all strings which may have bad effect following parts.

# %%
def get_body(url):
    txt_name = get_txt_name(url)
    with open(txt_name,'r',encoding='UTF-8') as content:
        text = content.read()
    
    text = text.replace('\n',' ')
    text = text.replace('?','')
    text = text.replace('¿','')
    text = text.replace('ﬃ','ffi')
    text = text.replace('ﬂ','fl')
    text = text.replace('ﬀ','ff')
    text = text.replace('ﬁ','fi')
    
    body_pattern = '1\sPaper\sBody(.*)2\sReferences'
    body = re.search(body_pattern,text)
    body = body.group(1)
    
    return body
get_body(inputfile[1])[:200]
# Out:
# '  Current reinforcement-learning (RL) techniques hold great promise for creating a general type of artificial intelligence (AI), specifically autonomous (software) agents that learn difficult tasks wi'

# %% [markdown]
# For sentence segmentation, I read [PunktSentenceTokenizer](https://nlpforhackers.io/splitting-text-into-sentences/) as a reference to train a Punkt Sentence Tokenizer. It will be useful in `tokenization` function.

# %%
## sentence segnmentation
text = ""
for file_id in gutenberg.fileids():
    text += gutenberg.raw(file_id)
    
trainer = PunktTrainer()
trainer.INCLUDE_ALL_COLLOCS = True ##wether contain collocations or not
trainer.train(text)

# %% [markdown]
# Read `stopwords.txt` file and store in a set.

# %%
##read stop word file
with open('stopwords_en.txt') as stopwords:
    stopwords = stopwords.read()
stopwords_list = re.split('\n', stopwords)
stopwords_set = set(stopwords_list)

# %% [markdown]
# Then in order to tokenize the words in the body, the paper body should be integrated into a dictionary(key is paper ID, value is body).

# %%
##create dictionary to store all bodies
body_raw = {}
all_pid = []
for i in range(len(inputfile)): 
    all_body = "".join(get_body(inputfile[i])) ## get all body by using 'get_body' function.
    pid = get_pdf_name(inputfile[i])
    pid = pid.replace('.pdf','')
    body_raw[pid] = all_body ## store paper id and its body into a dictionary
    all_pid.append(pid)

# %% [markdown]
# define a `RegexTokenizer` to tokenize all words from paper.

# %%
tokenizer = RegexpTokenizer(r"[A-Za-z]\w+(?:[-'?]\w+)?")

# %% [markdown]
# Utilize the trainning we defined in last few parts to lowercase normal characters. And then tokenize all the tokens from body.

# %%
def tokenizebody(pid):
    ##normalized to lowercase except the capital tokens appearing in the middle of a sentence/line.
    lower_tokenizer = PunktSentenceTokenizer(trainer.get_params())
    raw_body = body_raw[pid]
    sentences = lower_tokenizer.tokenize(raw_body)
    sentences_lower = [s[0].lower()+s[1:] for s in sentences]
    raw_body = "".join(sentences_lower)
    ## tokenize words
    tokenized_body = tokenizer.tokenize(raw_body)
    return (pid, tokenized_body) # return a tupel of patent_id and a list of tokens

# %%
##get all tokens
tokenized_body = dict(tokenizebody(pid) for pid in body_raw.keys())
tokenized_body['PP7260'][0:10]
# Out:
# ['Neuropsychiatric',
#  'disorders',
#  'schizophrenia',
#  'autism',
#  'spectral',
#  'disorder',
#  'etc',
#  'take',
#  'an',
#  'enormous']

# %% [markdown]
# In order to get all words from dictionary, The [itertools tutorila](https://docs.python.org/2/library/itertools.html) is really helpful to sepreate words and integrate them.

# %%
all_words = list(chain.from_iterable(tokenized_body.values()))
len(all_words)
# Out:
# 806122

# %% [markdown]
# The context-independent stop words should be removed from the vocabulary(using `stopwords_set` we defined before).

# %%
##remove all stop_word
stopped_tokens = [w for w in all_words if w not in stopwords_set]## append words from tokens who is not stop word
len(stopped_tokens)
# Out:
# 439378

# %% [markdown]
# For generating 200 meaningful collocations task. The functions we need include
# * BigramAssocMeasures()
# * BigramCollocationFinder.from_words()
# * apply_freq_filter(20)
# * apply_word_filter(lambda w: len(w) < 3)
# * nbest(bigram_measures.pmi, 200)
#
# which are come from http://www.nltk.org/howto/collocations.html.

# %%
## generate 200 meaningful collocation
bigram_measures = nltk.collocations.BigramAssocMeasures()
bigram_finder = nltk.collocations.BigramCollocationFinder.from_words(stopped_tokens)
bigram_finder.apply_freq_filter(20)
bigram_finder.apply_word_filter(lambda w: len(w) < 3)# or w.lower() in ignored_words)
top_200_bigrams = bigram_finder.nbest(bigram_measures.pmi, 200) # Top-200 bigrams
len(top_200_bigrams)
# Out:
# 200

# %% [markdown]
# Now, we introduce 200 collcations. we need to make sure those collocations are not split into two individual words.

# %%
mwetokenizer = MWETokenizer(top_200_bigrams)
colloc_paper =  dict((pid, mwetokenizer.tokenize(body)) for pid,body in tokenized_body.items())
all_words_colloc = list(chain.from_iterable(colloc_paper.values()))
colloc_voc = list(set(all_words_colloc))

# %% [markdown]
# check the difference between th output of MWEtokenizer and RegexpTokenizer by adpating the following code to make sure we get the right collocation

# %%
for pid in tokenized_body.keys():
    diff = set(colloc_paper[pid])-set(tokenized_body[pid])
    if len(diff) != 0:
        print (pid, diff)
# Out:
# PP3164 {'mutual_information', 'junction_tree', 'oracle_calls', 'special_case', 'dynamic_programming', 'fig_shows', 'closely_related', 'upper_bound', 'upper_bounds', 'global_optimum'}
# PP3197 {'reinforcement_learning', 'decision_making', 'Related_Work', 'computational_complexity', 'lower_bound', 'upper_bound'}
# PP3199 {'standard_deviation', 'reinforcement_learning', 'Related_Work', 'figure_shows', 'storm_cell', 'perfor_mance'}
# PP3249 {'worst_case', 'prob_lem', 'special_case', 'lower_bound', 'upper_bound'}
# PP3279 {'free_energy', 'Markov_Random', 'lateral_connections', 'square_root', 'visible_units', 'figure_shows', 'deep_belief', 'weight_decay', 'lower_bound', 'hidden_units'}
# PP3282 {'Monte_Carlo', 'standard_deviation', 'marginal_likelihood', 'free_energy', 'acknowledgments_This', 'dynamical_systems', 'figure_shows', 'hand_side', 'algo_rithm', 'upper_bound', 'computationally_efficient', 'gradient_descent', 'error_bars', 'maximum_likelihood'}
# PP3320 {'randomly_selected', 'random_walk', 'fig_shows', 'Euclidean_distance', 'ridge_regression'}
# PP3362 {'Monte_Carlo', 'standard_deviation', 'gene_expression', 'sufficient_statistics', 'closed_form', 'computational_complexity', 'Figure_Left', 'exponential_family'}
# PP3365 {'state-of_the-art', 'arg_max', 'sufficient_statistics', 'figure_shows', 'distri_bution', 'algo_rithm', 'ground_truth'}
# PP3427 {'cross_validation', 'dimensionality_reduction', 'Related_Work', 'Figure_Left', 'logistic_regression', 'fully_connected', 'positive_definite', 'singular_vectors'}
# PP3441 {'state-of_the-art', 'algo_rithms', 'sufficient_statistics', 'Related_Work', 'figure_shows', 'Hamming_distance', 'algo_rithm', 'computational_complexity'}
# PP3444 {'local_minima', 'http_www', 'hand_side', 'Bayes_classifier', 'special_case', 'lower_bound', 'upper_bound'}
# PP3500 {'standard_deviation', 'mutual_information', 'state-of_the-art', 'http_www', 'arg_min', 'nearest_neighbor', 'information_theoretic', 'global_optimum', 'maximum_likelihood'}
# PP3501 {'standard_deviation', 'neural_networks', 'reinforcement_learning', 'computational_complexity', 'algo_rithm', 'upper_bound', 'computationally_efficient', 'wide_range', 'perfor_mance', 'ridge_regression'}
# PP3545 {'meth_ods', 'reinforcement_learning', 'dynamical_systems', 'figure_shows', 'exponential_family', 'special_case', 'lower_bound', 'Fisher_information', 'error_bars'}
# PP3580 {'real_world', 'multi-armed_bandit', 'algo_rithms', 'figure_shows', 'algo_rithm', 'perfor_mance', 'lower_bound', 'upper_bound'}
# PP3596 {'arg_min', 'sparsity_pattern', 'hand_side', 'Frobenius_norm', 'special_case', 'lower_bound', 'computationally_efficient'}
# PP3600 {'standard_deviation', 'real_world', 'reinforcement_learning', 'figure_shows', 'dynamic_programming'}
# PP3628 {'mutual_information', 'state-of_the-art', 'nearest_neighbor', 'RBF_kernels', 'deep_belief', 'Figure_Left', 'deep_architectures', 'wide_range', 'special_case', 'hidden_units', 'neural_networks'}
# PP3649 {'cross_validation', 'arg_max', 'arg_min', 'computational_complexity', 'supplementary_material', 'gradient_descent', 'Lipschitz_continuous', 'partially_supported', 'lower_bound', 'ground_truth', 'Lipschitz_constant', 'computer_vision'}
# PP3651 {'brain_regions', 'brain_connectivity', 'http_www', 'gene_expression', 'inverse_covariance', 'closely_related', 'maximum_likelihood'}
# PP3661 {'http_www', 'strongly_convex', 'arg_min', 'projected_gradient', 'Related_Work', 'Frobenius_norm', 'Lipschitz_continuous', 'Lipschitz_constant'}
# PP3675 {'norm_MKL', 'real_world', 'empirical_risk', 'acknowledgments_This', 'state-of_the-art', 'http_www', 'RBF_kernels', 'figure_shows', 'upper_bound', 'Hilbert_space', 'Figure_Left', 'supplementary_material', 'reproducing_kernel', 'risk_minimization', 'special_case', 'hinge_loss', 'closely_related', 'error_bars'}
# PP3741 {'coordinate_system', 'standard_deviation', 'worst_case', 'tangent_space', 'empirical_risk', 'dimensionality_reduction', 'state-of_the-art', 'http_www', 'arg_min', 'supplementary_material', 'Frobenius_norm', 'special_case', 'ground_truth', 'fig_shows', 'perfor_mance', 'ridge_regression'}
# PP3744 {'reinforcement_learning', 'sufficient_statistics', 'fig_shows', 'membrane_potential'}
# PP3773 {'wide_range', 'figure_shows', 'hand_side', 'content-unrelated_annotations'}
# PP3784 {'Brownian_motion', 'arg_min', 'sparsity_pattern', 'wide_range', 'special_case'}
# PP3790 {'mutual_information', 'acknowledgments_This', 'deep_belief', 'Figure_Left', 'deep_architectures', 'wide_range', 'weight_decay', 'receptive_field', 'hidden_units', 'computer_vision'}
# PP3830 {'local_minima', 'standard_deviation', 'RBF_kernel', 'Markov_chain', 'free_energy', 'state-of_the-art', 'http_www', 'distri_bution', 'computational_complexity', 'special_case', 'lower_bound', 'maximum_likelihood'}
# PP3841 {'dynamical_systems', 'closed_form', 'distri_bution', 'upper_bound', 'supplementary_material', 'wide_range', 'lower_bound', 'fig_shows', 'membrane_potential'}
# PP3855 {'standard_deviation', 'meth_ods', 'real_world', 'logistic_regression', 'upper_bound'}
# PP3883 {'total_variation', 'prob_lem', 'algo_rithms', 'Related_Work', 'figure_shows', 'upper_bound'}
# PP3887 {'arg_max', 'algo_rithms', 'nearest_neighbor', 'perfor_mance', 'gradient_descent', 'affinity_graph', 'special_case', 'hinge_loss', 'ground_truth', 'Rand_index', 'upper_bound'}
# PP3892 {'Monte_Carlo', 'standard_deviation', 'worst_case', 'real_world', 'state-of_the-art', 'figure_shows', 'upper_bound'}
# PP3908 {'cross_validation', 'Rademacher_complexity', 'empirical_risk', 'randomly_selected', 'nearest_neighbor', 'Related_Work', 'closely_related'}
# PP3909 {'state-of_the-art', 'prob_lem', 'adjacency_matrix', 'algo_rithm', 'special_case', 'fig_shows', 'upper_bound', 'computer_vision'}
# PP3929 {'arg_min', 'figure_shows', 'hand_side', 'deep_belief', 'theoretical_guarantees', 'Lipschitz_constant', 'sparse_coding'}
# PP3932 {'standard_deviation', 'cross_validation', 'meth_ods', 'prob_lem', 'computationally_efficient', 'matrix_completion', 'low_rank', 'singular_vectors', 'global_optimum'}
# PP3934 {'Monte_Carlo', 'real_world', 'arg_max', 'closed_form', 'distri_bution', 'Related_Work', 'shadow_Dirichlet', 'gradient_descent', 'convex_hull', 'fig_shows', 'maximum_likelihood'}
# PP3979 {'dimensionality_reduction', 'state-of_the-art', 'neural_networks', 'computational_complexity', 'wide_range', 'information_theoretic', 'Neural_Information', 'gradient_ascent', 'error_bars', 'Euclidean_distance', 'Processing_Systems'}
# PP3981 {'real_world', 'adjacency_matrix', 'random_walk', 'wide_range', 'inverse_covariance', 'closely_related'}
# PP3993 {'meth_ods', 'causal_graph', 'dimensionality_reduction', 'arg_max', 'http_www', 'arg_min', 'closed_form', 'figure_shows', 'theoretical_guarantees', 'risk_minimization', 'ground_truth', 'maximum_likelihood'}
# PP4028 {'dimensionality_reduction', 'algo_rithms', 'special_case', 'Lipschitz_constant', 'state-of_the-art', 'prob_lem', 'MAP_inference', 'arg_min', 'closed_form', 'ground_truth', 'Markov_Random', 'Lipschitz_continuous', 'gradient_descent', 'partially_supported', 'worst_case', 'arg_max', 'figure_shows', 'upper_bound', 'submodular_minimization'}
# PP4039 {'worst_case', 'Supplementary_Material', 'tangent_space', 'dimensionality_reduction', 'nearest_neighbor', 'RPT_REE', 'upper_bound', 'upper_bounds'}
# PP4078 {'meth_ods', 'symbolic_mismatch', 'arg_max', 'nearest_neighbor', 'Related_Work', 'closely_related', 'computationally_efficient'}
# PP4081 {'empirical_risk', 'acknowledgments_This', 'square_root', 'bipartite_ranking', 'figure_shows', 'hand_side', 'Figure_Left', 'reproducing_kernel', 'partially_supported', 'special_case', 'lower_bound', 'upper_bound', 'upper_bounds'}
# PP4084 {'cross_validation', 'tangent_space', 'acknowledgments_This', 'projected_gradient', 'computational_complexity', 'low_rank', 'gradient_descent', 'special_case', 'hinge_loss', 'ground_truth', 'closely_related', 'error_bars'}
# PP4153 {'standard_deviation', 'cross_validation', 'real_world', 'Markov_Random', 'gene_expression', 'lower_bound', 'ground_truth', 'Rand_index'}
# PP4179 {'standard_deviation', 'trsf_Cstr', 'state-of_the-art', 'Our_appr', 'square_root', 'ground_truth', 'closed_form', 'computer_vision', 'appr_trsf', 'Frobenius_norm', 'trsf_Our', 'fig_shows', 'constraint_violation', 'error_bars', 'singular_vectors'}
# PP4216 {'RBF_kernel', 'empirical_risk', 'arg_min', 'RBF_kernels', 'Hilbert_space', 'reproducing_kernel', 'special_case', 'upper_bound'}
# PP4234 {'Monte_Carlo', 'worst_case', 'state-of_the-art', 'arg_min', 'figure_shows', 'upper_bound'}
# PP4235 {'local_minima', 'closed_form', 'matrix_completion', 'Frobenius_norm', 'low_rank', 'special_case'}
# PP4260 {'state-of_the-art', 'randomly_selected', 'gene_expression', 'figure_shows', 'Figure_Left', 'Frobenius_norm', 'partially_supported'}
# PP4312 {'Rademacher_complexity', 'empirical_risk', 'arg_min', 'nearest_neighbor', 'Bayes_classifier', 'Hilbert_space', 'reproducing_kernel', 'hinge_loss', 'ridge_regression'}
# PP4325 {'mutual_information', 'Supplementary_Material', 'empirical_risk', 'arg_min', 'closed_form', 'distri_bution', 'Bayes_classifier', 'algo_rithm', 'special_case', 'lower_bound', 'closely_related', 'upper_bound', 'upper_bounds'}
# PP4368 {'standard_deviation', 'Markov_Random', 'http_www', 'visible_units', 'distri_bution', 'Figure_Left', 'supplementary_material', 'weight_decay', 'gradient_descent', 'special_case', 'hidden_units', 'neural_networks', 'recurrent_neural', 'maximum_likelihood'}
# PP4432 {'meth_ods', 'Gradient_Descent', 'algo_rithm', 'Hilbert_space', 'Figure_Left', 'supplementary_material', 'gradient_descent', 'mini-batch_size', 'hinge_loss', 'upper_bound', 'upper_bounds'}
# PP4454 {'additive_noise', 'standard_deviation', 'projected_gradient', 'arg_min', 'distri_bution', 'figure_shows', 'theoretical_guarantees', 'gradient_descent', 'special_case', 'inverse_covariance', 'closely_related', 'partially_supported', 'global_optimum'}
# PP4456 {'mutual_information', 'marginal_likelihood', 'Markov_chain', 'closed_form', 'contraction_operator', 'wide_range', 'special_case', 'Lipschitz_constant', 'computationally_efficient'}
# PP4471 {'figure_shows', 'closed_form', 'hand_side', 'special_case', 'partially_supported'}
# PP4497 {'meth_ods', 'complex_cell', 'prob_lem', 'randomly_selected', 'nearest_neighbor', 'Related_Work', 'algo_rithm', 'closely_related', 'neural_networks'}
# PP4499 {'prob_lem', 'gene_expression', 'randomly_selected', 'sparsity_pattern', 'figure_shows', 'adjacency_matrix', 'algo_rithm', 'wide_range', 'Frobenius_norm', 'gradient_ascent', 'special_case', 'closely_related', 'positive_definite', 'computer_vision', 'maximum_likelihood'}
# PP4521 {'Monte_Carlo', 'standard_deviation', 'closed_form', 'distri_bution', 'special_case', 'fig_shows', 'error_bars'}
# PP4576 {'worst_case', 'reinforcement_learning', 'decision_making', 'Newtons_method', 'approximate_Newton', 'computational_complexity', 'algo_rithm', 'supplementary_material', 'gradient_ascent', 'dynamic_programming', 'Fisher_information', 'closely_related', 'global_optimum'}
# PP4605 {'algo_rithms', 'Hilbert_space', 'risk_minimization', 'meth_ods', 'state-of_the-art', 'prob_lem', 'MAP_inference', 'junction_tree', 'logistic_regression', 'dynamic_programming', 'fully_connected', 'upper_bounds', 'global_optimum', 'cross_validation', 'Related_Work', 'theoretical_guarantees', 'closely_related', 'empirical_risk', 'deep_belief', 'hinge_loss'}
# PP4616 {'upper_bounds', 'standard_deviation', 'Supplementary_Material', 'multi-armed_bandit', 'figure_shows', 'upper_bound', 'error_bars', 'partially_supported'}
# PP4642 {'local_minima', 'cross_validation', 'real_world', 'reinforcement_learning', 'supplementary_material', 'lower_bound', 'perfor_mance', 'maximum_likelihood'}
# PP4708 {'coordinate_system', 'tangent_space', 'state-of_the-art', 'randomly_selected', 'Markov_Random', 'exponential_family', 'Fisher_information', 'closely_related'}
# PP4720 {'special_case'}
# PP4721 {'Monte_Carlo', 'Bellman_error', 'Markov_chain', 'Markov_Random', 'reinforcement_learning', 'decision_making', 'figure_shows', 'Hamming_distance', 'adjacency_matrix', 'dynamic_programming', 'gradient_descent', 'lower_bound', 'Euclidean_distance', 'computer_vision'}
# PP4759 {'lattice_filter', 'gradient_descent', 'receptive_field', 'special_case', 'receptive_fields'}
# PP4797 {'prob_lem', 'Gradient_Descent', 'strongly_convex', 'computational_complexity', 'matrix_completion', 'gradient_descent', 'Lipschitz_continuous', 'convex_hull', 'closely_related', 'computationally_efficient'}
# PP4842 {'bounding_box', 'corner_locations', 'square_root', 'object_detection', 'figure_shows', 'row_column', 'bounding_boxes', 'dynamic_programming', 'ground_truth', 'computer_vision'}
# PP4896 {'norm_MKL', 'standard_deviation', 'Rademacher_complexity', 'worst_case', 'convex_hull', 'empirical_risk', 'algo_rithms', 'Hilbert_space', 'supplementary_material', 'theoretical_guarantees', 'special_case', 'reproducing_kernel', 'local_Rademacher', 'hinge_loss', 'upper_bound'}
# PP4917 {'meth_ods', 'arg_max', 'reinforcement_learning', 'algo_rithms', 'decision_making', 'figure_shows', 'dynamic_programming'}
# PP4957 {'empirical_risk', 'state-of_the-art', 'gene_expression', 'hand_side', 'algo_rithm', 'special_case', 'local_Rademacher', 'upper_bounds'}
# PP4983 {'standard_deviation', 'worst_case', 'meth_ods', 'Hamming_distance', 'computational_complexity', 'computationally_efficient', 'supplementary_material', 'information_theoretic', 'special_case', 'lower_bound', 'upper_bound', 'upper_bounds', 'maximum_likelihood'}
# PP4998 {'Monte_Carlo', 'meth_ods', 'real_world', 'acknowledgments_This', 'distri_bution', 'Figure_Left', 'supplementary_material'}
# PP5001 {'cross_validation', 'real_world', 'state-of_the-art', 'algo_rithms', 'nearest_neighbor', 'figure_shows', 'adjacency_matrix', 'supplementary_material', 'special_case', 'closely_related'}
# PP5023 {'Markov_chain', 'Markov_chains', 'sparse_coding', 'distri_bution', 'random_walk', 'transition_operator', 'lower_bound', 'fig_shows', 'hidden_units', 'singular_vectors', 'maximum_likelihood'}
# PP5059 {'brain_regions', 'acknowledgments_This', 'state-of_the-art', 'figure_shows', 'weight_decay', 'gradient_descent', 'neural_networks'}
# PP5063 {'additive_noise', 'marginal_likelihood', 'equivalence_class', 'figure_shows', 'ground_truth', 'fully_connected'}
# PP5118 {'Monte_Carlo', 'Markov_chain', 'entry-wise_PDFs', 'prob_lem', 'algo_rithms', 'figure_shows', 'dynamic_programming', 'partially_supported', 'Frobenius_norm', 'lower_bound', 'ground_truth', 'upper_bounds', 'maximum_likelihood'}
# PP5129 {'local_minima', 'empirical_risk', 'acknowledgments_This', 'state-of_the-art', 'http_www', 'Gradient_Descent', 'arg_min', 'algo_rithms', 'strongly_convex', 'computational_complexity', 'Lipschitz_continuous', 'logistic_regression', 'gradient_descent', 'closely_related'}
# PP5182 {'Bellman_error', 'Markov_chain', 'dimensionality_reduction', 'neural_networks', 'reinforcement_learning', 'figure_shows', 'computational_complexity', 'Figure_Left', 'theoretical_guarantees', 'gradient_descent', 'Frobenius_norm', 'dynamic_programming', 'upper_bound', 'ridge_regression'}
# PP5202 {'bounding_box', 'state-of_the-art', 'nearest_neighbor', 'object_detection', 'figure_shows', 'Figure_Left', 'gradient_ascent', 'Euclidean_distance', 'partially_supported'}
# PP5207 {'bounding_box', 'state-of_the-art', 'prob_lem', 'Related_Work', 'bounding_boxes', 'deep_architectures', 'wide_range', 'receptive_field', 'ground_truth', 'fully_connected', 'neural_networks', 'object_detection'}
# PP5209 {'RBF_kernel', 'state-of_the-art', 'Gradient_Descent', 'nearest_neighbor', 'closed_form', 'ground_truth', 'computer_vision'}
# PP5215 {'acknowledgments_This', 'state-of_the-art', 'weak_learner', 'closely_related', 'computer_vision', 'computationally_efficient'}
# PP5222 {'state-of_the-art', 'bipartite_ranking', 'algo_rithms', 'figure_shows', 'computational_complexity', 'special_case'}
# PP5229 {'Monte_Carlo', 'standard_deviation', 'arg_max', 'arg_min', 'global_MLE', 'algo_rithms', 'sufficient_statistics', 'exponential_family', 'lower_bound', 'Fisher_information', 'fig_shows', 'closely_related', 'neural_networks', 'maximum_likelihood'}
# PP5242 {'worst_case', 'Gradient_Descent', 'algo_rithms', 'algo_rithm', 'gradient_descent', 'logistic_regression', 'lower_bound', 'upper_bound', 'upper_bounds'}
# PP5263 {'standard_deviation', 'cross_validation', 'complex_cell', 'Newtons_method', 'closed_form', 'receptive_field', 'lower_bound', 'ground_truth', 'receptive_fields'}
# PP5314 {'adjacency_matrix', 'special_case', 'lower_bound', 'singular_vectors', 'upper_bound', 'computer_vision', 'global_optimum'}
# PP5340 {'prob_lem', 'reinforcement_learning', 'random_walk', 'receptive_field', 'dynamic_programming', 'fig_shows', 'closely_related', 'Euclidean_distance', 'receptive_fields', 'computationally_efficient'}
# PP5348 {'cross_validation', 'acknowledgments_This', 'state-of_the-art', 'randomly_selected', 'Related_Work', 'hand_side', 'Hilbert_space', 'supplementary_material', 'reproducing_kernel', 'gradient_descent', 'partially_supported', 'neural_networks', 'positive_definite', 'computer_vision'}
# PP5366 {'worst_case', 'cross_validation', 'RBF_kernel', 'real_world', 'state-of_the-art', 'influence_maximization', 'figure_shows', 'closed_form', 'hand_side', 'ground_truth', 'maximum_likelihood', 'upper_bound', 'ridge_regression'}
# PP5381 {'standard_deviation', 'arg_min', 'hand_side', 'Figure_Left', 'upper_bound'}
# PP5392 {'total_variation', 'worst_case', 'equivalence_class', 'computational_complexity', 'wide_range', 'logistic_regression', 'special_case', 'differentially_private', 'information_theoretic', 'closely_related', 'upper_bound', 'upper_bounds', 'differential_privacy'}
# PP5461 {'multi-armed_bandit', 'reinforcement_learning', 'computational_complexity', 'algo_rithm', 'supplementary_material', 'lower_bound'}
# PP5472 {'worst_case', 'MAP_instantiation', 'state-of_the-art', 'arg_max', 'Markov_Random', 'MAP_inference', 'figure_shows', 'Hamming_distance', 'Bayes_classifier', 'supplementary_material', 'junction_tree', 'partially_supported'}
# PP5493 {'acknowledgments_This', 'state-of_the-art', 'influence_maximization', 'arg_max', 'arg_min', 'algo_rithms', 'dynamic_programming', 'Figure_Left', 'supplementary_material', 'partially_supported', 'special_case', 'lower_bound', 'fig_shows', 'upper_bound', 'upper_bounds'}
# PP5498 {'equivalence_class', 'arg_max', 'MAP_inference', 'algo_rithms', 'figure_shows', 'MLN_theory', 'supplementary_material', 'partially_supported', 'special_case', 'single_occurrence', 'computer_vision'}
# PP5516 {'local_minima', 'additive_noise', 'meth_ods', 'sufficient_statistics', 'figure_shows', 'special_case', 'singular_vectors', 'computationally_efficient'}
# PP5535 {'worst_case', 'causal_graph', 'equivalence_class', 'adjacency_matrix', 'lower_bound', 'upper_bound', 'upper_bounds'}
# PP5539 {'fully_connected', 'state-of_the-art', 'Related_Work', 'ground_truth', 'fig_shows', 'hidden_units'}
# PP5542 {'bounding_box', 'http_www', 'reinforcement_learning', 'decision_making', 'object_detection', 'figure_shows', 'computational_complexity', 'wide_range', 'gradient_descent', 'ground_truth', 'fully_connected', 'hidden_units', 'neural_networks', 'recurrent_neural', 'computer_vision'}
# PP5558 {'free_energy', 'figure_shows'}
# PP5565 {'standard_deviation', 'mutual_information', 'Markov_chain', 'state-of_the-art', 'arg_min', 'nearest_neighbor', 'Related_Work', 'figure_shows', 'random_walk', 'information_theoretic', 'perfor_mance', 'partially_supported'}
# PP5593 {'marginal_likelihood', 'state-of_the-art', 'sufficient_statistics', 'figure_shows', 'Related_Work', 'computational_complexity', 'inducing_points', 'supplementary_material', 'gradient_descent', 'special_case', 'lower_bound', 'ridge_regression'}
# PP5598 {'acknowledgments_This', 'algo_rithms', 'sufficient_statistics', 'gradient_descent', 'logistic_regression', 'lower_bound'}
# PP5607 {'mutual_information', 'real_world', 'state-of_the-art', 'prob_lem', 'http_www', 'arg_min', 'Related_Work', 'pairwise_labels', 'computer_vision', 'supplementary_material', 'matrix_completion', 'low_rank', 'closely_related', 'singular_vectors'}
# PP5617 {'dimensionality_reduction', 'Gradient_Descent', 'theoretical_guarantees', 'supplementary_material', 'gradient_descent', 'special_case', 'singular_vectors', 'ridge_regression'}
# PP5618 {'Monte_Carlo', 'Supplementary_Material', 'arg_min', 'closed_form', 'supplementary_material', 'special_case', 'lower_bound', 'upper_bound', 'computer_vision', 'maximum_likelihood'}
# PP5650 {'dynamical_systems', 'decision_making', 'figure_shows', 'supplementary_material', 'random_walk', 'https_github', 'error_bars'}
# PP5661 {'Monte_Carlo', 'marginal_likelihood', 'lower_bound', 'state-of_the-art', 'acknowledgments_This', 'arg_max', 'gene_expression', 'sufficient_statistics', 'closed_form', 'Hamming_distance', 'algo_rithm', 'Figure_Left', 'exponential_family', 'dynamic_programming', 'ground_truth', 'fig_shows'}
# PP5672 {'dimensionality_reduction', 'state-of_the-art', 'trust_region', 'figure_shows', 'closed_form', 'Related_Work', 'distri_bution', 'information_theoretic', 'Fisher_information', 'positive_definite'}
# PP5687 {'standard_deviation', 'cross_validation', 'RBF_kernel', 'empirical_risk', 'dimensionality_reduction', 'arg_max', 'arg_min', 'nearest_neighbor', 'optimal_transport', 'closed_form', 'computational_complexity', 'virtual_points', 'supplementary_material', 'Frobenius_norm', 'hinge_loss', 'closely_related', 'Euclidean_distance'}
# PP5689 {'causal_graph', 'equivalence_class', 'figure_shows', 'distri_bution', 'adjacency_matrix', 'special_case', 'dynamic_programming', 'ground_truth', 'upper_bound'}
# PP5763 {'total_variation', 'worst_case', 'strongly_convex', 'algo_rithms', 'lower_bound', 'RVU_property', 'upper_bound'}
# PP5794 {'coordinate_system', 'real_world', 'dimensionality_reduction', 'prob_lem', 'randomly_selected', 'arg_max', 'Figure_Left', 'gradient_descent'}
# PP5858 {'bounding_box', 'strong_annotations', 'Gradient_Descent', 'Related_Work', 'bounding_boxes', 'fully_connected', 'perfor_mance'}
# PP5895 {'Monte_Carlo', 'cross_validation', 'worst_case', 'marginal_likelihood', 'Markov_chain', 'arg_max', 'http_www', 'sufficient_statistics', 'closed_form', 'figure_shows', 'exponential_family', 'supplementary_material', 'Lipschitz_continuous', 'logistic_regression', 'gradient_descent', 'lower_bound'}
# PP5934 {'Monte_Carlo', 'total_variation', 'Markov_chain', 'Brownian_motion', 'square_root', 'hand_side', 'supplementary_material', 'gradient_descent', 'special_case', 'closely_related'}
# PP5959 {'standard_deviation', 'RBF_kernel', 'nearest_neighbor', 'Related_Work', 'figure_shows', 'Hilbert_space', 'reproducing_kernel', 'wide_range', 'closely_related'}
# PP5963 {'standard_deviation', 'marginal_likelihood', 'hidden_units', 'gene_expression', 'visible_units', 'projected_gradient', 'hand_side', 'computational_complexity', 'supplementary_material', 'Frobenius_norm', 'fig_shows', 'maximum_likelihood', 'sparse_coding', 'ridge_regression'}
# PP5965 {'Monte_Carlo', 'standard_deviation', 'meth_ods', 'marginal_likelihood', 'neural_networks', 'reinforcement_learning', 'gradient_descent', 'lower_bound', 'ground_truth', 'hidden_units', 'error_bars'}
# PP5990 {'additive_noise', 'coordinate_system', 'square_root', 'Related_Work', 'supplementary_material', 'positive_definite'}
# PP6021 {'lower_bound', 'additive_noise', 'upper_bound', 'Frobenius_norm'}
# PP6025 {'acknowledgments_This', 'multi-armed_bandit', 'reinforcement_learning', 'strongly_convex', 'arg_min', 'Related_Work', 'supplementary_material', 'Lipschitz_continuous', 'special_case', 'Lipschitz_constant', 'maximum_likelihood'}
# PP6148 {'inverse_covariance', 'randomly_selected', 'arg_max', 'https_github', 'Frobenius_norm', 'lower_bound', 'Neural_Information', 'NIPS_Barcelona', 'gradient_ascent', 'positive_definite', 'Processing_Systems'}
# PP6170 {'worst_case', 'algo_rithm', 'differentially_private', 'special_case', 'Neural_Information', 'NIPS_Barcelona', 'upper_bound', 'Processing_Systems', 'differential_privacy'}
# PP6174 {'Monte_Carlo', 'worst_case', 'marginal_likelihood', 'http_www', 'closed_form', 'algo_rithm', 'Hilbert_space', 'supplementary_material', 'theoretical_guarantees', 'reproducing_kernel', 'special_case', 'Neural_Information', 'NIPS_Barcelona', 'Processing_Systems'}
# PP6175 {'worst_case', 'real_world', 'influence_maximization', 'figure_shows', 'oﬄine_greedy', 'algo_rithm', 'Figure_Left', 'supplementary_material', 'oracle_calls', 'special_case', 'lower_bound', 'Neural_Information', 'NIPS_Barcelona', 'Processing_Systems', 'ridge_regression'}
# PP6181 {'standard_deviation', 'empirical_risk', 'state-of_the-art', 'influence_maximization', 'http_www', 'ground_truth', 'algo_rithms', 'figure_shows', 'theoretical_guarantees', 'logistic_regression', 'Neural_Information', 'NIPS_Barcelona', 'error_bars', 'Processing_Systems', 'maximum_likelihood'}
# PP6224 {'Markov_chain', 'prob_lem', 'Processing_Systems', 'perfor_mance', 'special_case', 'dynamic_programming', 'Neural_Information', 'NIPS_Barcelona', 'choice_probabilities', 'upper_bound', 'upper_bounds', 'computationally_efficient'}
# PP6241 {'Monte_Carlo', 'fully_connected', 'standard_deviation', 'state-of_the-art', 'distri_bution', 'weight_decay', 'Neural_Information', 'NIPS_Barcelona', 'neural_networks', 'recurrent_neural', 'Processing_Systems'}
# PP6251 {'fully_connected', 'standard_deviation', 'ground_truth', 'http_www', 'figure_shows', 'gradient_descent', 'receptive_field', 'Neural_Information', 'NIPS_Barcelona', 'neural_networks', 'Processing_Systems'}
# PP6262 {'meth_ods', 'empirical_risk', 'state-of_the-art', 'Gradient_Descent', 'strongly_convex', 'Newtons_method', 'hand_side', 'computational_complexity', 'perfor_mance', 'supplementary_material', 'Ada_Newton', 'Lipschitz_continuous', 'gradient_descent', 'risk_minimization', 'upper_bound', 'upper_bounds'}
# PP6271 {'local_minima', 'worst_case', 'prob_lem', 'trust_region', 'hand_side', 'theoretical_guarantees', 'matrix_completion', 'gradient_descent', 'low_rank', 'Neural_Information', 'NIPS_Barcelona', 'Processing_Systems', 'global_optimum'}
# PP6275 {'Monte_Carlo', 'local_minima', 'hidden_units', 'state-of_the-art', 'figure_shows', 'https_github', 'gradient_descent', 'mini-batch_size', 'lower_bound', 'Neural_Information', 'NIPS_Barcelona', 'gradient_ascent', 'Processing_Systems'}
# PP6296 {'standard_deviation', 'ground_truth', 'arg_max', 'closed_form', 'figure_shows', 'Neural_Information', 'NIPS_Barcelona', 'gradient_ascent', 'positive_definite', 'Processing_Systems'}
# PP6316 {'worst_case', 'lower_bound', 'prob_lem', 'positive_negative', 'Processing_Systems', 'https_github', 'supplementary_material', 'special_case', 'hinge_loss', 'Neural_Information', 'NIPS_Barcelona', 'upper_bound', 'upper_bounds'}
# PP6338 {'http_www', 'algo_rithms', 'Hilbert_space', 'Neural_Information', 'NIPS_Barcelona', 'positive_definite', 'Gradient_Descent', 'arg_min', 'closed_form', 'logistic_regression', 'mini-batch_size', 'Processing_Systems', 'Monte_Carlo', 'gradient_descent', 'https_github', 'gradient_ascent', 'RBF_kernel', 'real_world', 'figure_shows', 'reproducing_kernel', 'hidden_units', 'neural_networks'}
# PP6352 {'cross_validation', 'dimensionality_reduction', 'state-of_the-art', 'strongly_convex', 'ridge_regression', 'sufficient_statistics', 'algo_rithm', 'special_case', 'Neural_Information', 'NIPS_Barcelona', 'closely_related', 'Lipschitz_constant', 'Processing_Systems', 'global_optimum'}
# PP6353 {'Monte_Carlo', 'marginal_likelihood', 'Related_Work', 'figure_shows', 'https_github', 'lower_bound', 'Neural_Information', 'NIPS_Barcelona', 'gradient_ascent', 'neural_networks', 'Processing_Systems'}
# PP6361 {'prob_lem', 'square_root', 'projected_gradient', 'figure_shows', 'Figure_Left', 'matroid_rank', 'weight_decay', 'information_theoretic', 'Neural_Information', 'NIPS_Barcelona', 'hidden_units', 'neural_networks', 'submodular_minimization', 'Processing_Systems'}
# PP6369 {'cross_validation', 'acknowledgments_This', 'nearest_neighbor', 'figure_shows', 'computational_complexity', 'https_github', 'supplementary_material', 'information_theoretic', 'special_case', 'Neural_Information', 'NIPS_Barcelona', 'closely_related', 'error_bars', 'Processing_Systems', 'computationally_efficient'}
# PP6415 {'worst_case', 'multi-armed_bandit', 'arg_min', 'supplementary_material', 'special_case', 'lower_bound', 'Neural_Information', 'NIPS_Barcelona', 'closely_related', 'upper_bound', 'Processing_Systems'}
# PP6417 {'worst_case', 'prob_lem', 'positive_negative', 'ground_truth', 'algo_rithms', 'distri_bution', 'warm_start', 'Processing_Systems', 'theoretical_guarantees', 'gradient_descent', 'special_case', 'Neural_Information', 'NIPS_Barcelona', 'closely_related', 'upper_bound', 'upper_bounds'}
# PP6427 {'fully_connected', 'worst_case', 'RBF_kernel', 'hidden_units', 'empirical_risk', 'figure_shows', 'Hilbert_space', 'supplementary_material', 'reproducing_kernel', 'hinge_loss', 'Neural_Information', 'NIPS_Barcelona', 'closely_related', 'neural_networks', 'Processing_Systems'}
# PP6441 {'standard_deviation', 'meth_ods', 'neural_networks', 'Figure_Left', 'weight_decay', 'mini-batch_size', 'Neural_Information', 'NIPS_Barcelona', 'hidden_units', 'perfor_mance', 'Processing_Systems'}
# PP6457 {'Monte_Carlo', 'coordinate_system', 'neural_networks', 'prob_lem', 'square_root', 'reinforcement_learning', 'figure_shows', 'supplementary_material', 'theoretical_guarantees', 'special_case', 'Neural_Information', 'NIPS_Barcelona', 'perfor_mance', 'positive_definite', 'Processing_Systems', 'global_optimum'}
# PP6478 {'Markov_chain', 'SSUMPTION_FREE', 'algo_rithms', 'distri_bution', 'Neural_Information', 'NIPS_Barcelona', 'total_variation', 'meth_ods', 'Markov_chains', 'computational_complexity', 'perfor_mance', 'Euclidean_distance', 'Processing_Systems', 'Monte_Carlo', 'algo_rithm', 'theoretical_guarantees', 'partially_supported', 'real_world', 'acknowledgments_This', 'figure_shows', 'FREE_MC2'}
# PP6481 {'local_minima', 'standard_deviation', 'randomly_selected', 'hand_side', 'gradient_descent', 'mini-batch_size', 'lower_bound', 'https_github', 'upper_bounds'}
# PP6487 {'fully_connected', 'acknowledgments_This', 'state-of_the-art', 'ground_truth', 'neural_networks', 'spatial_transformer', 'nearest_neighbor', 'Processing_Systems', 'supplementary_material', 'Neural_Information', 'NIPS_Barcelona', 'perfor_mance', 'Euclidean_distance', 'computer_vision'}
# PP6514 {'Monte_Carlo', 'meth_ods', 'Markov_chain', 'Brownian_motion', 'Gradient_Descent', 'algo_rithms', 'figure_shows', 'distri_bution', 'Frobenius_norm', 'mini-batch_size', 'Neural_Information', 'NIPS_Barcelona', 'upper_bound', 'Processing_Systems'}
# PP6517 {'local_minima', 'tangent_space', 'hand_side', 'adjacency_matrix', 'computational_complexity', 'Processing_Systems', 'matrix_completion', 'Lipschitz_continuous', 'Frobenius_norm', 'NIPS_Barcelona', 'partially_supported', 'global_optimum'}
# PP6520 {'ground_truth', 'reinforcement_learning', 'Related_Work', 'supplementary_material', 'gradient_descent', 'Neural_Information', 'NIPS_Barcelona', 'neural_networks', 'recurrent_neural', 'Processing_Systems'}
# PP6526 {'worst_case', 'acknowledgments_This', 'arg_max', 'Related_Work', 'Processing_Systems', 'supplementary_material', 'logistic_regression', 'Neural_Information', 'NIPS_Barcelona', 'partially_supported'}
# PP6534 {'local_minima', 'standard_deviation', 'Supplementary_Material', 'Markov_chains', 'hidden_units', 'Markov_chain', 'Gradient_Descent', 'algo_rithms', 'Related_Work', 'computational_complexity', 'gradient_descent', 'lower_bound', 'Neural_Information', 'NIPS_Barcelona', 'gradient_ascent', 'neural_networks', 'Processing_Systems'}
# PP6537 {'Monte_Carlo', 'brain_regions', 'state-of_the-art', 'randomly_selected', 'decision_making', 'closed_form', 'Related_Work', 'computationally_efficient', 'Neural_Information', 'NIPS_Barcelona', 'Processing_Systems', 'maximum_likelihood'}
# PP6564 {'Monte_Carlo', 'figure_shows', 'Hamming_distance', 'wide_range', 'Neural_Information', 'NIPS_Barcelona', 'Processing_Systems'}
# PP6570 {'total_variation', 'dimensionality_reduction', 'algo_rithm', 'Processing_Systems', 'Laplacian_smoothing', 'lower_bound', 'Neural_Information', 'NIPS_Barcelona', 'upper_bound', 'upper_bounds'}
# PP6576 {'neural_networks', 'algo_rithms', 'hand_side', 'Euclidean_distance', 'Processing_Systems', 'gradient_descent', 'information_theoretic', 'lower_bound', 'Neural_Information', 'NIPS_Barcelona', 'upper_bound', 'Lipschitz_constant', 'upper_bounds', 'maximum_likelihood'}
# PP6609 {'bounding_box', 'state-of_the-art', 'ground_truth', 'receptive_fields', 'NIPS_Long', 'Related_Work', 'Processing_Systems', 'bounding_boxes', 'deep_architectures', 'attention_maps', 'Neural_Information', 'perfor_mance', 'object_detection'}
# PP6659 {'worst_case', 'cross_validation', 'empirical_risk', 'acknowledgments_This', 'state-of_the-art', 'NIPS_Long', 'ordinal_regression', 'closed_form', 'Related_Work', 'exponential_family', 'special_case', 'hinge_loss', 'Neural_Information', 'closely_related', 'Processing_Systems', 'maximum_likelihood'}
# PP6677 {'standard_deviation', 'ground_truth', 'NIPS_Long', 'Processing_Systems', 'supplementary_material', 'gradient_descent', 'Neural_Information', 'computer_vision'}
# PP6683 {'prob_lem', 'NIPS_Long', 'distri_bution', 'special_case', 'lower_bound', 'Neural_Information', 'upper_bound', 'submodular_minimization', 'Processing_Systems'}
# PP6713 {'local_minima', 'RBF_kernel', 'empirical_risk', 'dynamical_systems', 'NIPS_Long', 'figure_shows', 'Hilbert_space', 'reproducing_kernel', 'wide_range', 'gradient_descent', 'mini-batch_size', 'RBF_kernels', 'Neural_Information', 'neural_networks', 'recurrent_neural', 'Processing_Systems'}
# PP6726 {'standard_deviation', 'prob_lem', 'strongly_convex', 'NIPS_Long', 'arg_min', 'Related_Work', 'warm_start', 'Processing_Systems', 'low_rank', 'special_case', 'hinge_loss', 'Neural_Information', 'inverse_covariance', 'upper_bound', 'partially_supported'}
# PP6727 {'real_world', 'randomly_selected', 'ground_truth', 'NIPS_Long', 'nearest_neighbor', 'Related_Work', 'Processing_Systems', 'Figure_Left', 'gradient_descent', 'Neural_Information', 'fully_connected', 'hidden_units', 'computer_vision'}
# PP6743 {'standard_deviation', 'cross_validation', 'empirical_risk', 'acknowledgments_This', 'ground_truth', 'arg_max', 'NIPS_Long', 'Processing_Systems', 'supplementary_material', 'modal_regression', 'Lipschitz_continuous', 'wide_range', 'Frobenius_norm', 'risk_minimization', 'Neural_Information', 'perfor_mance', 'partially_supported', 'ridge_regression'}
# PP6812 {'bounding_box', 'real_world', 'state-of_the-art', 'ground_truth', 'reinforcement_learning', 'NIPS_Long', 'object_detection', 'Related_Work', 'Processing_Systems', 'bounding_boxes', 'Neural_Information', 'fully_connected', 'computer_vision'}
# PP6820 {'state-of_the-art', 'neural_networks', 'ground_truth', 'arg_max', 'NIPS_Long', 'Related_Work', 'upper_bound', 'supplementary_material', 'dynamic_programming', 'Neural_Information', 'perfor_mance', 'recurrent_neural', 'Processing_Systems'}
# PP6834 {'Monte_Carlo', 'standard_deviation', 'arg_max', 'trust_region', 'distri_bution', 'closed_form', 'Newtons_method', 'algo_rithm', 'exponential_family', 'supplementary_material', 'oracle_calls', 'lower_bound'}
# PP6847 {'worst_case', 'prob_lem', 'NIPS_Long', 'Processing_Systems', 'Frobenius_norm', 'convex_hull', 'Neural_Information', 'Euclidean_distance', 'partially_supported'}
# PP6873 {'coordinate_system', 'tangent_space', 'equivalence_class', 'NIPS_Long', 'closed_form', 'hand_side', 'Euclidean_distance', 'gradient_descent', 'Neural_Information', 'fully_connected', 'neural_networks', 'positive_definite', 'Processing_Systems'}
# PP6882 {'http_www', 'NIPS_Long', 'Neural_Information', 'meth_ods', 'state-of_the-art', 'mini-batch_size', 'fully_connected', 'perfor_mance', 'Processing_Systems', 'secondary_structure', 'cross_validation', 'free_energy', 'Related_Work', 'supplementary_material', 'gradient_descent', 'https_github', 'acknowledgments_This', 'hidden_units', 'neural_networks', 'recurrent_neural'}
# PP6916 {'state-of_the-art', 'reinforcement_learning', 'NIPS_Long', 'nearest_neighbor', 'Related_Work', 'wide_range', 'Neural_Information', 'https_github', 'neural_networks', 'Processing_Systems'}
# PP6931 {'mutual_information', 'RBF_kernel', 'state-of_the-art', 'http_www', 'NIPS_Long', 'deep_belief', 'exponential_family', 'wide_range', 'special_case', 'Neural_Information', 'fully_connected', 'closely_related', 'recurrent_neural', 'Processing_Systems', 'ridge_regression'}
# PP6954 {'worst_case', 'state-of_the-art', 'ground_truth', 'NIPS_Long', 'closed_form', 'logistic_regression', 'special_case', 'Neural_Information', 'https_github', 'Processing_Systems'}
# PP6958 {'local_minima', 'ground_truth', 'NIPS_Long', 'figure_shows', 'supplementary_material', 'Neural_Information', 'https_github', 'closely_related', 'upper_bound', 'Processing_Systems', 'global_optimum'}
# PP6963 {'fully_connected', 'standard_deviation', 'RBF_kernel', 'state-of_the-art', 'NIPS_Long', 'optimal_transport', 'Processing_Systems', 'supplementary_material', 'hinge_loss', 'Neural_Information', 'https_github', 'neural_networks', 'Lipschitz_constant', 'computer_vision', 'ridge_regression'}
# PP6970 {'acknowledgments_This', 'influence_maximization', 'http_www', 'prob_lem', 'NIPS_Long', 'figure_shows', 'algo_rithm', 'supplementary_material', 'theoretical_guarantees', 'special_case', 'lower_bound', 'Neural_Information', 'upper_bound', 'Processing_Systems'}
# PP7008 {'additive_noise', 'standard_deviation', 'Markov_chain', 'inverse_filtering', 'acknowledgments_This', 'reinforcement_learning', 'NIPS_Long', 'distri_bution', 'hand_side', 'algo_rithm', 'Processing_Systems', 'supplementary_material', 'Neural_Information', 'partially_supported'}
# PP7019 {'real_world', 'reinforcement_learning', 'NIPS_Long', 'decision_making', 'figure_shows', 'dynamic_programming', 'Neural_Information', 'upper_bound', 'Processing_Systems'}
# PP7026 {'standard_deviation', 'Markov_chain', 'free_energy', 'positive_negative', 'NIPS_Long', 'distri_bution', 'Related_Work', 'gradient_descent', 'special_case', 'lower_bound', 'Neural_Information', 'closely_related', 'neural_networks', 'recurrent_neural', 'Processing_Systems', 'transition_operator'}
# PP7034 {'meth_ods', 'Supplementary_Material', 'empirical_risk', 'http_www', 'Gradient_Descent', 'NIPS_Long', 'algo_rithms', 'Lipschitz_continuous', 'gradient_descent', 'special_case', 'Information_Processing', 'Neural_Information', 'inverse_covariance', 'mini-batch_size', 'Lipschitz_constant', 'Processing_Systems'}
# PP7035 {'Supplementary_Material', 'hidden_units', 'visible_units', 'NIPS_Long', 'algo_rithms', 'computational_complexity', 'truncation_points', 'gradient_descent', 'mini-batch_size', 'lower_bound', 'Neural_Information', 'gradient_ascent', 'neural_networks', 'Processing_Systems', 'maximum_likelihood'}
# PP7045 {'http_www', 'NIPS_Long', 'wide_range', 'special_case', 'Neural_Information', 'state-of_the-art', 'MAP_inference', 'closed_form', 'inducing_points', 'perfor_mance', 'Processing_Systems', 'Monte_Carlo', 'cross_validation', 'standard_deviation', 'randomly_selected', 'square_root', 'Related_Work', 'supplementary_material', 'lower_bound', 'https_github', 'error_bars', 'RBF_kernel', 'marginal_likelihood', 'deep_belief', 'hidden_units', 'neural_networks'}
# PP7051 {'standard_deviation', 'state-of_the-art', 'randomly_selected', 'NIPS_Long', 'Fisher_information', 'figure_shows', 'weak_learner', 'Figure_Left', 'gradient_descent', 'special_case', 'Neural_Information', 'neural_networks', 'Processing_Systems'}
# PP7067 {'Monte_Carlo', 'acknowledgments_This', 'neural_networks', 'NIPS_Long', 'algo_rithm', 'exponential_family', 'gradient_descent', 'lower_bound', 'Neural_Information', 'https_github', 'hidden_units', 'perfor_mance', 'Processing_Systems'}
# PP7081 {'dimensionality_reduction', 'state-of_the-art', 'randomly_selected', 'NIPS_Long', 'figure_shows', 'warm_start', 'Processing_Systems', 'cold_start', 'deep_architectures', 'wide_range', 'low_rank', 'Neural_Information', 'fully_connected', 'hidden_units', 'recurrent_neural', 'computer_vision'}
# PP7110 {'mutual_information', 'Supplementary_Material', 'acknowledgments_This', 'state-of_the-art', 'neural_networks', 'NIPS_Long', 'algo_rithms', 'arg_min', 'figure_shows', 'adjacency_matrix', 'random_walk', 'gradient_descent', 'logistic_regression', 'Neural_Information', 'https_github', 'upper_bound', 'Processing_Systems'}
# PP7118 {'local_aggregative', 'Lipschitz_constant', 'real_world', 'square_root', 'NIPS_Long', 'algo_rithms', 'Hamming_distance', 'adjacency_matrix', 'Processing_Systems', 'supplementary_material', 'wide_range', 'information_theoretic', 'lower_bound', 'Neural_Information', 'fig_shows', 'aggregative_games', 'upper_bounds'}
# PP7126 {'worst_case', 'cross_validation', 'neural_networks', 'square_root', 'NIPS_Long', 'weak_learner', 'Processing_Systems', 'theoretical_guarantees', 'Neural_Information', 'https_github', 'upper_bound', 'upper_bounds'}
# PP7252 {'Monte_Carlo', 'Hawkes_process', 'reinforcement_learning', 'NIPS_Long', 'sufficient_statistics', 'distri_bution', 'Related_Work', 'logistic_regression', 'Neural_Information', 'https_github', 'hidden_units', 'error_bars', 'recurrent_neural', 'Processing_Systems'}
# PP7253 {'meth_ods', 'proxy_reward', 'real_world', 'reinforcement_learning', 'NIPS_Long', 'distri_bution', 'figure_shows', 'Related_Work', 'supplementary_material', 'Neural_Information', 'Processing_Systems'}
# PP7260 {'additive_noise', 'brain_regions', 'cross_validation', 'dimensionality_reduction', 'NIPS_Long', 'distri_bution', 'hand_side', 'figure_shows', 'gradient_descent', 'logistic_regression', 'Neural_Information', 'maximum_likelihood', 'neural_networks', 'Processing_Systems', 'computationally_efficient'}

# %% [markdown]
# Rare tokens (with the threshold set to 3%) and meaningless tokens (with the threshold set to 95%) must be removed from the vocab. The iteration that I write will spend a quite long time. So I store the result into a txt file for the moment to save time.

# %%
##save Rare tokens (with the threshold set to 3%) and context-dependent (with the threshold set to %95)
words = []
all_words_set = list(set(all_words))
count = 0 ##give a 0 value to count
for x in all_words_set:
    for i in all_pid:
        this_body_words = list(set(tokenized_body[i])) ## to get tokends of current paper
        ## if find this word in a paper, count + 1
        if x in this_body_words:
            count += 1
            
        ## if result is in this range, record this word.
    print(x + ':' + str(count/200))## see document frequency for each token
    if count/len(all_pid) >= 0.95 or count/len(all_pid) < 0.03:
        words.append(x)
    count = 0 ##initialize the counter for each loop
words = list(set(words))
# Out:
# suggestions:0.03
# de2:0.005
# videos4:0.005
# parameterselection:0.005
# restraint:0.005
# aj:0.065
# teacher:0.025
# processor:0.025
# max-normalized:0.005
# nR:0.01
# subcellular:0.005
# Recently:0.03
# taminated:0.005
# ample:0.025
# Vars:0.005
# surprised:0.005
# px1:0.005
# Takeda:0.005
# faithfulness:0.01
# SSC:0.01
# Gilbert:0.005
# genetically-encoded:0.005
# dictive:0.005
# partment:0.005
# Globerson:0.005
# betas:0.005
# SurK:0.005
# refseq:0.005
# physically:0.025
# Long-Term:0.005
# market:0.04
# native:0.015
# tracking:0.065
# tij:0.01
# concentrates:0.005
# dJ:0.005
# estimatorTV:0.005
# pan:0.01
# alternatingly:0.015
# sachusetts:0.01
# conditions:0.435
# trip:0.01
# broadcasted:0.005
# EfL:0.005
# guages:0.005
# level-set:0.005
# Cn:0.025
# ec:0.01
# experimentation:0.01
# slowly:0.08
# seeking:0.03
# elim:0.005
# convex-concave:0.015
# Numerical:0.055
# jye02:0.005
# metal:0.005
# IK:0.005
# meantime:0.01
# did:0.3
# Model-4:0.005
# P2n500r25:0.005
# crawled:0.005
# pre-processed:0.015
# convolumatching:0.005
# Near-optimal:0.005
# label-wise:0.005
# abound:0.01
# dvdelectronics:0.005
# non-iconic:0.005
# row-column:0.005
# RmL:0.005
# nitys:0.01
# yy:0.01
# OA:0.005
# predetermined:0.02
# Oh:0.005
# handbags:0.005
# formances:0.005
# intercepts:0.005
# corresponded:0.01
# incidentally:0.005
# SVMsdata:0.005
# legs:0.005
# Shared:0.01
# rection:0.01
# notwithstand:0.005
# summing:0.07
# mocap:0.005
# pm:0.015
# Katyusha:0.005
# nT:0.015
# producing:0.055
# xjU:0.005
# curvesAof:0.005
# Perr:0.005
# matricies:0.005
# conciseness:0.005
# Russell:0.01
# Sufficient:0.015
# simultaneously:0.25
# bottom-k:0.005
# minimum-norm:0.005
# confined:0.01
# Moreover:0.07
# fault-detection:0.005
# Lawrence:0.02
# solv:0.005
# MovieLens:0.01
# Arbitrary:0.01
# circles:0.055
# noise:0.435
# thought:0.11
# Hatt:0.005
# Retina:0.005
# twisting:0.005
# Description:0.015
# atmospheric:0.005
# Surface:0.01
# insights:0.05
# fol:0.04
# lowdimensional:0.01
# Indian:0.005
# chu:0.005
# Minds:0.005
# waiting:0.015
# appear:0.215
# iVt:0.005
# james:0.005
# errsq:0.005
# pets:0.005
# popularization:0.005
# normalizing:0.07
# speeding:0.02
# Hence:0.065
# y3:0.005
# alpha:0.01
# intra-democrat:0.005
# item-context:0.005
# NG:0.005
# matic:0.005
# Epoches:0.005
# kWIK:0.005
# alternating:0.135
# initialization:0.17
# low:0.455
# ten:0.115
# rASLre:0.005
# language:0.145
# Ckk1:0.005
# veal:0.015
# culverts:0.005
# TensorSketch:0.005
# renders:0.04
# Mmono:0.005
# caltechamazon:0.005
# Flight:0.005
# Sections:0.07
# DIMACS:0.005
# bottom-up:0.02
# side:0.285
# deconvolutional:0.01
# Bias:0.015
# ME-grid:0.005
# prescribed:0.02
# translations:0.025
# IIS1350983:0.005
# dates:0.02
# DiffPowers:0.005
# signatures:0.01
# maxEnt:0.005
# Bialek:0.005
# partitionings:0.01
# Artifact:0.005
# aimed:0.045
# Teradata:0.005
# Predict:0.01
# pYM:0.005
# possessing:0.01
# Zien:0.005
# soft-greedy:0.005
# nm3:0.005
# logR:0.005
# RP:0.015
# fluctuations:0.035
# Region:0.015
# nearly:0.2
# summarises:0.005
# assay:0.015
# relationships:0.095
# accom:0.005
# a2jj:0.005
# CKN-PM1:0.005
# gathering:0.005
# qualities:0.025
# EEGs:0.005
# Material:0.045
# Allard:0.005
# cross-entropy:0.055
# tpost:0.005
# v0:0.04
# mnist-group:0.005
# stateaction:0.01
# Xii:0.005
# ADMMs:0.005
# gigahertz:0.005
# scharstein:0.005
# huge:0.08
# Susskind:0.01
# communi:0.015
# dot-dashed:0.005
# Strategy:0.02
# Remote:0.005
# nkp:0.005
# Breakthroughs:0.005
# mAP-DLM:0.005
# difficult:0.54
# court:0.01
# scrambling:0.005
# kwjt:0.005
# quantification:0.02
# ineffective:0.015
# paths:0.13
# zZD:0.005
# Yong:0.005
# arises:0.14
# push:0.04
# mately:0.015
# Zit:0.005
# Non-additive:0.005
# Xz:0.005
# sectorial:0.005
# Qlj:0.005
# Hermitian:0.005
# Moser:0.005
# looked:0.045
# correspon:0.01
# sth:0.015
# non-orthogonal:0.005
# generalised:0.01
# Run:0.005
# mit:0.02
# cuss:0.005
# defaults:0.005
# ak2:0.005
# rope:0.005
# parti:0.01
# Coefficient:0.005
# Darley:0.005
# Magnetic:0.005
# monopolist:0.005
# spatial:0.185
# hinting:0.005
# sutton:0.005
# symmetrically:0.025
# Load:0.005
# anism:0.025
# Optimization:0.125
# expressivity:0.015
# raptis:0.005
# hearing:0.005
# Sundermeyer:0.005
# AP:0.035
# Depressing:0.005
# strives:0.01
# vowel:0.005
# Joho:0.005
# pave:0.015
# ridge-regression:0.005
# Bk2:0.005
# roundedness:0.005
# eruption:0.005
# Xth:0.005
# uncon:0.015
# objective-function:0.005
# ZnD:0.005
# retrieve:0.035
# organiza:0.005
# clarity:0.04
# WTAcircuits:0.005
# iDt:0.005
# listwise:0.005
# identify:0.21
# AU6:0.005
# MemeTrack:0.005
# motion-selectivity:0.005
# letters:0.07
# eigenfunctions:0.015
# assigning:0.09
# conservatively:0.005
# capital:0.03
# Zvi:0.005
# WHOIS:0.005
# OP:0.015
# navigation:0.015
# circu:0.005
# Lap:0.01
# presy:0.005
# modality:0.01
# Circuit:0.005
# host:0.025
# coding:0.08
# nents:0.01
# VC-index:0.005
# Scellier:0.005
# qualita:0.005
# punity:0.005
# errorerror:0.005
# determining:0.085
# dritchie:0.005
# conv:0.02
# Cand:0.005
# faces:0.045
# jDOT:0.005
# Metody:0.005
# n66001-15:0.005
# b1:0.07
# Lam:0.005
# bears:0.005
# pseudo-inner:0.005
# time-locked:0.005
# nition:0.025
# programmable:0.005
# DAGs:0.01
# Condition:0.03
# corpora-level:0.005
# sacrificing:0.03
# secutive:0.005
# Mesenchymal:0.005
# Government:0.03
# sigma:0.005
# kXt:0.005
# KM:0.005
# analyses:0.1
# GrangerRanks:0.005
# slide:0.005
# wjt:0.005
# improved:0.33
# gleaned:0.01
# Leader:0.015
# recognize:0.04
# ficiently:0.005
# properly:0.09
# Torch:0.01
# Hessian:0.06
# electrocardiogram:0.005
# hyperparameters:0.13
# Flowers:0.005
# hCV:0.005
# howard:0.01
# better:0.805
# publishers:0.005
# kAT2:0.005
# solid:0.095
# Kanpur:0.005
# inapplicable:0.005
# single-batch:0.005
# store:0.115
# TEMPERATURE:0.005
# wherein:0.035
# fast-sign:0.005
# ner:0.015
# prevents:0.05
# jugate:0.01
# Setup:0.05
# protein-coding:0.005
# asymme:0.005
# kGj:0.005
# TTt:0.005
# softness:0.005
# Hlder:0.005
# DKS14:0.005
# Choosing:0.005
# broker:0.005
# lexical:0.01
# Consistency:0.035
# decoded:0.02
# delineate:0.005
# bicluster:0.005
# uu:0.005
# rectional:0.01
# Learnability:0.015
# Accum:0.005
# And:0.03
# lazy-forward:0.005
# mutated:0.005
# GausTrain:0.005
# ai1:0.005
# constant-sum:0.005
# shallow:0.045
# Alexey:0.005
# Objects:0.005
# Financial:0.005
# nificance:0.005
# iterate:0.08
# resembling:0.035
# kpkW:0.005
# Lleft-translation:0.005
# sbn:0.005
# bench:0.02
# brick:0.005
# LiDAR:0.005
# spring:0.005
# seg:0.015
# till:0.015
# Trees:0.01
# Alternating:0.01
# one-at:0.005
# pxi:0.005
# telling:0.01
# revolves:0.005
# ESC:0.005
# tically:0.005
# Pixels:0.015
# portions:0.015
# word-pairs:0.005
# blockmodel:0.005
# shoes:0.01
# turalSVM:0.005
# conservation:0.015
# wellspecified:0.005
# imagenet:0.005
# Lozano:0.005
# aD:0.005
# hard-drive:0.005
# inductive:0.02
# optogenetics:0.005
# bounded:0.425
# cc:0.015
# nbs:0.005
# Baidu:0.005
# file:0.02
# ITS:0.005
# functionto:0.005
# confounder:0.005
# wfilled:0.005
# aka:0.015
# calcuated:0.005
# Alarm:0.005
# termthe:0.005
# Greg:0.005
# depth2:0.005
# where:1.0
# Applying:0.025
# N1J:0.005
# complementary:0.08
# climbing:0.01
# formalizes:0.015
# monotonic:0.035
# lifting:0.01
# Common:0.01
# negative-definite:0.005
# ng:0.005
# retain:0.07
# eigenmapsor:0.005
# C005848:0.005
# sky:0.015
# full-exponential:0.005
# lip:0.01
# timevarying:0.005
# receive:0.085
# MILP:0.005
# outputting:0.01
# rates:0.29
# Chichilnisky:0.005
# dAG:0.005
# SMISC:0.005
# Rem:0.005
# elusive:0.005
# Errors:0.015
# Hopkins:0.01
# dna-original:0.005
# dw:0.02
# MUA:0.005
# park:0.005
# disi:0.005
# Learning-to:0.005
# Active:0.015
# threaded:0.005
# days:0.065
# sian:0.075
# onthis:0.005
# Price:0.005
# fires:0.015
# figures:0.13
# recurrences:0.005
# cross-frequency:0.005
# HOIs:0.005
# ported:0.02
# atten:0.015
# Patches:0.01
# females:0.005
# hplane:0.005
# rejection:0.025
# Ru:0.005
# Perturbed:0.005
# non-strategic:0.01
# dc:0.025
# proce:0.025
# Laminar:0.005
# Exy:0.005
# nMF:0.01
# sVI:0.01
# task:0.54
# now:0.645
# midsection:0.005
# firing:0.04
# guaran:0.025
# guesses:0.005
# minibatching:0.005
# potential:0.265
# tradeoffs:0.01
# uncountably:0.005
# boy:0.005
# pH:0.005
# abstracting:0.005
# argming2G:0.005
# nuclear:0.03
# distant:0.045
# Details:0.025
# Combined:0.02
# Shields:0.005
# derivatives:0.115
# iH:0.015
# impacted:0.005
# ST:0.02
# innovation:0.04
# XSnn:0.005
# autopsy:0.005
# Howard:0.005
# iteration-specific:0.005
# Reinforcement:0.035
# DTK16:0.005
# Obj:0.005
# rewarded:0.015
# specular:0.005
# compatibility:0.005
# slightly:0.375
# mE-full:0.005
# and-Authorities:0.005
# gym:0.005
# chose:0.135
# heuristics:0.07
# kui:0.005
# tively:0.085
# chitecture:0.015
# maxRk:0.005
# trades-off:0.005
# fishand:0.005
# pur:0.015
# close:0.54
# inappropriate:0.005
# PASCAL:0.015
# Ln:0.025
# Threshold:0.035
# Forward:0.015
# comprise:0.01
# sitting:0.015
# kf:0.07
# generous:0.005
# home:0.015
# deteriorate:0.03
# Exponentiated:0.005
# artificial:0.085
# four-neighbor:0.005
# Guarantee:0.015
# twitter:0.005
# Getoor:0.005
# fixation:0.005
# Rkk:0.015
# Thorpe:0.005
# Minimizing:0.025
# v01:0.005
# disambiguate:0.02
# constant:0.635
# ying:0.01
# Age:0.005
# instrument:0.01
# guidedand:0.005
# hVt:0.005
# mirror:0.045
# weight-space:0.005
# laplacian:0.015
# coverage:0.08
# reused:0.015
# diameters:0.005
# trivially:0.075
# KW14:0.005
# Invp:0.005
# formulation:0.33
# CCF:0.005
# shtml:0.005
# pre-compute:0.01
# Charitable:0.015
# feedbacks:0.015
# pathwise:0.005
# Ldata:0.005
# encode:0.14
# Anew:0.005
# dx:0.095
# bengio:0.005
# flavour:0.005
# bl0:0.005
# multi-type:0.005
# assume:0.77
# computationally-efficient:0.005
# phe:0.01
# anatomical:0.015
# acteristics:0.01
# off-line:0.005
# sandwich:0.005
# between-lobe:0.005
# texts:0.015
# cancellation:0.005
# GEEM:0.005
# Non-stick:0.005
# endorsements:0.01
# goto:0.005
# please:0.07
# subroutines:0.005
# P3n500r25:0.005
# asymmetries:0.005
# proximity-bias:0.005
# D9:0.005
# art:0.18
# Nove:0.005
# Null:0.005
# ani:0.005
# Schedule:0.005
# EXPX:0.005
# Moment:0.005
# ZX12:0.005
# undersample:0.005
# departs:0.01
# Correspondences:0.005
# specialist:0.01
# YO:0.005
# avatar:0.005
# iRk:0.005
# chemistry:0.01
# rounding:0.02
# Advantage:0.005
# determinants:0.005
# visualization:0.07
# eTj:0.005
# continuity:0.035
# rL:0.015
# Ros:0.005
# Ballin-a:0.005
# effe:0.005
# Jascha:0.005
# Lc:0.005
# XY:0.025
# capped:0.01
# treatment-control:0.005
# Carota:0.005
# frequentist:0.005
# ziTWzj:0.005
# de-synchronization:0.005
# mingV:0.005
# manipulate:0.025
# grouped:0.06
# State:0.025
# non-identifiability:0.01
# spective:0.005
# confi:0.015
# webdev:0.005
# toQ:0.005
# correp:0.005
# Loan:0.005
# eral:0.065
# DIP:0.01
# conjugate-exponential:0.005
# avoided:0.025
# builds:0.11
# mixing:0.1
# subtraction:0.005
# currently:0.165
# surrounding:0.04
# foreign:0.005
# eigenspace:0.01
# conspire:0.005
# Dass:0.005
# yi4:0.005
# Friendster:0.005
# reoccurence:0.005
# representations:0.23
# stable:0.155
# broadening:0.01
# readily:0.05
# idiosyncratic:0.01
# Loreta-1:0.005
# arora:0.005
# wittawatj:0.005
# number:0.96
# SHOGUN:0.005
# fD1:0.005
# additively:0.02
# compiling:0.005
# Proneural:0.005
# pU:0.005
# search-directions:0.005
# similiarity:0.005
# meagre:0.005
# utrue:0.005
# situation:0.155
# costs:0.17
# Gaussian-shaped:0.005
# a20:0.005
# RBFRamp:0.005
# iu:0.005
# Km:0.015
# EkA:0.005
# entire:0.31
# Sanders:0.005
# movement:0.055
# transcriptomics:0.005
# yb:0.005
# Shaded:0.005
# mountains:0.005
# similaran:0.005
# judges:0.005
# bacteria:0.005
# imate:0.02
# communities:0.04
# sub-exponential:0.005
# Predicate:0.005
# hA:0.015
# SM-A:0.005
# Bound:0.045
# Pcan:0.005
# homotopy:0.005
# fragile:0.01
# Diag:0.005
# PFC0950c:0.005
# daysvirtually:0.005
# lets:0.06
# Gould:0.005
# borrowed:0.015
# pruned:0.01
# cessfully:0.01
# gradually:0.07
# KNN:0.005
# endures:0.005
# ey:0.005
# avoiding:0.05
# eEG:0.005
# mass:0.125
# MiMa:0.005
# digamma:0.02
# Wirtinger:0.005
# Ouv:0.005
# Em:0.01
# LLtrain:0.005
# mean2:0.005
# XIs:0.005
# re-organizing:0.005
# walk-back:0.005
# elementwise:0.035
# silence:0.005
# Fdl:0.005
# kernelsdegree:0.005
# sad:0.005
# EQVars:0.005
# Sutton:0.01
# submanifold:0.02
# bEB:0.005
# predefine:0.005
# motivations:0.025
# proposal:0.065
# revenues:0.01
# along:0.39
# pleasing:0.005
# parameteriz:0.005
# zero-sum:0.02
# b2500-10:0.005
# RVML-Lin:0.005
# PAS:0.005
# eigen-points:0.005
# adversary:0.04
# imation:0.045
# recast:0.025
# fCN:0.005
# Fi:0.04
# mountain:0.005
# pools:0.005
# ui3:0.005
# instantaneously:0.01
# Bartlett:0.005
# point-to:0.01
# aJm:0.005
# Split:0.01
# CRC:0.005
# CKN-GM:0.005
# yaxis:0.005
# canbe:0.01
# genthe:0.005
# random:0.785
# mixed-strategy:0.005
# tlc:0.005
# ESPGame:0.005
# entring:0.005
# mim:0.005
# burn:0.005
# zeros:0.06
# Multi-stream:0.005
# tistical:0.03
# reconfigure:0.005
# detectors:0.03
# near-optimal:0.05
# crank:0.005
# Mas-Collel:0.005
# L1LSTD:0.005
# regret1:0.005
# Liouville:0.005
# x6000:0.005
# graz:0.005
# integrating:0.085
# IBM-4:0.005
# Glosten:0.005
# stantial:0.005
# Adding:0.01
# pxn:0.005
# chemicals:0.005
# retained:0.02
# persistent:0.01
# Russon:0.005
# XG:0.005
# colour:0.005
# gamma:0.015
# Delete:0.005
# negligible:0.09
# P1n:0.005
# superpixel:0.005
# pre-image:0.005
# channel-wise:0.005
# Continual:0.005
# under-specified:0.005
# foto:0.005
# dpi:0.005
# Ours:0.025
# pool1:0.005
# segmen:0.01
# idle:0.005
# slot:0.015
# A9550-09:0.005
# bundle:0.01
# trajec:0.02
# half-normal:0.005
# tized:0.005
# sends:0.035
# Constant:0.005
# sides:0.085
# ALL:0.005
# wE:0.005
# PT0:0.005
# DVDs:0.015
# dependence:0.27
# per-category:0.005
# pre-select:0.005
# factoriza:0.01
# chronological:0.005
# un1:0.01
# permute:0.015
# served:0.055
# nectivity:0.005
# Conefor:0.005
# Eigenvector:0.005
# divergences:0.035
# enlarged:0.005
# News:0.025
# raise:0.025
# Sparsity:0.03
# bl:0.005
# comprising:0.015
# word-type:0.005
# expres:0.015
# SM:0.015
# save:0.025
# MCMC:0.075
# tTk:0.005
# interventions:0.015
# neurophysiological:0.005
# petitors:0.005
# ccs:0.005
# lesions:0.005
# re-scaling:0.01
# MPII:0.01
# truth:0.205
# queries:0.09
# Pham:0.005
# re-train:0.005
# sum-kernel:0.005
# Briefing:0.005
# horizon:0.08
# click:0.02
# likelihood:0.36
# harness:0.01
# non-ground:0.005
# Hk1:0.005
# two-set:0.005
# LPR:0.005
# Luce:0.01
# unboundedly:0.005
# MWIS:0.005
# distance-preserving:0.01
# log:0.665
# nt:0.025
# pA:0.01
# wanted:0.01
# AXthat:0.005
# inversion:0.065
# feedforward:0.05
# SGD:0.095
# Regulatees:0.005
# Prioritize:0.005
# tical:0.035
# BBC:0.01
# tremely:0.015
# Chernoff:0.015
# Xlk:0.005
# decline:0.005
# proxy:0.075
# Nw:0.01
# supw:0.005
# volution:0.005
# fake:0.015
# dating:0.015
# ImageNets:0.005
# presidential:0.005
# componentwise:0.015
# relegate:0.01
# pharmaceutical:0.005
# win:0.01
# Dawid:0.005
# failures:0.03
# grating:0.01
# ascent:0.08
# fits:0.085
# mPn:0.005
# elections:0.005
# kicking:0.005
# Cataract:0.005
# train-test:0.01
# st1:0.02
# studied:0.38
# adagan:0.005
# Rademacher:0.05
# helpful:0.165
# quasiorthogonalization:0.005
# pullback:0.005
# diagonally:0.005
# esti:0.075
# rect-img:0.005
# PZ:0.015
# Rd2:0.005
# HMMs:0.04
# line-thickness:0.005
# timeseries:0.005
# GRK1589:0.005
# Lm:0.01
# mle:0.005
# cOIL:0.005
# ScSPM:0.005
# Miller-Maddow:0.005
# posi:0.035
# fai:0.005
# principle:0.165
# SEP:0.005
# Quailty:0.005
# AGM12:0.005
# dlPKLL04:0.005
# providing:0.18
# plasticity:0.015
# lPACJT:0.005
# Relationships:0.005
# FA955009-1:0.005
# xi4:0.005
# duplicity:0.005
# couples:0.01
# LwF:0.005
# observations:0.35
# itera:0.03
# ents:0.005
# Spares:0.005
# uk1:0.01
# Lasso:0.05
# accent:0.005
# yd:0.01
# QCLP:0.005
# post-multiplying:0.005
# dXt0:0.005
# me:0.015
# convo:0.01
# grocery:0.01
# Function:0.095
# Arrows:0.005
# singled:0.005
# Munson:0.005
# sum-product:0.005
# guess:0.025
# seeing:0.03
# kqA:0.005
# purchased:0.005
# theMairal:0.005
# competi:0.01
# Pny:0.01
# Lazebnik:0.005
# xa1:0.005
# vasz:0.005
# manifests:0.005
# cording:0.03
# transferable:0.005
# electron:0.005
# preferred:0.095
# kWkF:0.005
# Cooking:0.005
# Snoek:0.005
# Terminology:0.005
# ognizing:0.005
# Criteria:0.005
# belonging:0.095
# analysed:0.005
# MT4:0.005
# taxi:0.01
# CDec-POMDPsSoft:0.005
# YT1:0.005
# mandate:0.005
# emission:0.025
# all-zeros:0.005
# single-instruction:0.005
# W3T:0.005
# Secondary:0.01
# noverlap:0.005
# each:0.99
# sizeM:0.005
# FA8750-17:0.005
# let:0.77
# Vs:0.015
# kAi:0.01
# log-det:0.01
# ularizer:0.005
# Imaging:0.005
# deferred:0.04
# classi:0.04
# locus:0.005
# stumps:0.01
# IFA:0.005
# Uh:0.005
# mid-level:0.01
# keck:0.005
# remind:0.025
# micropolicy:0.005
# bhojanapalli:0.005
# ckP:0.005
# over-determined:0.005
# gg:0.005
# nonon-constant:0.005
# b500ei:0.005
# level:0.48
# Meeting:0.01
# aY:0.005
# receives:0.135
# Alpes:0.005
# xy:0.015
# Sim:0.01
# i212:0.005
# ZQR:0.005
# neighbor:0.125
# initialise-c:0.005
# Welfare:0.005
# mz:0.005
# corpus:0.055
# Minh:0.005
# UCM:0.005
# Remp:0.005
# Toy:0.025
# realisations:0.01
# correlational:0.005
# accurately:0.205
# logging:0.005
# tified:0.01
# digest:0.005
# beating:0.005
# data-likelihood:0.005
# Peoples:0.005
# anomaly:0.02
# AUCs:0.01
# zroot:0.005
# STRADSs:0.005
# Epanechnikov:0.005
# dq:0.005
# Gatsby:0.015
# L2-norm:0.01
# parameterizes:0.01
# Kawahara:0.005
# elm:0.005
# neighbortions:0.005
# constructs:0.095
# unperturbed:0.005
# When:0.155
# v40:0.005
# Smr:0.005
# DeconvNet:0.005
# hand-rotating:0.005
# uninforma:0.005
# realisation:0.005
# techni:0.005
# svmc:0.005
# unspecified:0.01
# MB:0.01
# standard:0.79
# qt:0.015
# Groups:0.015
# Thi:0.005
# kwk1:0.005
# Hadfield-Menell:0.005
# owing:0.02
# seventh:0.005
# set-up:0.035
# gray-scale:0.005
# Brooks:0.005
# plot:0.23
# incremented:0.01
# obtainwith:0.005
# pseudonorm:0.005
# material:0.315
# supplemen:0.02
# conceived:0.005
# bent:0.005
# gent:0.01
# OWT-UCM:0.005
# Peshkin:0.005
# CAP:0.005
# additive:0.17
# Intrinsic:0.01
# abscissae:0.005
# Regres:0.005
# balls:0.03
# axes:0.045
# MLN:0.005
# vs-all:0.005
# handicaps:0.005
# propn:0.005
# van:0.03
# wu:0.01
# workers:0.02
# Ay:0.01
# died:0.005
# Mutual:0.015
# trial-and:0.025
# expensive:0.2
# pars:0.005
# time-step:0.03
# hardware:0.035
# discriminates:0.005
# popular:0.245
# But:0.01
# yn:0.07
# Trail:0.005
# weselect:0.005
# Structural:0.025
# Yanover:0.005
# tech101:0.01
# amplification:0.005
# unpaired:0.01
# Benchmark:0.025
# millisec:0.005
# anyRuntime:0.005
# ill-defined:0.015
# employee:0.005
# toolbox:0.03
# non-converters:0.005
# housing:0.015
# impressive:0.04
# Lorenz-x:0.005
# Regularizers:0.005
# GeRT:0.005
# LabelMe:0.005
# tying:0.02
# brand:0.005
# FKM05:0.005
# sklearn:0.005
# finished:0.01
# technology:0.04
# ulus:0.01
# pedestrian:0.01
# corners:0.025
# cavity:0.01
# tk1:0.01
# af:0.02
# CanICA:0.005
# geographic:0.005
# one-half:0.005
# power-method:0.005
# AUPRG:0.005
# describ:0.005
# upfront:0.005
# minv:0.01
# converted:0.06
# yellow:0.035
# minkx:0.005
# Violated:0.01
# coefficient:0.11
# MR8:0.005
# maxkx:0.005
# carmounted:0.005
# zspec:0.005
# Dv:0.01
# Promotion:0.005
# desired:0.225
# temporal-occipital:0.005
# wake:0.01
# autoenInitialize:0.005
# Amodei:0.005
# ciently:0.025
# kindly:0.01
# non-submodularity:0.005
# sprial:0.005
# prop:0.065
# referenced:0.015
# slices:0.01
# Alfred:0.01
# causes:0.115
# rod:0.005
# posed:0.105
# warping:0.01
# qT0:0.005
# mil:0.01
# Optimize:0.005
# kNh:0.005
# tran:0.005
# eg:0.025
# monetary:0.005
# zx:0.005
# non-Euclidean:0.005
# sonar:0.005
# Samsung:0.02
# was:0.9
# pretrained:0.02
# feasible:0.165
# different:0.92
# initializer:0.005
# profile:0.045
# neighboring:0.1
# ill-conditioned:0.01
# Python:0.035
# regularizer2:0.005
# blocked:0.025
# dogma:0.005
# ErD:0.005
# song:0.005
# contemporaneous:0.005
# Eqn:0.02
# landscape:0.02
# deAlgorithm:0.005
# concurrently:0.02
# cancerous:0.005
# Summing:0.01
# follow:0.345
# configura:0.005
# Sensitivity:0.01
# configurations:0.07
# Pi:0.05
# type-accuracy:0.005
# daily:0.01
# tative:0.01
# collapsing:0.01
# Nonnegative:0.005
# overly-compact:0.005
# kin8nm:0.005
# aries:0.01
# confirmation:0.005
# respec:0.045
# relative:0.385
# kuu:0.005
# MaxEnt:0.015
# clinically:0.005
# timisation:0.005
# Dang:0.005
# PQ:0.005
# coordinated:0.01
# inconsequentially:0.005
# ship:0.025
# NL:0.005
# non-commutative:0.01
# analogs:0.015
# bilmes:0.005
# square-integrability:0.005
# effect:0.355
# Fb:0.005
# prefered:0.005
# Jjk:0.005
# assump:0.045
# nmax:0.01
# ramp:0.02
# lAC:0.005
# resolved:0.02
# Jacobian:0.035
# sub-mini:0.005
# weighted-degree:0.005
# efficiently:0.415
# bn:0.035
# Protein:0.02
# divergence2:0.005
# wKor:0.005
# Daily:0.005
# ADMM-best:0.005
# VC-classPof:0.005
# slab:0.005
# User-selected:0.005
# Pars:0.005
# bias-shifting:0.005
# PMI:0.005
# amples:0.015
# downsides:0.005
# ft:0.025
# Williamson:0.015
# RN1:0.005
# surplus:0.005
# clog:0.005
# competitors:0.03
# tiConf:0.005
# nice:0.055
# Loglikelihood:0.005
# multiview:0.01
# St1:0.005
# testi:0.005
# Typical:0.015
# indirectly:0.055
# Receptive-field:0.005
# crete:0.005
# shear:0.005
# Dirich:0.015
# forward-backward:0.01
# mistic:0.005
# drag:0.005
# Mini-Batches:0.005
# species:0.035
# medians:0.005
# decorrelating:0.005
# Fk:0.01
# maxhH:0.01
# high-precision:0.01
# nA:0.02
# inequality:0.29
# teach-in:0.005
# dataThe:0.005
# ajt1:0.005
# fully-sequential:0.005
# fb:0.015
# Regina:0.005
# Drawing:0.005
# Realized:0.005
# suc31st:0.005
# proved:0.24
# happens:0.13
# binning:0.02
# eG:0.005
# transmitting:0.02
# Diagrams:0.005
# splice:0.01
# context-response:0.005
# vocabulary:0.06
# feeding:0.015
# Jensen:0.015
# Viji:0.005
# yielding:0.13
# att:0.005
# ql:0.01
# Ble12:0.005
# boltzmann:0.005
# technically:0.025
# Poljak:0.005
# minRY:0.005
# qM:0.005
# finetun:0.005
# biological:0.11
# per-image:0.005
# selecting:0.19
# reallocation:0.005
# advertise:0.005
# multi-region:0.005
# CatGAN:0.005
# instantiating:0.005
# scale:0.41
# Alignment:0.005
# thesize:0.005
# identifying:0.115
# Ignoring:0.01
# Covertype:0.005
# embed:0.075
# ridge-penalized:0.005
# Aji:0.005
# tA:0.005
# implic:0.005
# solve:0.41
# INPUT:0.005
# xd:0.02
# reaching:0.05
# left-to:0.005
# Katzell:0.005
# Undirected:0.005
# memoization:0.01
# Libavcodec:0.005
# Sinusoidal:0.005
# Maillard:0.005
# affiliate:0.005
# AS-1:0.005
# log1d:0.005
# model3:0.005
# rotating:0.025
# Co-Adapt:0.005
# differences:0.21
# Dropout:0.025
# Yi1:0.005
# rational:0.02
# frontal-parietal:0.005
# enhancing:0.01
# DPM:0.015
# characteristically:0.005
# ride:0.005
# say:0.24
# amin:0.005
# feature-networks:0.005
# DN-CDL:0.005
# Automated:0.01
# Stick-Breaking:0.005
# tionaries:0.005
# quantity:0.18
# per-cluster:0.005
# Yl:0.005
# attainable:0.01
# rious:0.005
# Ancona:0.005
# unrelated:0.025
# Mark:0.015
# IIS-1252412:0.005
# contaminating:0.005
# schedule:0.05
# rayleigh:0.005
# deracted:0.005
# converse:0.01
# Gauss-Seidel:0.005
# lipschitzness:0.005
# desk:0.005
# mj:0.02
# Sets:0.02
# Detailed:0.01
# re-update:0.005
# dthen:0.005
# sinp2Xp1:0.005
# orthogonalization:0.01
# non-spherical:0.01
# Gong:0.005
# fully-automatic:0.005
# Importance:0.02
# high-magnitude:0.005
# underlying:0.355
# experimentis:0.005
# kSn:0.005
# limited:0.365
# BEBF:0.005
# cepts:0.01
# predecessors:0.005
# factorised:0.005
# throughout:0.245
# disregarding:0.005
# multi-neuron:0.005
# ADMM:0.03
# Despite:0.01
# stamps:0.005
# narios:0.02
# toronto:0.01
# during:0.345
# activations:0.09
# Bayes-Learn:0.005
# Continuous-Time:0.005
# enlarging:0.005
# BGCM-L:0.005
# FA:0.015
# loglikehood:0.005
# scientists:0.01
# reconstruct:0.08
# Assortment:0.005
# Rdr:0.005
# affordable:0.01
# Bringmann:0.005
# camel:0.005
# player-specific:0.005
# SGCls:0.005
# oriented:0.02
# bI:0.005
# uously:0.005
# v10:0.005
# nonasymptotic:0.005
# truly:0.045
# geomet:0.005
# optimising:0.01
# DR:0.015
# righthand:0.005
# majorization-minimization:0.01
# marony:0.005
# AEPDGP:0.005
# blog2:0.005
# EhQ:0.005
# NORB:0.015
# discrimination:0.015
# ExpB:0.005
# alternation:0.005
# restrictive:0.06
# reimple:0.005
# M2:0.04
# procedureand:0.005
# inferences:0.025
# ONR-N00014:0.005
# selec:0.015
# MemeTracker:0.01
# having:0.335
# discriminability:0.005
# Quantification:0.005
# B1t:0.005
# tell:0.04
# Power-law:0.005
# FBIS:0.005
# fine-tuning:0.05
# dedi:0.01
# inextricably:0.005
# vp:0.005
# clines:0.005
# ends:0.055
# SUSY:0.015
# bracket:0.01
# memory:0.255
# PNW:0.005
# vegetables:0.005
# ances:0.005
# iD:0.01
# DC:0.02
# Matchings:0.005
# reflects:0.09
# prestr:0.005
# accordingly:0.07
# xir:0.005
# streaks:0.005
# child:0.01
# music:0.025
# tangent:0.09
# claimed:0.005
# umass:0.005
# Program:0.05
# vm:0.005
# glutamate:0.005
# parsimonious:0.015
# scheduler:0.005
# spatiotemoral:0.005
# RMSEs:0.005
# Maas:0.005
# had:0.255
# arechoose:0.005
# schitz:0.01
# skull:0.005
# donation:0.015
# Sphere:0.01
# hensman:0.005
# assembled:0.01
# cC:0.005
# Cumulative:0.005
# ND:0.005
# templates:0.005
# Iv:0.005
# archi:0.02
# of-concept:0.005
# items:0.09
# Structures:0.015
# specialized:0.045
# pima-diabetes:0.005
# such:0.98
# rounds:0.115
# Probabilistic-Backpropagation:0.005
# dJconcave:0.005
# Ji-LassoLu:0.005
# trastive:0.005
# itos:0.005
# Florian:0.005
# cantly:0.02
# andtooptimization:0.005
# fixedpoint:0.005
# troll:0.005
# OMD:0.005
# maximizer:0.02
# rearranging:0.02
# painless:0.005
# stimulus-information:0.005
# theano:0.01
# recognizable:0.01
# cropped:0.05
# server:0.015
# lda16:0.005
# elasticity:0.005
# prob7:0.005
# Rglin:0.005
# laptops:0.005
# Implicit:0.015
# mS:0.005
# proteins:0.02
# GPU:0.05
# DMP:0.005
# attained:0.03
# thickness:0.02
# yaw:0.005
# repeating:0.05
# thesoft:0.005
# p00:0.005
# accelerations:0.01
# Dribble:0.005
# Poly:0.005
# torNet:0.005
# pproposed:0.005
# IS14013A:0.005
# dCSFA-3:0.005
# xs:0.04
# certain:0.465
# Gradient:0.13
# segregation:0.005
# np2:0.005
# Randomize:0.005
# rASLil:0.005
# identifies:0.065
# fU:0.005
# Mkj:0.005
# conset:0.005
# UCB-S:0.005
# lake:0.005
# preference-content:0.005
# indicies:0.005
# ade:0.005
# Dempster:0.005
# Yan:0.01
# affinely:0.005
# generalization:0.265
# Gershman:0.01
# lower:0.655
# capitalization:0.005
# OBS:0.005
# koh:0.005
# Cluster:0.01
# oversea:0.005
# nearest-neighbor:0.015
# intriguing:0.02
# ci:0.09
# overfitted:0.005
# ResNet101:0.005
# proof:0.53
# Cv2:0.005
# log-transition:0.005
# steep:0.015
# Liu:0.03
# corresponds:0.45
# pendency:0.005
# WSJ:0.005
# abstentions:0.005
# question:0.305
# Xk:0.015
# exemplar-based:0.005
# vate:0.005
# Lasfeature:0.005
# aa:0.005
# proximately:0.045
# highest:0.21
# daters:0.005
# core-set:0.005
# ecient:0.005
# Guggenheim:0.005
# Ti:0.02
# single-regime:0.005
# introduce:0.48
# Identifiability:0.005
# spokes:0.005
# scalability:0.11
# fitness:0.015
# dL0:0.005
# basketball:0.015
# substitut:0.005
# Pascal-2:0.005
# maxyi:0.005
# sto:0.005
# sibility:0.005
# Effect:0.03
# indicative:0.02
# reorganized:0.005
# Tx:0.01
# eventually:0.115
# Bloggers:0.005
# exponential1:0.005
# Krause:0.01
# Z2m:0.005
# ground-truth:0.065
# nipsfsc:0.005
# homuncular:0.005
# urations:0.005
# figure-ground:0.005
# sufficientk:0.005
# DW:0.005
# Afonso:0.005
# CFG14:0.005
# weaker:0.09
# softplus:0.02
# Correlation:0.02
# Chung:0.005
# Mej:0.005
# unity:0.01
# to-east:0.005
# generalizes:0.115
# transitional:0.005
# yes:0.01
# DNL:0.005
# issued:0.01
# SINR-bias:0.005
# FindConsistentTree:0.005
# de-n:0.005
# Eitan:0.005
# hilbert:0.005
# surrounded:0.01
# SAM:0.005
# wij:0.035
# res:0.01
# libSVM:0.005
# transformed:0.13
# purple:0.005
# resuling:0.005
# Barkan:0.005
# Extensions:0.02
# p10:0.005
# exdb:0.005
# them:0.71
# hL:0.01
# monumental:0.005
# probably:0.06
# attn:0.005
# tissue:0.03
# priced:0.005
# tightening:0.005
# divergence:0.215
# CPUs:0.025
# EFE:0.005
# Smoker:0.005
# Cinzia:0.005
# relaxations:0.025
# Salakhutdinov:0.005
# specifies:0.095
# Wij2:0.005
# sistency:0.005
# guarantees:0.335
# minimizers:0.035
# flowers:0.005
# Clustering:0.035
# interpretation:0.17
# Celebi:0.005
# HITS:0.005
# Exploration:0.02
# element-wise:0.045
# mdj:0.005
# n2m1:0.005
# Eigendecomposition:0.005
# GLS81:0.005
# d2r:0.005
# filter:0.115
# serves:0.08
# Yil:0.005
# gripper:0.005
# HM:0.01
# kKt:0.005
# volunteers:0.005
# ACE:0.005
# cosets:0.005
# subpolicies:0.005
# admissions:0.005
# composable:0.01
# L2LSTD:0.005
# Nearset:0.005
# double-or:0.005
# tempt:0.01
# Wx0j:0.005
# DetectorNet1:0.005
# ParaHippocampal:0.005
# Subgroups:0.005
# difficultly:0.005
# joint-actions:0.005
# docenti:0.005
# multiplicaT:0.005
# testify:0.005
# mid-1950s:0.005
# Zl1:0.005
# rated:0.02
# LSB:0.005
# CASA:0.005
# allocation:0.035
# sss1:0.005
# Dj:0.005
# navigational:0.005
# ning:0.03
# sin:0.09
# Berkes:0.005
# Apprenticeship:0.005
# Egregious:0.005
# itpwere:0.005
# xr:0.02
# word-alignment:0.005
# genis:0.005
# eliciting:0.01
# avg:0.015
# cave:0.005
# enormously:0.005
# Hart:0.005
# funtion:0.005
# appeals:0.01
# rons:0.015
# hallmark:0.01
# simply:0.56
# hierarchically:0.01
# MIT:0.01
# cre:0.005
# paremeters:0.005
# Boltzmann:0.05
# sometime:0.005
# band:0.04
# handbag:0.005
# SG:0.01
# architectures:0.11
# reaction:0.01
# mistakes:0.05
# FP7-ICT:0.005
# flow-based:0.005
# extrapolates:0.01
# hetereogeneous:0.005
# epoches:0.01
# multiway:0.005
# conjec:0.005
# IFKs:0.005
# actorcritic:0.005
# screening:0.005
# xT:0.06
# trast:0.015
# setsanreveal:0.005
# barriers:0.015
# projecting:0.09
# sums:0.12
# lustrate:0.005
# qualification:0.005
# labelstypically:0.005
# complicates:0.03
# rectifiers:0.01
# kvk:0.035
# tion:0.725
# active:0.195
# Fiechter:0.005
# mtitsias:0.005
# Lin:0.02
# gil:0.005
# company:0.035
# Fields:0.03
# nFESS:0.005
# misation:0.005
# Tanakas:0.005
# usethat:0.005
# richness:0.005
# distributionperhaps:0.005
# downstream:0.02
# Propagation:0.015
# HypFwd:0.005
# phenomenological:0.005
# COIL-20:0.005
# SEQUENCES:0.005
# rectangles:0.01
# sentence-pairs:0.005
# cardio:0.005
# alized:0.005
# Yin:0.005
# discoGAN:0.005
# fia:0.005
# Mt1:0.005
# kQY:0.005
# matrix2:0.005
# izing:0.01
# superscript:0.025
# evening:0.005
# Reverse:0.005
# compositioncombining:0.005
# Z1t:0.005
# paramterized:0.005
# Motivated:0.01
# agnostic:0.025
# parallels:0.01
# Open:0.025
# compound:0.005
# lawns:0.005
# mP:0.01
# obtainable:0.005
# suboptimal:0.09
# BSC:0.005
# mild:0.095
# question-answering:0.005
# QLDS-model:0.005
# Word:0.025
# v3:0.005
# havep:0.005
# clearer:0.01
# Filter:0.02
# ModelEdge:0.005
# single-kernel:0.005
# cleaning:0.005
# zeroth-order:0.01
# CXCR5:0.005
# Removal:0.005
# Parallelism:0.005
# testbeds:0.005
# KX:0.005
# pref:0.005
# Tang:0.01
# accelerating:0.035
# WMF:0.005
# lic:0.01
# utes:0.015
# intra-class:0.01
# subregions:0.005
# lambda:0.005
# Memorial:0.005
# Fm:0.005
# limitation:0.09
# Round-robin:0.005
# DS:0.01
# ApplyEyeMakeup:0.005
# rive:0.015
# perpetually:0.005
# K1:0.07
# Reader:0.005
# Recall:0.08
# precondition:0.005
# elucidated:0.005
# NNs:0.005
# searchdirections:0.005
# hand-written:0.01
# Transforming:0.005
# ence:0.115
# single-variable:0.005
# sub-algorithm:0.005
# requires:0.63
# Wellner:0.005
# malizing:0.01
# Deformations:0.005
# parameterize:0.035
# fn:0.02
# jT:0.01
# lowers:0.02
# Prob:0.02
# Subprofile:0.005
# diminished:0.005
# Lat:0.005
# onedimensional:0.01
# Although:0.085
# jobs:0.02
# trinomial:0.005
# exon:0.015
# glc:0.005
# thisthe:0.005
# chip:0.005
# cepted:0.005
# dantly:0.005
# tour:0.005
# MMs:0.005
# website:0.06
# slowest:0.005
# originally:0.08
# sF:0.01
# upregulate:0.005
# synchronizing:0.005
# Blind:0.005
# unexpected:0.015
# PP:0.01
# dual-memory:0.005
# ject:0.02
# evolved:0.005
# Tsitsiklis:0.01
# wake-sleep:0.005
# Sample:0.085
# Slow:0.005
# indistinguishably:0.005
# average:0.615
# progres:0.005
# Abbe:0.005
# Bandeira:0.01
# TriFac:0.005
# appli:0.03
# unavoidably:0.005
# homolog:0.005
# diving-sp:0.005
# PPV3:0.005
# explain:0.185
# Risk-sensitive:0.005
# ps:0.02
# occupies:0.005
# datathe:0.005
# formingthis:0.005
# tiable:0.005
# time-stamp:0.005
# fallible:0.005
# non-ergodic:0.005
# revising:0.005
# reflect:0.12
# noisier:0.005
# undiscovered:0.005
# primarily:0.065
# SE1:0.005
# supplementary:0.33
# Christodoulopoulos:0.005
# GARGANTUA:0.005
# restart:0.015
# eigenvectors:0.085
# contributes:0.025
# quantifies:0.035
# plant3:0.005
# Zhangs:0.005
# Precuneus:0.005
# game-theoretic:0.005
# Improvements:0.005
# Ks:0.005
# ill:0.02
# Adversarial:0.035
# GAM:0.005
# movie:0.04
# iw:0.005
# nonnegative:0.105
# hole-reaching:0.005
# dynamics:0.21
# cross-species:0.005
# arrow:0.025
# Ultimately:0.01
# pf:0.01
# calculus:0.015
# recursive:0.08
# narasimhan:0.005
# ZZ:0.005
# Count:0.015
# Lei:0.005
# Task-relevant:0.005
# contrast-normalized:0.01
# enables:0.18
# Colorization:0.005
# imRecall:0.005
# years:0.195
# gold-standard:0.005
# Cascade:0.015
# HumanEva:0.005
# rises:0.015
# stage-wise:0.005
# frameworks:0.05
# bations:0.005
# expansions:0.03
# correspondences:0.03
# zero-out:0.01
# fers:0.005
# negatively:0.005
# ongo:0.005
# Brouwers:0.005
# thread:0.01
# PLaplacian:0.005
# skill:0.01
# books:0.025
# putationally:0.025
# possibility:0.095
# Sun:0.01
# specific:0.485
# vational:0.005
# simple-cell:0.01
# kEks:0.005
# mC-b:0.005
# meth:0.105
# ciated:0.005
# assess:0.125
# Altogether:0.005
# snatch:0.005
# paced:0.005
# comprises:0.035
# Being:0.005
# ZiD:0.005
# whats:0.005
# togram:0.005
# a3:0.02
# Groups2of2memes:0.005
# possib:0.005
# fibre:0.01
# maintenance:0.01
# agency:0.005
# Set:0.095
# precede:0.01
# genus:0.005
# constancy:0.005
# aggregating:0.015
# new:0.76
# IAP:0.005
# eats:0.005
# rti0:0.005
# dinal:0.005
# aT:0.025
# functionals:0.02
# unwrapped:0.005
# solue:0.005
# benchmarking:0.01
# rogate:0.005
# biguities:0.005
# brightness:0.01
# Preexposure:0.005
# separation:0.095
# spectively:0.03
# implemen:0.005
# VarDs:0.005
# relevances:0.005
# font:0.03
# bs:0.03
# guided:0.02
# tentrelated:0.005
# Self-Modulating:0.005
# diagrams:0.005
# maximal:0.135
# Windows:0.005
# falciparum:0.005
# TOP:0.005
# bird:0.025
# pST:0.005
# usually:0.41
# Correspon:0.005
# detecting:0.095
# workhorse:0.005
# bas:0.005
# equilibrium:0.055
# Wei:0.005
# None:0.005
# Restricting:0.005
# Constraint:0.015
# thant:0.005
# mulan:0.005
# bag:0.04
# wko:0.005
# adding:0.34
# whoseP:0.005
# agents:0.09
# haystack:0.005
# tersection:0.005
# BiLSTM:0.005
# morphology:0.02
# Hasting:0.005
# joint-value:0.005
# by-64:0.005
# Defazio:0.005
# Series:0.02
# Klein:0.01
# sfu:0.005
# kgt:0.015
# incorporates:0.075
# medications:0.005
# wit:0.005
# kU:0.015
# EM:0.13
# kloft:0.005
# kVj:0.005
# detector:0.03
# vj:0.03
# products:0.175
# Hamilton:0.005
# http:0.215
# Pierce:0.005
# x368:0.005
# minXC-S:0.005
# Weiss:0.005
# nm:0.05
# realization:0.065
# solberg:0.005
# Studies:0.01
# prediction:0.365
# taggingyet:0.005
# Jump:0.005
# TownsendG:0.005
# shallo:0.005
# travel:0.03
# Meliksetian:0.005
# finer-scale:0.005
# point-predictions:0.005
# doorways:0.005
# herein:0.01
# starts:0.14
# kwj:0.005
# yL:0.005
# Baldi:0.005
# meaningfully:0.015
# merely:0.075
# Inc:0.005
# zc0:0.005
# reflection:0.01
# X11:0.005
# emporal:0.005
# PGGs:0.005
# lMNN:0.005
# backtracking:0.005
# jection:0.02
# attend:0.015
# X1:0.125
# interleaves:0.005
# attentional:0.015
# traversed:0.005
# shenzhen:0.005
# kqkW:0.005
# unexpectedly:0.005
# resultsand:0.005
# zhen:0.005
# mulation:0.01
# appropriate:0.355
# strongs:0.005
# gj:0.025
# recurrence:0.03
# Sys3:0.005
# Contour:0.005
# Localized:0.005
# Frydenberg:0.005
# preserve:0.125
# recordedcan:0.005
# After:0.06
# Arcones:0.005
# ANR-11:0.01
# potheses:0.01
# expecting:0.015
# valuations:0.01
# fractionally:0.005
# implementation:0.315
# CAPS:0.005
# highlight:0.075
# supporting:0.015
# Lapla:0.025
# BJ:0.005
# timized:0.005
# constellation:0.005
# Assump:0.005
# FAH:0.005
# notwithstanding:0.01
# JC:0.005
# Javdani:0.005
# Fv:0.005
# arevolume:0.005
# Scheme:0.015
# FEM:0.005
# rougher:0.005
# xi2:0.01
# texturing:0.005
# orruption:0.005
# Simplifying:0.005
# photoreceptor:0.005
# notations:0.105
# CKN:0.005
# recently-published:0.005
# encounter:0.025
# decomposes:0.025
# inevitably:0.02
# convolutionally:0.005
# untangled:0.005
# tolerates:0.005
# plugging:0.075
# mispricing:0.005
# maxvCn:0.005
# l0:0.01
# entiable:0.005
# gyrus:0.005
# spe:0.02
# arc-cosine:0.01
# eliminated:0.04
# hav:0.005
# eigenvalue-based:0.005
# multiplications:0.03
# Rel:0.005
# onfeature:0.005
# BX:0.01
# expo:0.02
# misspecification:0.03
# toRtrain:0.005
# a1:0.125
# wearables:0.005
# peels:0.005
# meaningless:0.02
# optimally:0.08
# colorization:0.01
# Summary:0.05
# Warm-up:0.005
# phenomenon:0.09
# capture:0.34
# Top:0.08
# CPR:0.005
# hatena2:0.005
# discussed:0.37
# investigates:0.005
# Computationally:0.005
# non-input:0.005
# nets:0.05
# eCE:0.005
# been:0.92
# shift:0.09
# mannoprotein:0.005
# kkK:0.005
# hq:0.01
# Marc:0.015
# depicted:0.065
# preshaping:0.005
# KERNELS:0.005
# aCC:0.005
# dkl:0.01
# paper:0.84
# political:0.01
# Royal:0.005
# f4:0.005
# referential:0.01
# side-information:0.015
# positivenegative:0.005
# query:0.12
# acquisition:0.02
# big:0.065
# witharc:0.005
# hS:0.015
# Kohli:0.005
# CLSW16:0.005
# hope:0.175
# CUB:0.015
# positively:0.025
# tongue:0.005
# erality:0.005
# PAi1:0.005
# Mod:0.005
# escapes:0.005
# subspace-recovery:0.005
# Category:0.01
# csail:0.015
# caveat:0.02
# configure:0.005
# orthosymmetric:0.005
# aggregators:0.005
# GHz:0.065
# AGKM12:0.005
# Lyu:0.01
# IIS-1117591:0.005
# FAlap:0.005
# opportunities:0.03
# RCV1:0.005
# topic-weight:0.005
# claim:0.1
# assigns:0.09
# concatena:0.005
# experimentally:0.105
# exp-concave:0.005
# kP:0.025
# dynamical:0.065
# matics:0.005
# ainv:0.005
# Dec-POMDPs:0.005
# spawning:0.005
# benchmarks:0.055
# Sigmoid:0.01
# fG:0.005
# Alekh:0.005
# S2Z:0.005
# Frequencies:0.005
# ga0:0.005
# amazondslr:0.005
# presser:0.005
# faithful:0.02
# Cutajar:0.005
# relief:0.005
# gen:0.12
# IQP:0.005
# proportionality:0.005
# Panel:0.015
# ERG:0.005
# Ilan:0.005
# softmax:0.06
# truG-TRBM:0.005
# TruG-RBM:0.005
# TWV:0.005
# Id:0.02
# utmost:0.005
# chi-squared:0.01
# dilation:0.005
# Ei:0.03
# LWTA-n:0.005
# Seventh:0.025
# CPRL:0.005
# tautology:0.005
# xzi:0.005
# Bengio:0.035
# degree:0.24
# compared:0.66
# Ratio:0.015
# copiesto:0.005
# submits:0.005
# SimpleIS:0.005
# resolution:0.095
# increas:0.015
# Lamb:0.005
# freely:0.02
# HN-ST:0.005
# zij:0.015
# boosted:0.025
# uiSk:0.005
# Hubs:0.005
# mMD-quad:0.005
# angularly:0.005
# Auto-encoders:0.005
# supple:0.01
# PC14:0.005
# appends:0.005
# visit:0.03
# cQ:0.005
# peer:0.005
# Rmnn:0.005
# figs:0.01
# closed-loop:0.005
# N000141010934:0.005
# favourable:0.01
# multiplying:0.05
# undertaken:0.005
# near-optimality:0.015
# dy:0.055
# log-marginal:0.01
# kinetics:0.005
# MovieLens-10Million:0.005
# frequently-occurring:0.005
# wrt:0.01
# decidedly:0.005
# expertise:0.005
# xj1:0.015
# Fp:0.005
# RDP1:0.005
# framing:0.005
# peaky:0.005
# blendshape:0.005
# riod:0.005
# segregated:0.005
# kHk0:0.005
# two-sample:0.02
# Induction:0.005
# ireland:0.005
# hibits:0.005
# FSLs:0.005
# Topic-10:0.005
# Equa:0.01
# winds:0.005
# px:0.025
# GT1:0.005
# tommi:0.005
# Nat:0.005
# Cholesky-CMA:0.005
# ul:0.01
# straints:0.02
# Filters:0.015
# shots:0.005
# ywkj:0.005
# rq:0.01
# Phase:0.01
# Lossi:0.005
# nature:0.215
# Woodbury:0.02
# systematically:0.03
# influencing:0.005
# photore:0.005
# EY:0.015
# quartic:0.005
# efPT:0.005
# unknown:0.41
# lifts:0.01
# loosely:0.02
# levelslow:0.005
# physiological:0.02
# weakness:0.01
# deviates:0.01
# Gating:0.005
# justi:0.005
# lected:0.01
# attrac:0.005
# xG:0.005
# RDA:0.005
# Lo:0.005
# hand-designed:0.02
# subpopulations:0.01
# TestTest:0.005
# adversarial:0.09
# Tao:0.005
# grammar:0.005
# sHVN:0.005
# larly:0.03
# RF:0.005
# KPCA:0.005
# Haeberlen:0.005
# u0:0.03
# v20:0.005
# plane:0.085
# justifying:0.005
# Kronecker:0.045
# details:0.525
# Gaussian-Wishart:0.005
# composebya:0.005
# resolves:0.01
# SFO:0.005
# inappropri:0.005
# Sc:0.005
# vertices:0.1
# discrim:0.01
# Ada:0.005
# conflict-inducing:0.005
# tries:0.085
# controlled:0.09
# log10:0.015
# disciplines:0.01
# SUNprimitive:0.005
# simplies:0.005
# employ:0.195
# d2max:0.005
# symbolic:0.01
# field:0.21
# doc:0.015
# feedback:0.105
# sensitiv:0.005
# i5:0.01
# timal:0.04
# irrespective:0.02
# shifted:0.04
# MMDL:0.005
# RAW:0.01
# Activation:0.015
# mistakenly:0.005
# sub-family:0.005
# Vu:0.01
# Fouhey:0.005
# Ronan:0.005
# kqk4H:0.005
# destination:0.01
# electrostatic:0.005
# Prototyp:0.005
# y00:0.005
# Polymerase:0.01
# paints:0.005
# ad:0.105
# conjunctive:0.01
# Eberhardt:0.005
# occa:0.01
# Randomly:0.01
# catches:0.005
# phase-lag:0.005
# collaborated:0.005
# Two-sample:0.005
# fulfill:0.025
# linearthreshold:0.005
# ngram:0.005
# sN:0.01
# vox:0.005
# lesser:0.01
# darker:0.01
# probe:0.015
# fellowship:0.02
# discovered:0.05
# vjt:0.005
# non-expert:0.005
# Lastly:0.005
# Dev:0.005
# pull:0.015
# exonic:0.005
# IAPRTC-12:0.005
# spectroscopic:0.005
# Pennsylvania:0.01
# stereotyped:0.005
# fitted:0.045
# masks:0.03
# parity:0.005
# opportunity:0.015
# Laplacians:0.005
# Bilingual:0.01
# repository:0.065
# split:0.255
# proxies:0.02
# caltechdslr:0.005
# men:0.01
# prohibitively:0.04
# Dre:0.005
# Discrete:0.025
# initialise:0.015
# cart-balancing:0.005
# ss0:0.005
# MMCI:0.005
# synthesis:0.025
# realigned:0.005
# hand:0.495
# Ventral:0.005
# Completed:0.005
# GP-LVM:0.005
# projected:0.135
# by-C:0.005
# NCut:0.005
# EikM:0.005
# origin:0.05
# sparsification:0.01
# Branch:0.005
# revisits:0.01
# damianou:0.005
# monolingual:0.005
# Transductive:0.02
# wakes:0.005
# Chaudhuri:0.005
# pyraWMF:0.005
# SeDuMi:0.005
# seem:0.13
# likelihoods:0.055
# Update:0.12
# Positron:0.005
# non-convexity:0.055
# room:0.045
# argmaxAV:0.005
# infinitesimal:0.015
# misalignment:0.005
# squared-loss:0.005
# maze:0.01
# well-established:0.02
# invertible1:0.005
# dev:0.02
# document-specific:0.005
# sequence-based:0.005
# favored:0.01
# ral:0.06
# dummy:0.015
# Rakhlin:0.005
# Max-Cut:0.005
# Hutter:0.005
# Porder:0.005
# fora:0.005
# Labels:0.005
# indifferent:0.01
# well-known:0.225
# pFA:0.005
# performing:0.29
# attenuation:0.005
# greedily:0.035
# errT:0.005
# theart:0.015
# Loshchilov:0.005
# Domains:0.005
# knowing:0.08
# interQuse:0.005
# Fixed:0.025
# Informally:0.005
# torial:0.005
# mouse:0.03
# ufo:0.005
# A22E:0.005
# NWP:0.005
# formation:0.065
# deceptively:0.005
# word-distributions:0.005
# closeness:0.015
# mimic:0.04
# doubled:0.01
# ularity:0.005
# dom:0.04
# FPL-based:0.005
# a1a:0.005
# natural:0.49
# LIONS:0.005
# bijectively:0.005
# miss:0.035
# Return:0.04
# therefor:0.005
# intractable:0.2
# dhi:0.005
# align:0.055
# subgraph:0.03
# HMMfilter:0.005
# BGKP16:0.005
# detection:0.16
# bill:0.01
# cooperativeness:0.005
# tautologies:0.005
# gap:0.195
# backgam:0.005
# tag:0.025
# linear-Basis:0.005
# subpopulation:0.015
# nslkdd:0.005
# SDCA:0.005
# log-concave:0.015
# valuable:0.08
# bb:0.015
# ga:0.005
# time-stamps:0.005
# Pin:0.005
# noticeable:0.025
# Monotone:0.01
# cancer:0.02
# fitting:0.11
# lions:0.01
# Investigating:0.005
# LARS-TD:0.005
# Mosier:0.005
# Essential:0.01
# Roch:0.005
# Breakspear:0.005
# Unions:0.01
# Rti:0.005
# hard-coded:0.01
# xMAP:0.005
# Wherry:0.005
# price-setting:0.005
# CF:0.015
# uncensored:0.005
# deepest:0.02
# independenly:0.005
# LSR-L2:0.005
# to-rank:0.005
# krause:0.01
# coordinates2:0.005
# sought:0.02
# RN2:0.005
# erratic:0.01
# darkly:0.005
# EC:0.015
# LI:0.005
# occluding:0.005
# alone:0.085
# Lindsay:0.005
# unweighted-sum:0.005
# signifies:0.01
# micrograph:0.005
# reT:0.005
# Grossglauser:0.005
# FICA:0.005
# Invariance:0.01
# role:0.25
# isting:0.005
# proximalgradient:0.005
# integral:0.125
# Vk:0.035
# OER:0.005
# state-distribution:0.005
# used:0.975
# wmean:0.005
# minW:0.005
# tic:0.05
# nentially:0.005
# under-sampled:0.005
# Ratsch:0.005
# C3j:0.005
# Inequalities:0.005
# Frostig:0.005
# logics:0.005
# bivarim:0.005
# Pajarinen:0.005
# RoI:0.005
# rd:0.03
# sSVM:0.005
# four-component:0.005
# ekonomika:0.005
# unsuper:0.015
# ocean:0.01
# devia:0.01
# acknowledgements:0.15
# candidates:0.05
# temporarily:0.005
# basket:0.01
# IAF:0.005
# Directed:0.01
# alive:0.005
# ait1:0.005
# disadvantage:0.02
# inflated:0.005
# uncentered:0.01
# RKHS:0.045
# gorithm:0.07
# Displacement2D:0.005
# xTi:0.01
# actionable:0.01
# tripling:0.005
# Konstan:0.005
# Permutation:0.015
# coerced:0.005
# Hist:0.005
# EMD:0.005
# Foster:0.005
# complicate:0.005
# ec2:0.005
# invariants:0.005
# indistinguishability:0.01
# inversions:0.01
# Actually:0.005
# UMIST:0.005
# parameter-sharing:0.005
# cise:0.01
# violation:0.03
# Beta-Binomial:0.01
# JP26280086:0.005
# Cnb:0.005
# REDmc:0.005
# closest:0.095
# Splice:0.005
# discontinuities:0.015
# ti:0.09
# LF:0.01
# nu:0.025
# amenable:0.025
# Univariate:0.005
# attempt:0.145
# approximated:0.205
# universality:0.01
# inter-subject:0.005
# DAISY:0.005
# smith:0.005
# tile:0.01
# Sarkhel:0.005
# Insect:0.005
# Mathematics:0.02
# CCCP:0.01
# tialization:0.005
# burstiness:0.005
# Bonneel:0.005
# iY:0.005
# recorded:0.105
# boldface:0.02
# bY:0.005
# familiarized:0.005
# BLEU:0.005
# autism:0.005
# bolts:0.005
# docode:0.005
# abilistic:0.015
# wisc:0.005
# per-class:0.01
# distractor:0.005
# tization:0.005
# confusions:0.005
# leopard:0.005
# sketches:0.005
# XXT:0.01
# jagged:0.005
# kinds:0.1
# drawbacks:0.025
# ME:0.01
# spends:0.03
# bini:0.005
# Israel:0.01
# Adjusted:0.015
# WSA:0.005
# xq:0.01
# Previous:0.055
# partial-availability:0.005
# mDPs:0.005
# ed:0.02
# rameter:0.045
# Neurosci:0.005
# Michel:0.005
# requesting:0.01
# furniture:0.005
# xalt:0.005
# kUj:0.005
# superiority:0.045
# safely:0.01
# dataset7:0.005
# AVG-E:0.005
# tency:0.02
# RPN:0.005
# Alex:0.02
# Copyright:0.005
# Alzheimer:0.005
# actions1:0.005
# webspam:0.01
# chunking:0.01
# dif:0.15
# fresh:0.035
# enters:0.035
# DSFs:0.005
# super-clique:0.005
# data-science:0.005
# overly:0.045
# Bj:0.005
# e23:0.005
# internal:0.08
# DNA:0.045
# MSD:0.005
# instan:0.005
# Mismatch-SS:0.005
# dictate:0.03
# DeepMind:0.005
# transforms:0.095
# ematically:0.005
# Cor:0.01
# abstracted:0.01
# represented:0.4
# FACETS:0.005
# ke:0.015
# wont:0.01
# Obviously:0.015
# Sticky:0.005
# of3:0.005
# it:1.0
# eigenvalues:0.11
# forward-pass:0.005
# Kober:0.005
# Ynll:0.005
# mates:0.015
# princurve:0.005
# asymptotes:0.005
# restless:0.005
# kfD:0.005
# pertained:0.005
# algo10-2:0.005
# inar:0.005
# garbage:0.01
# yann:0.005
# readers:0.02
# commuting:0.005
# smoothed:0.095
# Larson:0.005
# challenges:0.095
# excess:0.04
# inal:0.01
# adpot:0.005
# Yacht:0.01
# octave:0.01
# profit1:0.005
# devised:0.03
# tle:0.005
# quantizers:0.01
# encourages:0.055
# debunks:0.005
# unlabelled:0.01
# sub-distributions:0.005
# OUTPUT:0.005
# permuting:0.01
# squares:0.095
# hernndez:0.005
# overlaid:0.02
# rescaling:0.065
# Bkt:0.005
# delicious:0.01
# hR:0.005
# petitive:0.005
# Abadi:0.005
# L2-transfer:0.005
# i01:0.01
# Inducing:0.005
# ppXti:0.005
# BCS-0941518:0.005
# occurs:0.17
# knoisy:0.005
# x55By:0.005
# tural:0.01
# classspecific:0.005
# resistant:0.005
# operator-splitting:0.005
# PCK:0.005
# demix:0.005
# variants:0.225
# market-Basket:0.005
# SCF-grid:0.005
# holdout:0.02
# offer:0.085
# ay:0.005
# Castro:0.005
# ADMM-RB:0.005
# visual-word:0.005
# pyramid:0.015
# perplex:0.01
# NP-hard:0.1
# fied:0.01
# audiology:0.005
# model-based:0.045
# counter-examples:0.005
# replicates:0.005
# domi:0.005
# supplied:0.005
# Binary:0.01
# Moon:0.005
# transferred:0.03
# dsf:0.005
# nats:0.005
# mans:0.005
# Hi:0.02
# ownership:0.01
# mellitus:0.005
# LiAP:0.005
# AR:0.025
# non-increasing:0.025
# diarization:0.005
# Controls:0.005
# online1:0.005
# tials:0.005
# Hoeffdings:0.02
# Friends:0.005
# Gamma:0.02
# Self-learning:0.005
# Pu:0.005
# mice:0.005
# Nkdj:0.005
# multinomial:0.075
# VEM:0.005
# non-differentiable:0.015
# Entner:0.005
# zontal:0.005
# Deterministic:0.01
# custom:0.005
# SgGen:0.005
# Akl:0.005
# sug:0.015
# Exploring:0.005
# extracting:0.11
# querying:0.015
# spuri:0.005
# t00nk1:0.005
# Bo:0.005
# Red:0.01
# SV:0.005
# structurally:0.015
# i204:0.005
# neurodegenerative:0.005
# EXPLORERS:0.005
# BCNM06:0.005
# k1:0.2
# pmf:0.01
# Zi2m:0.005
# vq:0.005
# Ul:0.005
# omission:0.015
# looser:0.01
# majority:0.12
# Kyung-Ah:0.005
# internal-context:0.005
# assumption:0.485
# neces:0.01
# deter:0.035
# dQdPd:0.005
# discarded:0.055
# locations:0.185
# subclasses:0.005
# violates:0.005
# displacements:0.01
# rejects:0.025
# SMOTE:0.005
# matching:0.2
# arriving:0.015
# Clemencon:0.005
# anisotropy:0.005
# Smoothness:0.005
# HX:0.005
# GPy:0.005
# Realization:0.005
# concatenating:0.04
# Ontology:0.005
# assignment:0.13
# dependes:0.005
# year:0.05
# persistently:0.005
# summary:0.135
# Tmax:0.005
# unfortunate:0.005
# interior:0.06
# discrimina:0.01
# sliding:0.02
# KL:0.165
# less-well:0.005
# JP26289320:0.005
# multi-instance:0.005
# mskcc:0.005
# marginalizations:0.005
# HSCA:0.005
# uiz:0.005
# verifying:0.03
# canonical:0.105
# label-totag:0.005
# dAspremont:0.01
# JHK:0.005
# oth:0.005
# goodness-of:0.005
# kxk:0.055
# Photoshop:0.005
# inflate:0.005
# ResNet50:0.005
# AC:0.02
# cuttingPlane:0.005
# hallway2:0.005
# il:0.02
# Digit:0.015
# plugged:0.015
# LMNNKPCA:0.005
# Whitening:0.01
# violated:0.055
# Pcurve:0.005
# tends:0.145
# mapper:0.005
# friend:0.005
# BRS16:0.005
# chances:0.01
# offerings:0.005
# exploratory:0.03
# circuitry:0.005
# one-vsall:0.005
# groundtruth:0.035
# loo:0.005
# Pictu:0.005
# arms:0.03
# non-faithful:0.005
# webpage:0.015
# mere:0.01
# rLn:0.005
# Kgg:0.005
# inaccurate:0.055
# trades:0.025
# hamerly:0.005
# memorize:0.005
# reconcile:0.005
# exif:0.005
# requests:0.015
# actly:0.01
# tributions:0.025
# tech:0.03
# pk:0.05
# Gaus2:0.005
# casino:0.005
# Params:0.005
# modela:0.005
# Sherman-Morrison:0.01
# mantic:0.005
# unpooling:0.005
# traditionally:0.04
# SADMM:0.01
# denote:0.685
# Few-Shot:0.01
# bringing:0.025
# yg:0.01
# Yt1:0.01
# Newman:0.01
# Exemplar:0.005
# Votes:0.005
# rM:0.005
# fea:0.11
# Seifert:0.005
# trans-NIH:0.005
# config:0.01
# subtypes:0.01
# moot:0.005
# LM:0.01
# under-rate:0.005
# Ten:0.005
# engineering:0.04
# Spread:0.005
# Lugosi:0.02
# Points:0.02
# validating:0.03
# iPOMCPs:0.005
# minxRm:0.005
# OATMIL:0.005
# crop:0.02
# authors:0.415
# IFF01:0.005
# whitening:0.025
# non-equilibrium:0.01
# topic-dependent:0.005
# kA2:0.005
# sUP:0.005
# Coulomb:0.005
# complex-cell:0.005
# Hours:0.005
# two-stream:0.005
# Rp:0.065
# drawing:0.05
# MKMs:0.005
# decider:0.005
# there:0.9
# illustrate:0.225
# climb:0.01
# appendices:0.01
# FD:0.005
# kB:0.01
# anarchy:0.005
# agement:0.005
# letdown:0.005
# intuitive:0.115
# dmax:0.005
# quadrics:0.005
# verification:0.01
# Newsgroup:0.005
# EK:0.01
# discretising:0.005
# Hilbertian:0.01
# senti:0.015
# habitat:0.005
# abilties:0.005
# lowerorder:0.005
# concept:0.15
# bare:0.005
# R1d:0.005
# ball-park:0.005
# ascertain:0.005
# budget:0.06
# Public:0.01
# equilibria:0.02
# full-width:0.005
# Pmin:0.01
# multi-period:0.005
# self-consistency:0.005
# AAH:0.005
# OF97:0.005
# clustering:0.205
# Perez-Quiros:0.005
# EM-inspired:0.005
# trainign:0.005
# Conceptually:0.005
# translation:0.095
# fwd:0.005
# qdXtk:0.005
# Huber-loss:0.005
# VISDEM:0.005
# instance-level:0.005
# analytic:0.08
# retail:0.01
# below-chance:0.005
# incurring:0.015
# center-cropped:0.005
# Garca-Garca:0.005
# Davis-Kahan:0.005
# in-house:0.01
# ending:0.03
# functionsthat:0.005
# Composition:0.005
# Desiderata:0.005
# Hasler:0.005
# specializing:0.005
# Autoencoders:0.005
# dient:0.045
# radiator:0.005
# AN:0.005
# hill:0.005
# hur:0.005
# pt:0.035
# rtask:0.005
# bounds5:0.005
# bike:0.015
# to-1:0.005
# push-forward:0.005
# posterior:0.25
# traction:0.01
# outer-product:0.005
# pocampal:0.005
# unnoticed:0.005
# Trading:0.005
# CMRA:0.005
# monosynaptically:0.005
# Graphs:0.005
# preWe:0.005
# Image:0.075
# pCA:0.01
# fastTag:0.005
# Hyperlipidemia:0.005
# bi:0.135
# coherently:0.005
# timestamped:0.005
# plex:0.025
# expressions:0.085
# hotdog:0.005
# t0:0.095
# Peq:0.005
# kkr:0.005
# languages:0.02
# kLS:0.005
# ecacy:0.005
# longer-timescale:0.005
# IOTRBM:0.005
# chromatin:0.005
# Mp:0.005
# regret:0.06
# Axka:0.005
# parallelize:0.035
# Wald:0.005
# GM:0.005
# anatomically:0.005
# Pre-miRNA:0.005
# HadfieldMenell:0.005
# pre-whitening:0.005
# smoothing:0.075
# Key-value:0.005
# resets:0.005
# AAL:0.005
# score-space:0.005
# puzzling:0.01
# RKKS:0.005
# rank-decient:0.005
# course-to:0.005
# AL:0.005
# Xqi:0.005
# non-existent:0.005
# lTCI:0.005
# operatorthat:0.005
# untractable:0.005
# MRA1:0.005
# self-supervised:0.005
# resenting:0.01
# make:0.69
# Zb:0.01
# normalizable:0.005
# Maximum:0.035
# distri:0.155
# premise:0.005
# GW:0.005
# NSLGRB:0.005
# OCR:0.005
# hierarchical:0.13
# neurodegeneration:0.005
# clipped:0.01
# terestingly:0.005
# reversal:0.01
# AGMS12:0.005
# lems:0.06
# L2:0.165
# correctness:0.045
# maxe:0.005
# genuine:0.01
# IQ:0.005
# WLOG:0.005
# DBN:0.03
# pursuit:0.015
# Yurii:0.005
# undone:0.005
# orremainder:0.005
# Whether:0.005
# knew:0.02
# rows:0.225
# ama:0.005
# egy:0.015
# Regularized:0.04
# accesses:0.005
# remedy:0.03
# low-dimensional:0.125
# struggles:0.015
# Foerster:0.005
# influences:0.03
# single-node:0.005
# sub-objective:0.005
# specification:0.055
# DSF:0.005
# concomittently:0.005
# R2:0.09
# dl2:0.005
# Planted:0.005
# dNNs:0.005
# Nodes:0.005
# Zhouchen:0.005
# equalized:0.005
# martingale:0.02
# Midas:0.005
# Zero-Phase:0.005
# AU24:0.005
# Watanabe:0.005
# DER:0.005
# econometrics:0.015
# Fast:0.025
# CMAC:0.005
# pal:0.005
# Model-Parallelism:0.005
# Bj1:0.005
# uk2:0.005
# inverses:0.005
# between:0.955
# cR:0.005
# Hardness:0.015
# theoretically:0.14
# December:0.01
# semi:0.065
# logged:0.005
# Conv4:0.005
# conne:0.005
# HPYM:0.005
# Ball-in:0.005
# Baum-Welch:0.01
# persistence:0.01
# indisputably:0.005
# Physics-Based:0.005
# regulatory:0.02
# dbTSS:0.005
# IIS-0916038:0.005
# doubles:0.01
# factorise:0.01
# define:0.685
# Vos:0.005
# parents:0.03
# Equations:0.035
# tern:0.015
# karna:0.005
# FG:0.005
# triangular:0.03
# annotator:0.01
# differentiate:0.04
# wi:0.14
# contribute:0.085
# metrics:0.105
# shift-invariant:0.005
# tagged:0.01
# down-side:0.005
# location:0.18
# showp:0.005
# x8:0.01
# robustifying:0.005
# plotting:0.015
# Psittacosis:0.005
# sound:0.035
# profor:0.005
# P3n500r20:0.005
# man-made:0.01
# fi:0.12
# Multi-class:0.005
# tuples:0.035
# Cross-Entropy:0.005
# eigenmapsare:0.005
# Josep:0.005
# Invariant:0.035
# inherits:0.01
# ...
# eating:0.01
# re-scaled:0.005
# Yi:0.075
# swing-up:0.015
# Formulas:0.005
# procedure8:0.005
# Eban:0.005
# metadata:0.005
# tted:0.005
# Inner:0.01
# Pn1:0.01
# NLP:0.01
# azurewebsites:0.005
# frames:0.085
# imageperfor:0.005
# cleaner:0.015
# right-translation:0.005
# TopCand:0.005
# EY019965:0.005
# acid:0.005
# re-prove:0.005
# trsf:0.005
# intermediate:0.125
# associating:0.015
# Curve:0.01
# eakmeans:0.005
# handwritten:0.04
# decoder:0.02
# Thresholding:0.005
# y1k:0.005
# Number:0.13
# TSLiNGAM:0.005
# bag-of:0.03
# Engli:0.005
# laboratory:0.01
# masked:0.02
# uct:0.015
# globally:0.06
# CKN-CO:0.005
# agonal:0.005
# ADEMACHER:0.005
# produc:0.005
# DingDubchak:0.005
# Microstructure:0.005
# decorative:0.005
# interchangeable:0.01
# Feet:0.005
# AJWT:0.005
# unwanted:0.005
# mathematical:0.075
# dundant:0.005
# ied:0.01
# HK:0.005
# peculiar:0.01
# actor:0.04
# Yersinia:0.005
# nSLGRB:0.005
# generalising:0.01
# condition:0.35
# SAG-ADMM:0.005
# yD:0.005
# eralize:0.01
# HDP-HMM:0.005
# iz:0.01
# Andrew:0.005
# Bij:0.005
# pre-registered:0.005
# between-hemisphere:0.005
# non-empirical:0.005
# personalized:0.025
# Multiresolution:0.005
# cellular:0.01
# FWO:0.005
# docu:0.01
# Rutgers:0.005
# Ribeiro:0.005
# interleavings:0.005
# teractions:0.02
# Joachims:0.005
# regions:0.22
# terpipe:0.005
# Barcelona:0.165
# Examination:0.005
# self-modularize:0.005
# Associating:0.005
# blogging:0.005
# pivotal:0.015
# tth:0.02
# Discovery:0.02
# NUTS:0.005
# Herzliya:0.005
# Electric:0.01
# MNIST:0.14
# lagged:0.01
# worthwhile:0.02
# popula:0.005
# lattice:0.025
# Critically:0.005
# appears:0.23
# ni:0.115
# legends:0.005
# Initialization:0.03
# Witwicki:0.005
# procedural:0.005
# typifies:0.005
# PnP:0.005
# lutive:0.005
# mD:0.005
# sE-MPP:0.005
# representativeness:0.005
# top-to:0.005
# initiate:0.01
# criterion:0.205
# Ncuts:0.005
# kernelized:0.02
# adaptively:0.07
# Parrotate:0.005
# XinHua:0.005
# prj:0.005
# signalin:0.005
# tiMINo-linear:0.005
# maxAV:0.005
# energy-consumption:0.005
# any:0.925
# deletion:0.015
# Detect:0.005
# LiveJournal:0.005
# adjusted:0.03
# iological:0.005
# Hakimi:0.005
# integrated:0.07
# mini-batch:0.075
# Re-compute:0.005
# re-parameterized:0.01
# Cii:0.005
# CDL:0.005
# positing:0.01
# scarce:0.02
# cubically:0.005
# clinical:0.035
# exemplifies:0.005
# PC15:0.005
# Berlin:0.01
# heights:0.005
# stochastic:0.425
# L3:0.02
# auctioneer:0.005
# gets:0.195
# Statistician:0.005
# M4:0.015
# milk:0.01
# dual:0.18
# LMS:0.005
# LUi:0.005
# Appendix:0.175
# aj1:0.005
# timing:0.045
# Peg-In:0.005
# setr:0.005
# Bayer:0.005
# RPCCA:0.005
# mentally:0.005
# Heckerman:0.005
# array:0.04
# observability:0.005
# po:0.02
# triage:0.01
# behavioral:0.045
# requirement:0.13
# ha:0.005
# shipped:0.005
# stimulus-part:0.005
# polarities:0.01
# no-mixture:0.005
# Topic6:0.005
# Xl:0.005
# Nothing:0.005
# unilaterally:0.01
# trieval:0.01
# Xil:0.005
# pv:0.01
# friendships:0.005
# pT0:0.01
# commonly-used:0.01
# oblivious:0.015
# drop:0.095
# Learning-curve:0.005
# rank-50:0.005
# unprecedented:0.015
# sse:0.005
# weakly:0.06
# E1:0.03
# flow:0.09
# sawtooth:0.005
# Housing:0.015
# initializationthere:0.005
# readibility:0.005
# articles:0.045
# hypersurface:0.005
# kernela:0.005
# christian:0.005
# Biol:0.005
# jam:0.005
# never:0.17
# kxk2n:0.005
# horizontally-mirrored:0.005
# anal:0.045
# AFOSR:0.02
# celebi:0.005
# xz:0.005
# abstract:0.08
# OMP:0.01
# simplified:0.09
# badges:0.005
# kx00:0.005
# ones:0.355
# Optimistic:0.01
# example1:0.005
# convergence:0.44
# specify:0.13
# GIICA-4:0.005
# timation:0.005
# racing:0.01
# disjunctive:0.01
# Yarsinia:0.005
# hypersphere:0.02
# wider:0.055
# modifies:0.005
# sketched:0.02
# dub:0.01
# rst-order:0.005
# Real-world:0.015
# xK:0.045
# riot:0.005
# excite:0.005
# sparse:0.355
# gams:0.005
# presumably:0.025
# cornell:0.005
# Accenture:0.01
# coincidentally:0.005
# spanning:0.035
# Sn1:0.01
# Maximize:0.005
# wrapper:0.01
# theses:0.005
# sanitized:0.005
# pilot:0.01
# Tk:0.025
# injects:0.005
# Score:0.02
# Homogeneity:0.005
# myopic:0.02
# Physics:0.01
# Hu:0.005
# adds:0.09
# Northwest:0.005
# involving:0.145
# scope:0.055
# wildcard:0.005
# defines:0.255
# APL:0.005
# Reproducing:0.005
# sition:0.035
# BLAST:0.005
# Time:0.135
# privacy:0.02
# Optimality:0.01
# STWF:0.005
# Simple:0.02
# success-weighted:0.005
# wonderful:0.005
# fectiveness:0.01
# connectedness:0.005
# reconP:0.005
# Ours-RN:0.005
# GRB:0.005
# top-1:0.005
# arrivals:0.005
# shaping:0.005
# reporter:0.005
# Diffusion:0.02
# corollaries:0.02
# wed:0.005
# positives:0.05
# optimisation:0.035
# radiators:0.005
# mohammad:0.005
# black-box:0.06
# Arizona:0.005
# shortening:0.005
# dwitten:0.005
# smax:0.005
# captur:0.005
# ROC:0.04
# portends:0.005
# Goldberg:0.01
# precluding:0.005
# setting:0.77
# GB:0.065
# Lcycle:0.005
# always:0.49
# grass:0.01
# Subsequently:0.005
# bottom-right:0.01
# EMER-002:0.005
# cannon:0.005
# rt:0.065
# scoring:0.06
# xnj:0.005
# scop:0.005
# maxkGj:0.005
# exponentiation:0.01
# Lovell:0.005
# magni:0.01
# proactive:0.005
# locomotion:0.005
# Objectives:0.005
# ModelShape:0.005
# finiteSince:0.005
# mini-ImageNet:0.005
# ers:0.045
# tmt:0.005
# tain:0.03
# Scheduling:0.005
# kk22:0.02
# incoherence:0.025
# volumic:0.005
# Office:0.055
# MKL:0.01
# Spectrum:0.01
# mV2:0.005
# Differential:0.015
# GGMs:0.005
# Mh:0.005
# Drineas:0.005
# collective:0.025
# ry:0.005
# www:0.13
# prioritizing:0.005
# indicate:0.21
# TEST:0.005
# rn1:0.005
# Non-ergodic:0.005
# pre-structured:0.005
# two-parameter:0.005
# imately:0.02
# thr:0.005
# macro-goal:0.005
# cubes:0.01
# sitys:0.005
# Xn:0.07
# italy:0.005
# kDk2F:0.005
# Geodesic:0.005
# non-intersecting:0.005
# dS:0.01
# dependent:0.205
# Cf:0.005
# beta:0.03
# incentivizes:0.005
# favoring:0.01
# today:0.015
# Australian:0.005
# linearly:0.175
# Likewise:0.005
# RSC:0.005
# gramming:0.01
# ReLU:0.08
# prompting:0.005
# Manufacturers:0.005
# dur:0.005
# Thus:0.15
# Structured:0.03
# inserting:0.01
# utilization:0.015
# o0:0.005
# tailsum:0.005
# muscle:0.005
# ez:0.005
# illustrative:0.035
# donoho:0.005
# detectionthis:0.005
# advancements:0.005
# CFZ:0.005
# tence:0.01
# nET:0.005
# CD-k:0.005
# milder:0.015
# Qsym:0.005
# cues:0.02
# approx:0.105
# region:0.31
# rel:0.06
# Thirdly:0.005
# orem:0.025
# Margin-Dependent:0.005
# readout:0.005
# observables:0.01
# kX:0.035
# hHA:0.005
# reflective:0.005
# iv:0.05
# Misclassification:0.005
# collections:0.02
# agile:0.005
# comparing:0.275
# sensorin:0.005
# exchangeability:0.01
# misspecifica:0.005
# peculiarity:0.005
# mnist-original:0.005
# third:0.315
# ff:0.005
# sheep:0.015
# self-occlusions:0.005
# homeomorphic:0.005
# sensor:0.085
# feature-by:0.005
# Relative:0.05
# privatization:0.005
# DEAD:0.005
# pY:0.01
# perceptron-like:0.005
# discounted-reward:0.005
# observation-alphabet:0.005
# maxpY:0.005
# Dbk1:0.005
# nemenman:0.005
# superimpose:0.005
# sensitively:0.005
# specifi:0.02
# ond:0.03
# aware:0.07
# vec:0.055
# Good:0.005
# Continuation:0.005
# micro-action:0.005
# Gain:0.005
# Segmentation:0.035
# analyzed:0.145
# Differences:0.01
# resistance:0.005
# kfL:0.005
# succesfully:0.005
# Greedy:0.04
# enlarges:0.005
# TPCMC:0.005
# pkq:0.015
# Geometric:0.02
# analytically:0.13
# competitively:0.02
# state-Based:0.005
# informed:0.03
# dut1:0.005
# Ioffe:0.005
# Dpuddle-world:0.005
# Gardiner:0.005
# idiosyncrasies:0.005
# resemblance:0.005
# investigation:0.075
# scanner:0.015
# transfered:0.005
# Lp:0.03
# impact:0.11
# rh:0.005
# TF:0.01
# description:0.18
# diminish:0.005
# xTt:0.01
# EMalgorithm:0.005
# enable:0.09
# rightA:0.005
# stems:0.025
# forcontrast:0.005
# Remark:0.065
# xTn:0.005
# benefit:0.22
# applies:0.175
# normalisation:0.015
# submit:0.005
# Frobenius:0.1
# flavours:0.005
# ad-hoc:0.03
# Lumping:0.005
# specialised:0.01
# MQ:0.005
# areP:0.005
# regulate:0.005
# nential:0.02
# Meanshift:0.005
# Seiberg:0.005
# generalizable:0.01
# LINE:0.005
# antonyms:0.005
# quences:0.025
# hyper-parameter:0.03
# constant-smooth:0.005
# bj:0.04
# largescale:0.015
# Cyber:0.005
# ligence:0.005
# Experimentally:0.005
# Naive:0.02
# Covariance:0.02
# splines:0.01
# Regress:0.005
# VvT:0.005
# semisynth:0.005
# long:0.425
# Selective:0.005
# Objective:0.04
# borrow:0.015
# IRD:0.005
# supervisory:0.005
# word-of:0.005
# gPU:0.005
# Ybi:0.005
# Mann-Whitney:0.005
# Nm:0.01
# AZ:0.01
# well-behaved:0.005
# decision-theory:0.005
# AUTON:0.005
# zK:0.005
# appreciated:0.01
# am:0.035
# manifolds:0.05
# num:0.095
# accuracy-conditional:0.005
# BFGS-B:0.005
# ADC:0.005
# required:0.44
# ucts:0.005
# arXn:0.005
# pix:0.005
# investor:0.005
# macrogoal:0.005
# wide-field:0.005
# shufnal:0.005
# they:0.905
# ensuring:0.1
# Newsgroup1:0.005
# Shuﬄed:0.005
# Ray:0.01
# unitary:0.02
# chamber:0.01
# Gj:0.02
# reaffirmed:0.005
# gbn:0.005
# subclass:0.015
# sk:0.065
# hC:0.005
# cancels:0.005
# backpropagation:0.045
# XS:0.025
# H1:0.055
# Rouault:0.005
# cost-effective:0.01
# ILSVRC:0.005
# P100:0.005
# vv:0.02
# versatility:0.015
# highresolu:0.005
# unimodal:0.01
# x22:0.005
# archetypal:0.005
# L1:0.105
# sinusoid:0.005
# Bickel:0.005
# Which:0.005
# Berkeley:0.015
# celestial:0.005
# tagger:0.005
# action-space:0.005
# W4:0.015
# equa:0.015
# obeying:0.02
# Plot:0.015
# Transfer:0.015
# cycled:0.005
# variation:0.145
# v11:0.01
# datasets:0.49
# birth:0.005
# reversible-jump:0.005
# countably-infinite:0.005
# Joo:0.005
# x228:0.005
# Mouse:0.005
# PTn:0.005
# Xib1:0.005
# XIk:0.005
# y4:0.005
# Jqr:0.005
# automate:0.01
# mkl:0.005
# fxj:0.005
# bach:0.01
# quentially:0.005
# mbike:0.005
# concatenation:0.04
# Round:0.005
# Hyperlink:0.005
# NIMH:0.005
# sulting:0.015
# onsets:0.005
# self-training:0.01
# Self:0.01
# funding:0.05
# paddle:0.005
# presumption:0.005
# RVML:0.005
# Vuk22:0.005
# delete-merge:0.005
# an:1.0
# UPC:0.005
# deeply:0.01
# tie:0.01
# wzz0:0.005
# topi:0.005
# accomodate:0.005
# cuitry:0.005
# binatorial:0.005
# Mass:0.005
# maxsS:0.005
# soon:0.06
# robotic:0.02
# non-adaptive:0.01
# matters:0.035
# kAb:0.005
# amplier:0.005
# Mammalian:0.005
# Chain-structured:0.005
# Labeled:0.015
# A0kj:0.005
# Palm:0.005
# repository1:0.005
# pendu:0.005
# bTSb:0.005
# filtering:0.11
# thou:0.005
# forcing:0.065
# profit:0.03
# amacrine:0.005
# Nte:0.01
# Notice:0.06
# resource:0.01
# fruit:0.005
# unm:0.005
# cN:0.01
# Predictor:0.005
# compressions:0.005
# q9ij:0.005
# cjlin:0.025
# cos:0.065
# Bingsheng:0.005
# MTi:0.005
# kept7:0.005
# adheres:0.01
# Vector:0.075
# THE:0.005
# trade25:0.005
# paying:0.01
# sufficiently:0.315
# practical:0.34
# wiK:0.005
# stanta:0.005
# fpr:0.005
# sliding-window:0.005
# disagreeing:0.005
# culates:0.005
# mine:0.03
# hyperparmeters:0.005
# https:0.115
# SONGS:0.005
# stimuli:0.035
# elicitation:0.005
# psychoacoustics:0.005
# recapitulate:0.005
# xti:0.01
# resistors:0.005
# factorizations:0.01
# data-submanifold:0.005
# meanwhile:0.06
# rewrite:0.085
# academic:0.01
# List:0.01
# clasof:0.005
# c4:0.025
# mensions:0.01
# protsubloc:0.01
# all-ones:0.005
# Karpathy:0.005
# provided:0.565
# Refer:0.005
# Op:0.02
# sub-location:0.005
# know:0.295
# documents:0.055
# shogun-toolbox:0.005
# kPd:0.005
# ily:0.015
# infers:0.025
# intrigued:0.005
# accumulators:0.005
# RichardsonRomberg:0.005
# adopters:0.01
# nc2:0.01
# undecided:0.005
# sphere-constrained:0.005
# yCn:0.005
# tagsets:0.005
# periodic:0.02
# LL:0.025
# kgkL2:0.005
# neg:0.015
# Technologies:0.005
# accrue:0.005
# putation:0.015
# GBA:0.005
# Emission:0.005
# forgetting:0.03
# context-free:0.005
# verses:0.005
# OCO:0.01
# Aenon:0.005
# FESS-MF:0.005
# FDG:0.005
# pyrimidines:0.005
# geograph:0.005
# Bayes-Bayes:0.005
# denoiser:0.005
# re-parameterization:0.005
# Muirhead:0.005
# every:0.585
# hln:0.005
# Feature-wise:0.005
# alidation:0.005
# pkj:0.01
# Intramural:0.005
# strated:0.005
# wzj:0.005
# Motivation:0.02
# continuum:0.015
# Crooks:0.005
# ARLY:0.005
# FAST:0.005
# continuous-space:0.005
# conceptualized:0.005
# Stratification:0.005
# etitions:0.005
# kzk0:0.005
# Iterate:0.005
# singularities:0.005
# striatum:0.005
# introduces:0.12
# finding:0.41
# Smooth:0.025
# pected:0.015
# ficulty:0.01
# pletely:0.01
# ical:0.075
# W1:0.04
# finances:0.005
# IFMOC:0.005
# lends:0.015
# fulness:0.005
# Dehydration:0.005
# agrees:0.02
# london:0.005
# Ll:0.01
# separa5:0.005
# jelly:0.005
# Heaviness:0.005
# ination:0.005
# Varma:0.005
# keyboard:0.005
# locally-weighted:0.005
# on-line:0.02
# medium-sized:0.005
# havepanels:0.005
# olding:0.005
# Attention:0.02
# Purity-coverage:0.005
# Pexp:0.005
# Algorithm:0.435
# un-normalized:0.02
# colouring:0.005
# NE:0.01
# nCA:0.005
# Net:0.03
# termediaries:0.005
# politics:0.02
# plemental:0.005
# ti11:0.005
# kED-KCCA:0.005
# synthetically:0.02
# tabu:0.005
# ecti:0.005
# April:0.01
# simultaneous:0.055
# Schulman:0.01
# methodswith:0.005
# headlights:0.005
# theo:0.015
# probabilistically:0.02
# RIA:0.005
# HoG:0.005
# consistent:0.325
# formulations:0.08
# audibly:0.005
# subchains:0.005
# Page:0.005
# keeps:0.055
# non-probabilistic:0.005
# Schmeidler:0.005
# Passing:0.005
# intuition:0.185
# resource-consuming:0.005
# subtle:0.03
# classically:0.005
# COLT:0.005
# YahooLDA:0.005
# ghosh:0.005
# SMIDAS:0.005
# whenever:0.155
# trails:0.005
# Newtons:0.02
# channelsa:0.005
# already:0.33
# vote:0.025
# non-linearly:0.015
# Statistics:0.025
# Corrected:0.005
# nucleus:0.005
# HCP:0.005
# improves:0.23
# s3:0.005
# categorized:0.03
# MasCollel:0.005
# eE:0.02
# Initial:0.03
# Higher:0.005
# inapproximable:0.005
# time1:0.005
# riding:0.015
# actve:0.005
# counterexample:0.005
# expqk:0.005
# PROTEIN:0.005
# reds:0.005
# fv:0.015
# tensor:0.045
# Equal:0.01
# cisions:0.01
# forestfire:0.005
# objec:0.035
# Mechanical:0.005
# immediate-threshold:0.005
# established:0.175
# OR-Library:0.005
# automatZ:0.005
# individual-level:0.01
# triplet:0.015
# gapped:0.005
# minwKIP:0.005
# vibrate:0.005
# Cramer-Rao:0.005
# pfull:0.005
# suppressing:0.01
# neurons:0.105
# PS:0.035
# Segments:0.01
# hKmi:0.005
# suinlee:0.005
# transformation:0.205
# availabity:0.005
# FNR:0.005
# orative:0.005
# Ajki:0.005
# similarity-based:0.015
# influence:0.155
# Vafa:0.005
# outlinks:0.005
# Integration:0.005
# wiped:0.005
# minf:0.005
# view-based:0.005
# Eric:0.005
# permutes:0.005
# optimized:0.19
# qkp:0.005
# courage:0.005
# optimization-based:0.01
# gal:0.01
# exponential:0.28
# mrc-lmb:0.005
# forwards:0.005
# sales:0.02
# body:0.11
# Hotelling:0.005
# averse:0.01
# Formalism:0.005
# bounding:0.175
# Regret2:0.005
# Strongly:0.01
# Ahead:0.005
# signifmeasuring:0.005
# Multi-Step:0.005
# look:0.195
# success:0.16
# frequent:0.045
# summarization:0.03
# multiclass-based:0.005
# modelled:0.035
# Karl:0.01
# thereon:0.01
# superadditive:0.005
# pretty:0.01
# user-job:0.005
# tens:0.05
# Understanding:0.005
# Gct:0.005
# hlog:0.005
# Supreeth:0.005
# removed:0.115
# motions:0.025
# ppXtk:0.005
# Decision:0.05
# hazard:0.005
# shot:0.01
# Changxi:0.005
# Correspond:0.005
# entail:0.02
# Adam:0.04
# video:0.12
# outperforming:0.035
# argu:0.015
# monitor:0.02
# nes:0.005
# emt:0.005
# november:0.005
# lows:0.035
# Automatic:0.015
# basics:0.005
# inexactly:0.005
# quicker:0.005
# ARE:0.005
# relevance:0.065
# heavier:0.005
# mean-square:0.005
# Another:0.05
# transactions:0.01
# gating:0.015
# d2i:0.005
# COs:0.005
# overestimated:0.005
# to:1.0
# Jiseob:0.005
# fk:0.045
# channelsthat:0.005
# bck:0.005
# visualizing:0.01
# KEGG:0.005
# Mode-IMM:0.005
# Rossler-x:0.005
# Department:0.04
# right-bottom:0.005
# Mean-IMM:0.005
# Wolfe:0.01
# a9aa9a-group:0.005
# surpass:0.005
# pre-training:0.02
# Pf:0.005
# CSF:0.01
# negating:0.005
# financial:0.05
# developes:0.005
# layout:0.025
# Ball-in31:0.005
# Sharma:0.005
# mhw:0.005
# chung:0.005
# warning:0.01
# khk2:0.005
# realness:0.005
# ignorant:0.005
# concretely:0.04
# Blum:0.005
# inter:0.085
# cucina:0.005
# jt:0.01
# scores:0.21
# Lazy:0.01
# overfits:0.025
# Continuous-time:0.01
# Grid:0.005
# dimension:0.38
# convolve:0.005
# laid:0.01
# spindle:0.005
# Coordinate:0.015
# FC:0.015
# range:0.455
# Saemundsson:0.005
# lava-free:0.005
# T8:0.005
# donut:0.005
# hm:0.02
# Wg:0.005
# ddimensional:0.005
# vocab:0.005
# sensible:0.04
# Real-World:0.01
# agated:0.005
# CQ0:0.005
# Parameterization:0.005
# pepper:0.01
# Gustafson:0.005
# operating:0.025
# situations:0.12
# Leibo:0.005
# very:0.8
# kvj:0.005
# island:0.01
# Cun:0.005
# relied:0.025
# Vt2:0.005
# Joint:0.015
# Our:0.475
# plexities:0.005
# lives:0.01
# underpinned:0.005
# primates:0.005
# dation:0.03
# Dependency:0.01
# up-to:0.005
# cost-sensitive:0.02
# Nb:0.01
# distinctive:0.02
# integers:0.04
# Transport:0.01
# fordirection:0.005
# acyclicity:0.01
# inaddition:0.005
# seemed:0.02
# Ridge-coding:0.005
# olded:0.005
# disjunction:0.005
# glioblastoma:0.005
# fold:0.135
# XTGgood:0.005
# kxwk2:0.005
# fz:0.01
# pos:0.1
# p0:0.065
# Bicriterion:0.005
# Jkp:0.005
# plat:0.005
# HICO:0.005
# STD:0.015
# Memisevic:0.01
# Reg:0.005
# FastICA:0.01
# Lkx:0.005
# worldclass:0.005
# proceedings:0.005
# remem:0.005
# imisation:0.005
# rectan:0.005
# VC-dim:0.005
# uncontid:0.005
# Realistic:0.005
# fantastic:0.005
# View:0.01
# Spike:0.015
# base-paired:0.005
# R2J:0.005
# HkX:0.005
# HOI:0.005
# coupled:0.065
# GPUs:0.025
# combinations:0.165
# Deflate:0.005
# cS:0.005
# ingenuity:0.005
# weakens:0.005
# switched:0.005
# GParML:0.005
# acetylglucosaminyl-phosphatidylinositol:0.005
# HRT:0.005
# annular:0.005
# Hiero:0.005
# duong:0.005
# complement:0.04
# retracted:0.005
# somaden:0.005
# arccos1:0.005
# by10K:0.005
# drastically:0.065
# snt:0.005
# undercomplete:0.005
# Badanidiyuru:0.005
# statis:0.03
# notions:0.03
# equivaProof:0.005
# interest:0.405
# Trains:0.01
# run-time:0.02
# member:0.05
# graph-cut:0.005
# URL3:0.005
# There:0.155
# Zhong:0.005
# NRCL:0.005
# Rosn:0.005
# postech:0.005
# Edge:0.015
# ED:0.005
# feeds:0.01
# didnt:0.005
# Binomial:0.005
# Benson:0.005
# evidently:0.005
# Key:0.015
# Sxi:0.005
# covertype-original:0.005
# Accordingly:0.005
# S2L:0.005
# qK:0.01
# Xvt:0.005
# non-dynamic:0.005
# mated:0.01
# Pk1:0.025
# sTu:0.005
# Per-class:0.005
# logits:0.005
# spaced:0.035
# classified:0.12

# %% [markdown]
# The next two part is not necessary, just for saving time when I restart this code.

# %%
##save Rare tokens (with the threshold set to 3%) and context-dependent (with the threshold set to %95)
with open('unsatisfactory_words.txt','w+',encoding='UTF-8') as unsatisfactory_words:
    for i in words:
        unsatisfactory_words.write(i+'\n')

# %%
##read stop word file
with open('unsatisfactory_words.txt') as unsatisfactory_words:
    unsatisfactory_words = unsatisfactory_words.read()
unsatisfactory_words_list = re.split('\n', unsatisfactory_words)

clean_tokens = [w for w in colloc_voc if w not in unsatisfactory_words_list]## same as remove stopwords part
clean_tokens.sort()

# %% [markdown]
# Unigram tokens should be stemmed using the Porter stemmer. [PorterStemmer](https://pythonprogramming.net/stemming-nltk-tutorial/) is useful to acheive this task.

# %%
##Store all the token which contains upper case(because PorterStemmer performs lower casing by default)
upper_token = []
for word in clean_tokens:
    for i in range(len(word)):
        if word[i].isupper() == True:##use .isupper() function to get the upper case
            upper_token.append(word)

##Porter stemmer           
porter_stemmer = PorterStemmer()
stemmed_token = []
for i in range(len(clean_tokens)):
    stemmed_token.append(porter_stemmer.stem(clean_tokens[i]))

stemmed_token.extend(upper_token)##get back upper case.
stemmed_token.sort() ##sort in alphabetical ascending order.
stemmed_token
# Out:
# ['A0',
#  'A0',
#  'A1',
#  'A1',
#  'A2',
#  'A2',
#  'A3',
#  'A3',
#  'ADMM',
#  'ADMM',
#  'ADMM',
#  'ADMM',
#  'ANR',
#  'ANR',
#  'ANR',
#  'AP',
#  'AP',
#  'AP',
#  'AT',
#  'AT',
#  'AT',
#  'AUC',
#  'AUC',
#  'AUC',
#  'Accuracy',
#  'Acknowledgements',
#  'Acknowledgments',
#  'Ada_Newton',
#  'Ada_Newton',
#  'Adam',
#  'Adaptive',
#  'Additionally',
#  'Advanced',
#  'Adversarial',
#  'After',
#  'Agency',
#  'Ai',
#  'Ai',
#  'Air',
#  'Ak',
#  'Ak',
#  'Alg',
#  'Algorithm',
#  'Algorithms',
#  'All',
#  'Also',
#  'Although',
#  'Amazon',
#  'An',
#  'An',
#  'Analysis',
#  'And',
#  'Another',
#  'Any',
#  'Ap',
#  'Ap',
#  'Appendix',
#  'Application',
#  'Applications',
#  'Apply',
#  'Approach',
#  'Approximate',
#  'Approximation',
#  'Architecture',
#  'Arora',
#  'As',
#  'As',
#  'Assume',
#  'Assumption',
#  'Assumptions',
#  'At',
#  'At',
#  'Average',
#  'Avg',
#  'Award',
#  'Ax',
#  'Ax',
#  'B1',
#  'B1',
#  'BFGS',
#  'BFGS',
#  'BFGS',
#  'BFGS',
#  'Bach',
#  'Background',
#  'Based',
#  'Basic',
#  'Bayes',
#  'Bayes_classifier',
#  'Bayesian',
#  'Beach',
#  'Because',
#  'Before',
#  'Bellman',
#  'Bellman_error',
#  'Bengio',
#  'Bernoulli',
#  'Best',
#  'Bi',
#  'Bi',
#  'Bk',
#  'Bk',
#  'Boltzmann',
#  'Both',
#  'Bottom',
#  'Bound',
#  'Bounds',
#  'Brain',
#  'Brownian_motion',
#  'Bt',
#  'Bt',
#  'By',
#  'By',
#  'C1',
#  'C1',
#  'C2',
#  'C2',
#  'CA',
#  'CA',
#  'CA',
#  'CAREER',
#  'CAREER',
#  'CAREER',
#  'CAREER',
#  'CAREER',
#  'CAREER',
#  'CDF',
#  'CDF',
#  'CDF',
#  'CIFAR',
#  'CIFAR',
#  'CIFAR',
#  'CIFAR',
#  'CIFAR',
#  'CIFAR-10',
#  'CIFAR-10',
#  'CIFAR-10',
#  'CIFAR-10',
#  'CIFAR-10',
#  'CNN',
#  'CNN',
#  'CNN',
#  'CPU',
#  'CPU',
#  'CPU',
#  'Cartesian',
#  'Case',
#  'Center',
#  'Chain',
#  'Challenge',
#  'Chapter',
#  'Chen',
#  'Choose',
#  'Ci',
#  'Ci',
#  'Class',
#  'Classification',
#  'Clearly',
#  'Clustering',
#  'Combining',
#  'Comparing',
#  'Comparison',
#  'Complexity',
#  'Component',
#  'Computation',
#  'Computational',
#  'Compute',
#  'Computer',
#  'Computing',
#  'Conclusion',
#  'Conclusions',
#  'Condition',
#  'Conference',
#  'Consider',
#  'Consistency',
#  'Continuous',
#  'Contributions',
#  'Convergence',
#  'Convex',
#  'Convolutional',
#  'Core',
#  'Corollary',
#  'Council',
#  'Coverage',
#  'D1',
#  'D1',
#  'D2',
#  'D2',
#  'DA',
#  'DA',
#  'DA',
#  'DARPA',
#  'DARPA',
#  'DARPA',
#  'DARPA',
#  'DARPA',
#  'DBN',
#  'DBN',
#  'DBN',
#  'DKL',
#  'DKL',
#  'DKL',
#  'DNA',
#  'DNA',
#  'DNA',
#  'DNN',
#  'DNN',
#  'DNN',
#  'DP',
#  'DP',
#  'DP',
#  'Data',
#  'Dataset',
#  'Datasets',
#  'Decision',
#  'Deep',
#  'Define',
#  'Definition',
#  'Department',
#  'Descent',
#  'Detection',
#  'Di',
#  'Di',
#  'Difference',
#  'Dirac',
#  'Dirichlet',
#  'Discussion',
#  'Distance',
#  'Distribution',
#  'Dk',
#  'Dk',
#  'Dn',
#  'Dn',
#  'Draw',
#  'Dual',
#  'Due',
#  'Dynamic',
#  'Dynamics',
#  'E1',
#  'E1',
#  'EM',
#  'EM',
#  'EM',
#  'EP',
#  'EP',
#  'EP',
#  'Each',
#  'Effect',
#  'Efficient',
#  'Ei',
#  'Ei',
#  'Embedding',
#  'Empirical',
#  'Energy',
#  'Engineering',
#  'English',
#  'Entropy',
#  'Ep',
#  'Ep',
#  'Eq',
#  'Eq',
#  'Eqs',
#  'Equation',
#  'Equations',
#  'Error',
#  'Estimate',
#  'Estimated',
#  'Estimating',
#  'Estimation',
#  'Euclidean',
#  'Euclidean_distance',
#  'European',
#  'Evaluation',
#  'Even',
#  'Ex',
#  'Ex',
#  'Example',
#  'Examples',
#  'Expectation',
#  'Expected',
#  'Experiment',
#  'Experimental',
#  'Experiments',
#  'Exponential',
#  'Extension',
#  'F0',
#  'F0',
#  'F1',
#  'F1',
#  'F2',
#  'F2',
#  'FP7',
#  'FP7',
#  'FREE_MC2',
#  'FREE_MC2',
#  'FREE_MC2',
#  'FREE_MC2',
#  'FREE_MC2',
#  'FREE_MC2',
#  'Facebook',
#  'False',
#  'Feature',
#  'Features',
#  'Fellowship',
#  'Fi',
#  'Fi',
#  'Field',
#  'Fields',
#  'Fig',
#  'Figure',
#  'Figure_Left',
#  'Figure_Left',
#  'Figures',
#  'Finally',
#  'First',
#  'Fisher',
#  'Fisher_information',
#  'Fix',
#  'Following',
#  'For',
#  'Force',
#  'Formulation',
#  'Foundation',
#  'Fourier',
#  'Fraction',
#  'Framework',
#  'French',
#  'Frobenius',
#  'Frobenius_norm',
#  'From',
#  'Full',
#  'Function',
#  'Functions',
#  'Furthermore',
#  'Future',
#  'G1',
#  'G1',
#  'GB',
#  'GB',
#  'GB',
#  'GHz',
#  'GHz',
#  'GP',
#  'GP',
#  'GP',
#  'GPU',
#  'GPU',
#  'GPU',
#  'Gaus',
#  'Gaussian',
#  'Gaussians',
#  'General',
#  'Generative',
#  'Gibbs',
#  'Given',
#  'Global',
#  'Google',
#  'Government',
#  'Gradient',
#  'Gradient_Descent',
#  'Gradient_Descent',
#  'Grant',
#  'Graph',
#  'Graphical',
#  'Greedy',
#  'Ground',
#  'Group',
#  'H0',
#  'H0',
#  'H1',
#  'H1',
#  'H2',
#  'H2',
#  'HMM',
#  'HMM',
#  'HMM',
#  'HMMs',
#  'HMMs',
#  'HMMs',
#  'HOG',
#  'HOG',
#  'HOG',
#  'Hamming',
#  'Hamming_distance',
#  'Hawkes_process',
#  'Hence',
#  'Here',
#  'Hessian',
#  'Hilbert',
#  'Hilbert_space',
#  'Hk',
#  'Hk',
#  'How',
#  'However',
#  'Human',
#  'Hz',
#  'Hz',
#  'I1',
#  'I1',
#  'ICA',
#  'ICA',
#  'ICA',
#  'II',
#  'II',
#  'II',
#  'If',
#  'If',
#  'Ik',
#  'Ik',
#  'Illustration',
#  'Im',
#  'Im',
#  'Image',
#  'ImageNet',
#  'ImageNet',
#  'Implementation',
#  'In',
#  'In',
#  'Independent',
#  'Inference',
#  'Information',
#  'Information_Processing',
#  'Information_Processing',
#  'Initial',
#  'Initialization',
#  'Initialize',
#  'Input',
#  'Instead',
#  'Institute',
#  'Intel',
#  'Introduction',
#  'Intuitively',
#  'Invariant',
#  'It',
#  'It',
#  'Iteration',
#  'Jacobian',
#  'Jensens',
#  'K1',
#  'K1',
#  'KL',
#  'KL',
#  'KL',
#  'KL-divergence',
#  'KL-divergence',
#  'Kernel',
#  'Ki',
#  'Ki',
#  'Kronecker',
#  'Kullback',
#  'Kullback-Leibler',
#  'Kullback-Leibler',
#  'L0',
#  'L0',
#  'L1',
#  'L1',
#  'L2',
#  'L2',
#  'LDA',
#  'LDA',
#  'LDA',
#  'LP',
#  'LP',
#  'LP',
#  'LR',
#  'LR',
#  'LR',
#  'LS',
#  'LS',
#  'LS',
#  'LSTM',
#  'LSTM',
#  'LSTM',
#  'LSTM',
#  'Lagrangian',
#  'Langevin',
#  'Laplace',
#  'Laplacian',
#  'Laplacian_smoothing',
#  'Lasso',
#  'Latent',
#  'Learned',
#  'Learning',
#  'Lebesgue',
#  'Lee',
#  'Left',
#  'Leibler',
#  'Lemma',
#  'Lemmas',
#  'Let',
#  'Li',
#  'Li',
#  'Likelihood',
#  'Linear',
#  'Lipschitz',
#  'Lipschitz_constant',
#  'Lipschitz_continuous',
#  'Liu',
#  'Lk',
#  'Lk',
#  'Local',
#  'Logistic',
#  'Long',
#  'Loss',
#  'Lower',
#  'Lp',
#  'Lp',
#  'M0',
#  'M0',
#  'M1',
#  'M1',
#  'M2',
#  'M2',
#  'MAP',
#  'MAP',
#  'MAP',
#  'MAP_inference',
#  'MAP_inference',
#  'MAP_inference',
#  'MAP_instantiation',
#  'MAP_instantiation',
#  'MAP_instantiation',
#  'MATLAB',
#  'MATLAB',
#  'MATLAB',
#  'MATLAB',
#  'MATLAB',
#  'MATLAB',
#  'MC',
#  'MC',
#  'MC',
#  'MCMC',
#  'MCMC',
#  'MCMC',
#  'MCMC',
#  'MDP',
#  'MDP',
#  'MDP',
#  'MDPs',
#  'MDPs',
#  'MDPs',
#  'ML',
#  'ML',
#  'ML',
#  'MLN_theory',
#  'MLN_theory',
#  'MLN_theory',
#  'MLP',
#  'MLP',
#  'MLP',
#  'MNIST',
#  'MNIST',
#  'MNIST',
#  'MNIST',
#  'MNIST',
#  'MSE',
#  'MSE',
#  'MSE',
#  'MURI',
#  'MURI',
#  'MURI',
#  'MURI',
#  'Ma',
#  'Ma',
#  'Machine',
#  'Machines',
#  'Main',
#  'Many',
#  'Markov',
#  'Markov_Random',
#  'Markov_Random',
#  'Markov_chain',
#  'Markov_chains',
#  'Markovian',
#  'Matching',
#  'Material',
#  'Materials',
#  'Matlab',
#  'Matrix',
#  'Max',
#  'Maximization',
#  'Maximum',
#  'Mean',
#  'Method',
#  'Methods',
#  'Mi',
#  'Mi',
#  'Microsoft',
#  'Mixture',
#  'Mj',
#  'Mj',
#  'Mk',
#  'Mk',
#  'Model',
#  'Modeling',
#  'Models',
#  'Monte_Carlo',
#  'Monte_Carlo',
#  'More',
#  'Moreover',
#  'Most',
#  'Multivariate',
#  'N1',
#  'N1',
#  'NIH',
#  'NIH',
#  'NIH',
#  'NIPS',
#  'NIPS',
#  'NIPS',
#  'NIPS',
#  'NIPS_Barcelona',
#  'NIPS_Barcelona',
#  'NIPS_Barcelona',
#  'NIPS_Barcelona',
#  'NIPS_Barcelona',
#  'NIPS_Long',
#  'NIPS_Long',
#  'NIPS_Long',
#  'NIPS_Long',
#  'NIPS_Long',
#  'NN',
#  'NN',
#  'NN',
#  'NP',
#  'NP',
#  'NP',
#  'NP-hard',
#  'NP-hard',
#  'NSF',
#  'NSF',
#  'NSF',
#  'National',
#  'Natural',
#  'Naval',
#  'Negative',
#  'Nesterov',
#  'Net',
#  'Network',
#  'Networks',
#  'Neural',
#  'Neural_Information',
#  'Neural_Information',
#  'New',
#  'Newton',
#  'Newtons_method',
#  'Next',
#  'Nk',
#  'Nk',
#  'No',
#  'No',
#  'Noise',
#  'Noisy',
#  'Normalized',
#  'Not',
#  'Notation',
#  'Note',
#  'Notice',
#  'Now',
#  'Number',
#  'Numerical',
#  'ONR',
#  'ONR',
#  'ONR',
#  'Objective',
#  'Observe',
#  'Office',
#  'On',
#  'On',
#  'One',
#  'Online',
#  'Optimal',
#  'Optimization',
#  'Original',
#  'Other',
#  'Our',
#  'Our_appr',
#  'Output',
#  'Overview',
#  'Oﬄine',
#  'P0',
#  'P0',
#  'P1',
#  'P1',
#  'P2',
#  'P2',
#  'PA',
#  'PA',
#  'PA',
#  'PAC',
#  'PAC',
#  'PAC',
#  'PC',
#  'PC',
#  'PC',
#  'PCA',
#  'PCA',
#  'PCA',
#  'PK',
#  'PK',
#  'PK',
#  'PN',
#  'PN',
#  'PN',
#  'PS',
#  'PS',
#  'PS',
#  'PSD',
#  'PSD',
#  'PSD',
#  'PT',
#  'PT',
#  'PT',
#  'Parameter',
#  'Parameters',
#  'Pd',
#  'Pd',
#  'Percentage',
#  'Performance',
#  'Pi',
#  'Pi',
#  'Pk',
#  'Pk',
#  'Pm',
#  'Pm',
#  'Pn',
#  'Pn',
#  'Poisson',
#  'Policy',
#  'Posterior',
#  'Power',
#  'Pr',
#  'Pr',
#  'Precision',
#  'Prediction',
#  'Preliminaries',
#  'Previous',
#  'Prior',
#  'Probabilistic',
#  'Probability',
#  'Problem',
#  'Process',
#  'Processes',
#  'Processing',
#  'Processing_Systems',
#  'Processing_Systems',
#  'Program',
#  'Programming',
#  'Project',
#  'Proof',
#  'Proofs',
#  'Proposed',
#  'Proposition',
#  'Pt',
#  'Pt',
#  'Python',
#  'Q1',
#  'Q1',
#  'Q2',
#  'Q2',
#  'Qt',
#  'Qt',
#  'R0',
#  'R0',
#  'R1',
#  'R1',
#  'R2',
#  'R2',
#  'RAM',
#  'RAM',
#  'RAM',
#  'RBF',
#  'RBF',
#  'RBF',
#  'RBF_kernel',
#  'RBF_kernel',
#  'RBF_kernel',
#  'RBF_kernels',
#  'RBF_kernels',
#  'RBF_kernels',
#  'RD',
#  'RD',
#  'RD',
#  'RGB',
#  'RGB',
#  'RGB',
#  'RKHS',
#  'RKHS',
#  'RKHS',
#  'RKHS',
#  'RL',
#  'RL',
#  'RL',
#  'RM',
#  'RM',
#  'RM',
#  'RMSE',
#  'RMSE',
#  'RMSE',
#  'RMSE',
#  'RN',
#  'RN',
#  'RN',
#  'ROC',
#  'ROC',
#  'ROC',
#  'RPT_REE',
#  'RPT_REE',
#  'RPT_REE',
#  'RPT_REE',
#  'RPT_REE',
#  'RPT_REE',
#  'RVU_property',
#  'RVU_property',
#  'RVU_property',
#  'Rademacher',
#  'Rademacher_complexity',
#  'Rand_index',
#  'Random',
#  'Rate',
#  'Rd',
#  'Rd',
#  'Re',
#  'Re',
#  'ReLU',
#  'ReLU',
#  'ReLU',
#  'Real',
#  'Recall',
#  'Recently',
#  'Recht',
#  'Recognition',
#  'Reduction',
#  'Regression',
#  'Regret',
#  'Regularized',
#  'Reinforcement',
#  'Related',
#  'Related_Work',
#  'Related_Work',
#  'Relationship',
#  'Relative',
#  'Remark',
#  'Representation',
#  'Research',
#  'Restricted',
#  'Result',
#  'Results',
#  'Return',
#  'Reward',
#  'Riemannian',
#  'Right',
#  'Rk',
#  'Rk',
#  'Rm',
#  'Rm',
#  'Rmn',
#  'Rn',
#  'Rn',
#  'Rnn',
#  'Rotation',
#  'Rp',
#  'Rp',
#  'Rt',
#  'Rt',
#  'Running',
#  'S0',
#  'S0',
#  'S1',
#  'S1',
#  'S2',
#  'S2',
#  'SD',
#  'SD',
#  'SD',
#  'SGD',
#  'SGD',
#  'SGD',
#  'SIFT',
#  'SIFT',
#  'SIFT',
#  'SIFT',
#  'SSUMPTION_FREE',
#  'SSUMPTION_FREE',
#  'SSUMPTION_FREE',
#  'SSUMPTION_FREE',
#  'SSUMPTION_FREE',
#  'SSUMPTION_FREE',
#  'SSUMPTION_FREE',
#  'SSUMPTION_FREE',
#  'SSUMPTION_FREE',
#  'SSUMPTION_FREE',
#  'SSUMPTION_FREE',
#  'SSUMPTION_FREE',
#  'SSUMPTION_FREE',
#  'SVD',
#  'SVD',
#  'SVD',
#  'SVM',
#  'SVM',
#  'SVM',
#  'SVMs',
#  'SVMs',
#  'SVMs',
#  'Sample',
#  'Sampling',
#  'Science',
#  'Sec',
#  'Second',
#  'Section',
#  'Sections',
#  'See',
#  'Segmentation',
#  'Select',
#  'Selection',
#  'Set',
#  'Setting',
#  'Setup',
#  'Shuﬄed',
#  'Si',
#  'Si',
#  'Similar',
#  'Similarly',
#  'Simulation',
#  'Since',
#  'Single',
#  'Size',
#  'Sj',
#  'Sj',
#  'Sk',
#  'Sk',
#  'Sketch',
#  'Sm',
#  'Sm',
#  'Sn',
#  'Sn',
#  'So',
#  'So',
#  'Social',
#  'Solution',
#  'Some',
#  'Space',
#  'Spain',
#  'Sparse',
#  'Sparsity',
#  'Standard',
#  'Start',
#  'Statistical',
#  'Step',
#  'Stochastic',
#  'Structure',
#  'Structured',
#  'Study',
#  'Such',
#  'Summary',
#  'Supervised',
#  'Supplementary',
#  'Supplementary_Material',
#  'Supplementary_Material',
#  'Support',
#  'Suppose',
#  'Synthetic',
#  'System',
#  'Systems',
#  'T1',
#  'T1',
#  'Table',
#  'Taking',
#  'Target',
#  'Taylor',
#  'Technology',
#  'Temporal',
#  'Test',
#  'That',
#  'Then',
#  'Theorem',
#  'Theorems',
#  'Theoretical',
#  'Theory',
#  'There',
#  'Therefore',
#  'These',
#  'This',
#  'Threshold',
#  'Throughout',
#  'Thus',
#  'Time',
#  'Titan',
#  'To',
#  'To',
#  'Top',
#  'Total',
#  'Tr',
#  'Tr',
#  'Train',
#  'Training',
#  'True',
#  'Tt',
#  'Tt',
#  'Two',
#  ...]

# %% [markdown]
# Remove tokens with the length less than 3 from the vocab

# %%
## reomve Tokens with the length less than 3
stemmed_token = [i for i in stemmed_token if len(i) >= 3]
len(stemmed_token)
# Out:
# 5787

# %% [markdown]
# Change the connector between two words in collocation to double underline

# %%
store_token = []
for word in stemmed_token: ## loop all word in list
    extracted_token = [] ##store word for the moment
    for i in range(len(word)):
        extracted_token.append(word[i].replace('_','__')) ## if a word contain '_', replace it to '__'
    extracted_token = "".join(extracted_token)
    store_token.append(extracted_token)
store_token.sort()
store_token
# Out:
# ['ADMM',
#  'ADMM',
#  'ADMM',
#  'ADMM',
#  'ANR',
#  'ANR',
#  'ANR',
#  'AUC',
#  'AUC',
#  'AUC',
#  'Accuracy',
#  'Acknowledgements',
#  'Acknowledgments',
#  'Ada__Newton',
#  'Ada__Newton',
#  'Adam',
#  'Adaptive',
#  'Additionally',
#  'Advanced',
#  'Adversarial',
#  'After',
#  'Agency',
#  'Air',
#  'Alg',
#  'Algorithm',
#  'Algorithms',
#  'All',
#  'Also',
#  'Although',
#  'Amazon',
#  'Analysis',
#  'And',
#  'Another',
#  'Any',
#  'Appendix',
#  'Application',
#  'Applications',
#  'Apply',
#  'Approach',
#  'Approximate',
#  'Approximation',
#  'Architecture',
#  'Arora',
#  'Assume',
#  'Assumption',
#  'Assumptions',
#  'Average',
#  'Avg',
#  'Award',
#  'BFGS',
#  'BFGS',
#  'BFGS',
#  'BFGS',
#  'Bach',
#  'Background',
#  'Based',
#  'Basic',
#  'Bayes',
#  'Bayes__classifier',
#  'Bayesian',
#  'Beach',
#  'Because',
#  'Before',
#  'Bellman',
#  'Bellman__error',
#  'Bengio',
#  'Bernoulli',
#  'Best',
#  'Boltzmann',
#  'Both',
#  'Bottom',
#  'Bound',
#  'Bounds',
#  'Brain',
#  'Brownian__motion',
#  'CAREER',
#  'CAREER',
#  'CAREER',
#  'CAREER',
#  'CAREER',
#  'CAREER',
#  'CDF',
#  'CDF',
#  'CDF',
#  'CIFAR',
#  'CIFAR',
#  'CIFAR',
#  'CIFAR',
#  'CIFAR',
#  'CIFAR-10',
#  'CIFAR-10',
#  'CIFAR-10',
#  'CIFAR-10',
#  'CIFAR-10',
#  'CNN',
#  'CNN',
#  'CNN',
#  'CPU',
#  'CPU',
#  'CPU',
#  'Cartesian',
#  'Case',
#  'Center',
#  'Chain',
#  'Challenge',
#  'Chapter',
#  'Chen',
#  'Choose',
#  'Class',
#  'Classification',
#  'Clearly',
#  'Clustering',
#  'Combining',
#  'Comparing',
#  'Comparison',
#  'Complexity',
#  'Component',
#  'Computation',
#  'Computational',
#  'Compute',
#  'Computer',
#  'Computing',
#  'Conclusion',
#  'Conclusions',
#  'Condition',
#  'Conference',
#  'Consider',
#  'Consistency',
#  'Continuous',
#  'Contributions',
#  'Convergence',
#  'Convex',
#  'Convolutional',
#  'Core',
#  'Corollary',
#  'Council',
#  'Coverage',
#  'DARPA',
#  'DARPA',
#  'DARPA',
#  'DARPA',
#  'DARPA',
#  'DBN',
#  'DBN',
#  'DBN',
#  'DKL',
#  'DKL',
#  'DKL',
#  'DNA',
#  'DNA',
#  'DNA',
#  'DNN',
#  'DNN',
#  'DNN',
#  'Data',
#  'Dataset',
#  'Datasets',
#  'Decision',
#  'Deep',
#  'Define',
#  'Definition',
#  'Department',
#  'Descent',
#  'Detection',
#  'Difference',
#  'Dirac',
#  'Dirichlet',
#  'Discussion',
#  'Distance',
#  'Distribution',
#  'Draw',
#  'Dual',
#  'Due',
#  'Dynamic',
#  'Dynamics',
#  'Each',
#  'Effect',
#  'Efficient',
#  'Embedding',
#  'Empirical',
#  'Energy',
#  'Engineering',
#  'English',
#  'Entropy',
#  'Eqs',
#  'Equation',
#  'Equations',
#  'Error',
#  'Estimate',
#  'Estimated',
#  'Estimating',
#  'Estimation',
#  'Euclidean',
#  'Euclidean__distance',
#  'European',
#  'Evaluation',
#  'Even',
#  'Example',
#  'Examples',
#  'Expectation',
#  'Expected',
#  'Experiment',
#  'Experimental',
#  'Experiments',
#  'Exponential',
#  'Extension',
#  'FP7',
#  'FP7',
#  'FREE__MC2',
#  'FREE__MC2',
#  'FREE__MC2',
#  'FREE__MC2',
#  'FREE__MC2',
#  'FREE__MC2',
#  'Facebook',
#  'False',
#  'Feature',
#  'Features',
#  'Fellowship',
#  'Field',
#  'Fields',
#  'Fig',
#  'Figure',
#  'Figure__Left',
#  'Figure__Left',
#  'Figures',
#  'Finally',
#  'First',
#  'Fisher',
#  'Fisher__information',
#  'Fix',
#  'Following',
#  'For',
#  'Force',
#  'Formulation',
#  'Foundation',
#  'Fourier',
#  'Fraction',
#  'Framework',
#  'French',
#  'Frobenius',
#  'Frobenius__norm',
#  'From',
#  'Full',
#  'Function',
#  'Functions',
#  'Furthermore',
#  'Future',
#  'GHz',
#  'GHz',
#  'GPU',
#  'GPU',
#  'GPU',
#  'Gaus',
#  'Gaussian',
#  'Gaussians',
#  'General',
#  'Generative',
#  'Gibbs',
#  'Given',
#  'Global',
#  'Google',
#  'Government',
#  'Gradient',
#  'Gradient__Descent',
#  'Gradient__Descent',
#  'Grant',
#  'Graph',
#  'Graphical',
#  'Greedy',
#  'Ground',
#  'Group',
#  'HMM',
#  'HMM',
#  'HMM',
#  'HMMs',
#  'HMMs',
#  'HMMs',
#  'HOG',
#  'HOG',
#  'HOG',
#  'Hamming',
#  'Hamming__distance',
#  'Hawkes__process',
#  'Hence',
#  'Here',
#  'Hessian',
#  'Hilbert',
#  'Hilbert__space',
#  'How',
#  'However',
#  'Human',
#  'ICA',
#  'ICA',
#  'ICA',
#  'Illustration',
#  'Image',
#  'ImageNet',
#  'ImageNet',
#  'Implementation',
#  'Independent',
#  'Inference',
#  'Information',
#  'Information__Processing',
#  'Information__Processing',
#  'Initial',
#  'Initialization',
#  'Initialize',
#  'Input',
#  'Instead',
#  'Institute',
#  'Intel',
#  'Introduction',
#  'Intuitively',
#  'Invariant',
#  'Iteration',
#  'Jacobian',
#  'Jensens',
#  'KL-divergence',
#  'KL-divergence',
#  'Kernel',
#  'Kronecker',
#  'Kullback',
#  'Kullback-Leibler',
#  'Kullback-Leibler',
#  'LDA',
#  'LDA',
#  'LDA',
#  'LSTM',
#  'LSTM',
#  'LSTM',
#  'LSTM',
#  'Lagrangian',
#  'Langevin',
#  'Laplace',
#  'Laplacian',
#  'Laplacian__smoothing',
#  'Lasso',
#  'Latent',
#  'Learned',
#  'Learning',
#  'Lebesgue',
#  'Lee',
#  'Left',
#  'Leibler',
#  'Lemma',
#  'Lemmas',
#  'Let',
#  'Likelihood',
#  'Linear',
#  'Lipschitz',
#  'Lipschitz__constant',
#  'Lipschitz__continuous',
#  'Liu',
#  'Local',
#  'Logistic',
#  'Long',
#  'Loss',
#  'Lower',
#  'MAP',
#  'MAP',
#  'MAP',
#  'MAP__inference',
#  'MAP__inference',
#  'MAP__inference',
#  'MAP__instantiation',
#  'MAP__instantiation',
#  'MAP__instantiation',
#  'MATLAB',
#  'MATLAB',
#  'MATLAB',
#  'MATLAB',
#  'MATLAB',
#  'MATLAB',
#  'MCMC',
#  'MCMC',
#  'MCMC',
#  'MCMC',
#  'MDP',
#  'MDP',
#  'MDP',
#  'MDPs',
#  'MDPs',
#  'MDPs',
#  'MLN__theory',
#  'MLN__theory',
#  'MLN__theory',
#  'MLP',
#  'MLP',
#  'MLP',
#  'MNIST',
#  'MNIST',
#  'MNIST',
#  'MNIST',
#  'MNIST',
#  'MSE',
#  'MSE',
#  'MSE',
#  'MURI',
#  'MURI',
#  'MURI',
#  'MURI',
#  'Machine',
#  'Machines',
#  'Main',
#  'Many',
#  'Markov',
#  'Markov__Random',
#  'Markov__Random',
#  'Markov__chain',
#  'Markov__chains',
#  'Markovian',
#  'Matching',
#  'Material',
#  'Materials',
#  'Matlab',
#  'Matrix',
#  'Max',
#  'Maximization',
#  'Maximum',
#  'Mean',
#  'Method',
#  'Methods',
#  'Microsoft',
#  'Mixture',
#  'Model',
#  'Modeling',
#  'Models',
#  'Monte__Carlo',
#  'Monte__Carlo',
#  'More',
#  'Moreover',
#  'Most',
#  'Multivariate',
#  'NIH',
#  'NIH',
#  'NIH',
#  'NIPS',
#  'NIPS',
#  'NIPS',
#  'NIPS',
#  'NIPS__Barcelona',
#  'NIPS__Barcelona',
#  'NIPS__Barcelona',
#  'NIPS__Barcelona',
#  'NIPS__Barcelona',
#  'NIPS__Long',
#  'NIPS__Long',
#  'NIPS__Long',
#  'NIPS__Long',
#  'NIPS__Long',
#  'NP-hard',
#  'NP-hard',
#  'NSF',
#  'NSF',
#  'NSF',
#  'National',
#  'Natural',
#  'Naval',
#  'Negative',
#  'Nesterov',
#  'Net',
#  'Network',
#  'Networks',
#  'Neural',
#  'Neural__Information',
#  'Neural__Information',
#  'New',
#  'Newton',
#  'Newtons__method',
#  'Next',
#  'Noise',
#  'Noisy',
#  'Normalized',
#  'Not',
#  'Notation',
#  'Note',
#  'Notice',
#  'Now',
#  'Number',
#  'Numerical',
#  'ONR',
#  'ONR',
#  'ONR',
#  'Objective',
#  'Observe',
#  'Office',
#  'One',
#  'Online',
#  'Optimal',
#  'Optimization',
#  'Original',
#  'Other',
#  'Our',
#  'Our__appr',
#  'Output',
#  'Overview',
#  'Oﬄine',
#  'PAC',
#  'PAC',
#  'PAC',
#  'PCA',
#  'PCA',
#  'PCA',
#  'PSD',
#  'PSD',
#  'PSD',
#  'Parameter',
#  'Parameters',
#  'Percentage',
#  'Performance',
#  'Poisson',
#  'Policy',
#  'Posterior',
#  'Power',
#  'Precision',
#  'Prediction',
#  'Preliminaries',
#  'Previous',
#  'Prior',
#  'Probabilistic',
#  'Probability',
#  'Problem',
#  'Process',
#  'Processes',
#  'Processing',
#  'Processing__Systems',
#  'Processing__Systems',
#  'Program',
#  'Programming',
#  'Project',
#  'Proof',
#  'Proofs',
#  'Proposed',
#  'Proposition',
#  'Python',
#  'RAM',
#  'RAM',
#  'RAM',
#  'RBF',
#  'RBF',
#  'RBF',
#  'RBF__kernel',
#  'RBF__kernel',
#  'RBF__kernel',
#  'RBF__kernels',
#  'RBF__kernels',
#  'RBF__kernels',
#  'RGB',
#  'RGB',
#  'RGB',
#  'RKHS',
#  'RKHS',
#  'RKHS',
#  'RKHS',
#  'RMSE',
#  'RMSE',
#  'RMSE',
#  'RMSE',
#  'ROC',
#  'ROC',
#  'ROC',
#  'RPT__REE',
#  'RPT__REE',
#  'RPT__REE',
#  'RPT__REE',
#  'RPT__REE',
#  'RPT__REE',
#  'RVU__property',
#  'RVU__property',
#  'RVU__property',
#  'Rademacher',
#  'Rademacher__complexity',
#  'Rand__index',
#  'Random',
#  'Rate',
#  'ReLU',
#  'ReLU',
#  'ReLU',
#  'Real',
#  'Recall',
#  'Recently',
#  'Recht',
#  'Recognition',
#  'Reduction',
#  'Regression',
#  'Regret',
#  'Regularized',
#  'Reinforcement',
#  'Related',
#  'Related__Work',
#  'Related__Work',
#  'Relationship',
#  'Relative',
#  'Remark',
#  'Representation',
#  'Research',
#  'Restricted',
#  'Result',
#  'Results',
#  'Return',
#  'Reward',
#  'Riemannian',
#  'Right',
#  'Rmn',
#  'Rnn',
#  'Rotation',
#  'Running',
#  'SGD',
#  'SGD',
#  'SGD',
#  'SIFT',
#  'SIFT',
#  'SIFT',
#  'SIFT',
#  'SSUMPTION__FREE',
#  'SSUMPTION__FREE',
#  'SSUMPTION__FREE',
#  'SSUMPTION__FREE',
#  'SSUMPTION__FREE',
#  'SSUMPTION__FREE',
#  'SSUMPTION__FREE',
#  'SSUMPTION__FREE',
#  'SSUMPTION__FREE',
#  'SSUMPTION__FREE',
#  'SSUMPTION__FREE',
#  'SSUMPTION__FREE',
#  'SSUMPTION__FREE',
#  'SVD',
#  'SVD',
#  'SVD',
#  'SVM',
#  'SVM',
#  'SVM',
#  'SVMs',
#  'SVMs',
#  'SVMs',
#  'Sample',
#  'Sampling',
#  'Science',
#  'Sec',
#  'Second',
#  'Section',
#  'Sections',
#  'See',
#  'Segmentation',
#  'Select',
#  'Selection',
#  'Set',
#  'Setting',
#  'Setup',
#  'Shuﬄed',
#  'Similar',
#  'Similarly',
#  'Simulation',
#  'Since',
#  'Single',
#  'Size',
#  'Sketch',
#  'Social',
#  'Solution',
#  'Some',
#  'Space',
#  'Spain',
#  'Sparse',
#  'Sparsity',
#  'Standard',
#  'Start',
#  'Statistical',
#  'Step',
#  'Stochastic',
#  'Structure',
#  'Structured',
#  'Study',
#  'Such',
#  'Summary',
#  'Supervised',
#  'Supplementary',
#  'Supplementary__Material',
#  'Supplementary__Material',
#  'Support',
#  'Suppose',
#  'Synthetic',
#  'System',
#  'Systems',
#  'Table',
#  'Taking',
#  'Target',
#  'Taylor',
#  'Technology',
#  'Temporal',
#  'Test',
#  'That',
#  'Then',
#  'Theorem',
#  'Theorems',
#  'Theoretical',
#  'Theory',
#  'There',
#  'Therefore',
#  'These',
#  'This',
#  'Threshold',
#  'Throughout',
#  'Thus',
#  'Time',
#  'Titan',
#  'Top',
#  'Total',
#  'Train',
#  'Training',
#  'True',
#  'Two',
#  'UCI',
#  'UCI',
#  'UCI',
#  'USA',
#  'USA',
#  'USA',
#  'USPS',
#  'USPS',
#  'USPS',
#  'USPS',
#  'Under',
#  'Unfortunately',
#  'Uniform',
#  'University',
#  'Unsupervised',
#  'Update',
#  'Upper',
#  'Using',
#  'Validation',
#  'Value',
#  'Var',
#  'Variable',
#  'Variation',
#  'Variational',
#  'Vector',
#  'Visual',
#  'Wang',
#  'Weights',
#  'Welling',
#  'When',
#  'While',
#  'Williams',
#  'With',
#  'Work',
#  'Works',
#  'Xeon',
#  'Xij',
#  'Xt1',
#  'Zhang',
#  'abil',
#  'abil',
#  'abl',
#  'abl',
#  'about',
#  'abov',
#  'absenc',
#  'absolut',
#  'absolut',
#  'abstract',
#  'abstract',
#  'abus',
#  'acceler',
#  'acceler',
#  'acceler',
#  'acceler',
#  'accept',
#  'accept',
#  'access',
#  'access',
#  'accommod',
#  'accomplish',
#  'accord',
#  'accordingli',
#  'account',
#  'account',
#  'accu',
#  'accumul',
#  'accur',
#  'accur',
#  'accuraci',
#  'accuraci',
#  'accuraci',
#  'achiev',
#  'achiev',
#  'achiev',
#  'achiev',
#  'achiev',
#  'acknowledg',
#  'acknowledg',
#  'acknowledg',
#  'acknowledg',
#  'acknowledg',
#  'acknowledg',
#  'acknowledgments__This',
#  'acknowledgments__thi',
#  'acquir',
#  'acquir',
#  'across',
#  'act',
#  'act',
#  'act',
#  'action',
#  'action',
#  'activ',
#  'activ',
#  'activ',
#  'activ',
#  'activ',
#  'activ',
#  'activ',
#  'actor',
#  'actual',
#  'actual',
#  'ad-hoc',
#  'ada__newton',
#  'adam',
#  'adapt',
#  'adapt',
#  'adapt',
#  'adapt',
#  'adapt',
#  'adapt',
#  'adapt',
#  'adapt',
#  'add',
#  'add',
#  'addi',
#  'addit',
#  'addit',
#  'addit',
#  'addit',
#  'addit',
#  'additive__nois',
#  'address',
#  'address',
#  'address',
#  'address',
#  'adequ',
#  'adjac',
#  'adjac',
#  'adjacency__matrix',
#  'adjust',
#  'adjust',
#  'adjust',
#  'adjust',
#  'admiss',
#  'admit',
#  'admit',
#  'admm',
#  'adopt',
#  'adopt',
#  'adopt',
#  'advanc',
#  'advanc',
#  'advanc',
#  'advanc',
#  'advantag',
#  'advantag',
#  'advantag',
#  'adversari',
#  'adversari',
#  'adversari',
#  'adversari',
#  'advertis',
#  'affect',
#  'affect',
#  'affect',
#  'affin',
#  'affinity__graph',
#  'aforement',
#  'after',
#  'after',
#  'again',
#  'against',
#  'age',
#  'age',
#  'agenc',
#  'agent',
#  'agent',
#  'aggreg',
#  'aggreg',
#  'aggregative__gam',
#  'aggress',
#  'agre',
#  'agreement',
#  'ahead',
#  'aim',
#  'aim',
#  'aim',
#  'air',
#  'akin',
#  'albeit',
#  'alg',
#  'algebra',
#  'algebra',
#  'algo',
#  'algo__rithm',
#  'algo__rithm',
#  'algorithm',
#  'algorithm',
#  'algorithm',
#  'algorithm',
#  'algorithm',
#  'align',
#  'align',
#  'align',
#  'all',
#  'allevi',
#  'allevi',
#  'alli',
#  'alloc',
#  'allow',
#  'allow',
#  'allow',
#  'allow',
#  'almost',
#  'alon',
#  'along',
#  'alphabet',
#  'alreadi',
#  'also',
#  'alter',
#  'altern',
#  'altern',
#  'altern',
#  'altern',
#  'altern',
#  'altern',
#  'although',
#  'although',
#  'altogeth',
#  'alway',
#  'amazon',
#  'ambigu',
#  'among',
#  'amongst',
#  'amount',
#  'amount',
#  'anal',
#  'analog',
#  'analog',
#  'analog',
#  'analog',
#  'analogu',
#  'analys',
#  'analysi',
#  'analysi',
#  'analyt',
#  'analyt',
#  'analyt',
#  'analyz',
#  'analyz',
#  'analyz',
#  'anc',
#  'anchor',
#  'and',
#  'angl',
#  'angl',
#  'angular',
#  'ani',
#  'ani',
#  'anim',
#  'annot',
#  'annot',
#  'annot',
#  'anonym',
#  'anoth',
#  'anoth',
#  'anr',
#  'answer',
#  'answer',
#  'anymor',
#  'apart',
#  'appar',
#  'appar',
#  'appeal',
#  'appear',
#  'appear',
#  'appear',
#  'appear',
#  'appear',
#  'appendix',
#  'appendix',
#  'appli',
#  'appli',
#  'appli',
#  'appli',
#  'appli',
#  'appli',
#  'applic',
#  'applic',
#  'applic',
#  'applic',
#  'applic',
#  'applic',
#  'applica',
#  'appr__trsf',
#  ...]

# %%
##remove all stop_word again
store_token = [w for w in store_token if w not in stopwords_set]## append words from tokens who is not stop word
len(store_token)
# Out:
# 5513

# %% [markdown]
# ### 4.3 Output vocabulary_index file and count_vector file

# %% [markdown]
# Now we get the clean token. So for each token we need to ensure it has index.

# %%
token_set = list(set(store_token))## remove repeting words
token_set.sort()
vocab_index = {}
for i in range(len(token_set)):##token_string:token_index format
    vocab_index[i] = token_set[i]
vocab_index
# Out:
# {0: 'ADMM',
#  1: 'ANR',
#  2: 'AUC',
#  3: 'Accuracy',
#  4: 'Acknowledgements',
#  5: 'Acknowledgments',
#  6: 'Ada__Newton',
#  7: 'Adam',
#  8: 'Adaptive',
#  9: 'Additionally',
#  10: 'Advanced',
#  11: 'Adversarial',
#  12: 'After',
#  13: 'Agency',
#  14: 'Air',
#  15: 'Alg',
#  16: 'Algorithm',
#  17: 'Algorithms',
#  18: 'All',
#  19: 'Also',
#  20: 'Although',
#  21: 'Amazon',
#  22: 'Analysis',
#  23: 'And',
#  24: 'Another',
#  25: 'Any',
#  26: 'Appendix',
#  27: 'Application',
#  28: 'Applications',
#  29: 'Apply',
#  30: 'Approach',
#  31: 'Approximate',
#  32: 'Approximation',
#  33: 'Architecture',
#  34: 'Arora',
#  35: 'Assume',
#  36: 'Assumption',
#  37: 'Assumptions',
#  38: 'Average',
#  39: 'Avg',
#  40: 'Award',
#  41: 'BFGS',
#  42: 'Bach',
#  43: 'Background',
#  44: 'Based',
#  45: 'Basic',
#  46: 'Bayes',
#  47: 'Bayes__classifier',
#  48: 'Bayesian',
#  49: 'Beach',
#  50: 'Because',
#  51: 'Before',
#  52: 'Bellman',
#  53: 'Bellman__error',
#  54: 'Bengio',
#  55: 'Bernoulli',
#  56: 'Best',
#  57: 'Boltzmann',
#  58: 'Both',
#  59: 'Bottom',
#  60: 'Bound',
#  61: 'Bounds',
#  62: 'Brain',
#  63: 'Brownian__motion',
#  64: 'CAREER',
#  65: 'CDF',
#  66: 'CIFAR',
#  67: 'CIFAR-10',
#  68: 'CNN',
#  69: 'CPU',
#  70: 'Cartesian',
#  71: 'Case',
#  72: 'Center',
#  73: 'Chain',
#  74: 'Challenge',
#  75: 'Chapter',
#  76: 'Chen',
#  77: 'Choose',
#  78: 'Class',
#  79: 'Classification',
#  80: 'Clearly',
#  81: 'Clustering',
#  82: 'Combining',
#  83: 'Comparing',
#  84: 'Comparison',
#  85: 'Complexity',
#  86: 'Component',
#  87: 'Computation',
#  88: 'Computational',
#  89: 'Compute',
#  90: 'Computer',
#  91: 'Computing',
#  92: 'Conclusion',
#  93: 'Conclusions',
#  94: 'Condition',
#  95: 'Conference',
#  96: 'Consider',
#  97: 'Consistency',
#  98: 'Continuous',
#  99: 'Contributions',
#  100: 'Convergence',
#  101: 'Convex',
#  102: 'Convolutional',
#  103: 'Core',
#  104: 'Corollary',
#  105: 'Council',
#  106: 'Coverage',
#  107: 'DARPA',
#  108: 'DBN',
#  109: 'DKL',
#  110: 'DNA',
#  111: 'DNN',
#  112: 'Data',
#  113: 'Dataset',
#  114: 'Datasets',
#  115: 'Decision',
#  116: 'Deep',
#  117: 'Define',
#  118: 'Definition',
#  119: 'Department',
#  120: 'Descent',
#  121: 'Detection',
#  122: 'Difference',
#  123: 'Dirac',
#  124: 'Dirichlet',
#  125: 'Discussion',
#  126: 'Distance',
#  127: 'Distribution',
#  128: 'Draw',
#  129: 'Dual',
#  130: 'Due',
#  131: 'Dynamic',
#  132: 'Dynamics',
#  133: 'Each',
#  134: 'Effect',
#  135: 'Efficient',
#  136: 'Embedding',
#  137: 'Empirical',
#  138: 'Energy',
#  139: 'Engineering',
#  140: 'English',
#  141: 'Entropy',
#  142: 'Eqs',
#  143: 'Equation',
#  144: 'Equations',
#  145: 'Error',
#  146: 'Estimate',
#  147: 'Estimated',
#  148: 'Estimating',
#  149: 'Estimation',
#  150: 'Euclidean',
#  151: 'Euclidean__distance',
#  152: 'European',
#  153: 'Evaluation',
#  154: 'Even',
#  155: 'Example',
#  156: 'Examples',
#  157: 'Expectation',
#  158: 'Expected',
#  159: 'Experiment',
#  160: 'Experimental',
#  161: 'Experiments',
#  162: 'Exponential',
#  163: 'Extension',
#  164: 'FP7',
#  165: 'FREE__MC2',
#  166: 'Facebook',
#  167: 'False',
#  168: 'Feature',
#  169: 'Features',
#  170: 'Fellowship',
#  171: 'Field',
#  172: 'Fields',
#  173: 'Fig',
#  174: 'Figure',
#  175: 'Figure__Left',
#  176: 'Figures',
#  177: 'Finally',
#  178: 'First',
#  179: 'Fisher',
#  180: 'Fisher__information',
#  181: 'Fix',
#  182: 'Following',
#  183: 'For',
#  184: 'Force',
#  185: 'Formulation',
#  186: 'Foundation',
#  187: 'Fourier',
#  188: 'Fraction',
#  189: 'Framework',
#  190: 'French',
#  191: 'Frobenius',
#  192: 'Frobenius__norm',
#  193: 'From',
#  194: 'Full',
#  195: 'Function',
#  196: 'Functions',
#  197: 'Furthermore',
#  198: 'Future',
#  199: 'GHz',
#  200: 'GPU',
#  201: 'Gaus',
#  202: 'Gaussian',
#  203: 'Gaussians',
#  204: 'General',
#  205: 'Generative',
#  206: 'Gibbs',
#  207: 'Given',
#  208: 'Global',
#  209: 'Google',
#  210: 'Government',
#  211: 'Gradient',
#  212: 'Gradient__Descent',
#  213: 'Grant',
#  214: 'Graph',
#  215: 'Graphical',
#  216: 'Greedy',
#  217: 'Ground',
#  218: 'Group',
#  219: 'HMM',
#  220: 'HMMs',
#  221: 'HOG',
#  222: 'Hamming',
#  223: 'Hamming__distance',
#  224: 'Hawkes__process',
#  225: 'Hence',
#  226: 'Here',
#  227: 'Hessian',
#  228: 'Hilbert',
#  229: 'Hilbert__space',
#  230: 'How',
#  231: 'However',
#  232: 'Human',
#  233: 'ICA',
#  234: 'Illustration',
#  235: 'Image',
#  236: 'ImageNet',
#  237: 'Implementation',
#  238: 'Independent',
#  239: 'Inference',
#  240: 'Information',
#  241: 'Information__Processing',
#  242: 'Initial',
#  243: 'Initialization',
#  244: 'Initialize',
#  245: 'Input',
#  246: 'Instead',
#  247: 'Institute',
#  248: 'Intel',
#  249: 'Introduction',
#  250: 'Intuitively',
#  251: 'Invariant',
#  252: 'Iteration',
#  253: 'Jacobian',
#  254: 'Jensens',
#  255: 'KL-divergence',
#  256: 'Kernel',
#  257: 'Kronecker',
#  258: 'Kullback',
#  259: 'Kullback-Leibler',
#  260: 'LDA',
#  261: 'LSTM',
#  262: 'Lagrangian',
#  263: 'Langevin',
#  264: 'Laplace',
#  265: 'Laplacian',
#  266: 'Laplacian__smoothing',
#  267: 'Lasso',
#  268: 'Latent',
#  269: 'Learned',
#  270: 'Learning',
#  271: 'Lebesgue',
#  272: 'Lee',
#  273: 'Left',
#  274: 'Leibler',
#  275: 'Lemma',
#  276: 'Lemmas',
#  277: 'Let',
#  278: 'Likelihood',
#  279: 'Linear',
#  280: 'Lipschitz',
#  281: 'Lipschitz__constant',
#  282: 'Lipschitz__continuous',
#  283: 'Liu',
#  284: 'Local',
#  285: 'Logistic',
#  286: 'Long',
#  287: 'Loss',
#  288: 'Lower',
#  289: 'MAP',
#  290: 'MAP__inference',
#  291: 'MAP__instantiation',
#  292: 'MATLAB',
#  293: 'MCMC',
#  294: 'MDP',
#  295: 'MDPs',
#  296: 'MLN__theory',
#  297: 'MLP',
#  298: 'MNIST',
#  299: 'MSE',
#  300: 'MURI',
#  301: 'Machine',
#  302: 'Machines',
#  303: 'Main',
#  304: 'Many',
#  305: 'Markov',
#  306: 'Markov__Random',
#  307: 'Markov__chain',
#  308: 'Markov__chains',
#  309: 'Markovian',
#  310: 'Matching',
#  311: 'Material',
#  312: 'Materials',
#  313: 'Matlab',
#  314: 'Matrix',
#  315: 'Max',
#  316: 'Maximization',
#  317: 'Maximum',
#  318: 'Mean',
#  319: 'Method',
#  320: 'Methods',
#  321: 'Microsoft',
#  322: 'Mixture',
#  323: 'Model',
#  324: 'Modeling',
#  325: 'Models',
#  326: 'Monte__Carlo',
#  327: 'More',
#  328: 'Moreover',
#  329: 'Most',
#  330: 'Multivariate',
#  331: 'NIH',
#  332: 'NIPS',
#  333: 'NIPS__Barcelona',
#  334: 'NIPS__Long',
#  335: 'NP-hard',
#  336: 'NSF',
#  337: 'National',
#  338: 'Natural',
#  339: 'Naval',
#  340: 'Negative',
#  341: 'Nesterov',
#  342: 'Net',
#  343: 'Network',
#  344: 'Networks',
#  345: 'Neural',
#  346: 'Neural__Information',
#  347: 'New',
#  348: 'Newton',
#  349: 'Newtons__method',
#  350: 'Next',
#  351: 'Noise',
#  352: 'Noisy',
#  353: 'Normalized',
#  354: 'Not',
#  355: 'Notation',
#  356: 'Note',
#  357: 'Notice',
#  358: 'Now',
#  359: 'Number',
#  360: 'Numerical',
#  361: 'ONR',
#  362: 'Objective',
#  363: 'Observe',
#  364: 'Office',
#  365: 'One',
#  366: 'Online',
#  367: 'Optimal',
#  368: 'Optimization',
#  369: 'Original',
#  370: 'Other',
#  371: 'Our',
#  372: 'Our__appr',
#  373: 'Output',
#  374: 'Overview',
#  375: 'Oﬄine',
#  376: 'PAC',
#  377: 'PCA',
#  378: 'PSD',
#  379: 'Parameter',
#  380: 'Parameters',
#  381: 'Percentage',
#  382: 'Performance',
#  383: 'Poisson',
#  384: 'Policy',
#  385: 'Posterior',
#  386: 'Power',
#  387: 'Precision',
#  388: 'Prediction',
#  389: 'Preliminaries',
#  390: 'Previous',
#  391: 'Prior',
#  392: 'Probabilistic',
#  393: 'Probability',
#  394: 'Problem',
#  395: 'Process',
#  396: 'Processes',
#  397: 'Processing',
#  398: 'Processing__Systems',
#  399: 'Program',
#  400: 'Programming',
#  401: 'Project',
#  402: 'Proof',
#  403: 'Proofs',
#  404: 'Proposed',
#  405: 'Proposition',
#  406: 'Python',
#  407: 'RAM',
#  408: 'RBF',
#  409: 'RBF__kernel',
#  410: 'RBF__kernels',
#  411: 'RGB',
#  412: 'RKHS',
#  413: 'RMSE',
#  414: 'ROC',
#  415: 'RPT__REE',
#  416: 'RVU__property',
#  417: 'Rademacher',
#  418: 'Rademacher__complexity',
#  419: 'Rand__index',
#  420: 'Random',
#  421: 'Rate',
#  422: 'ReLU',
#  423: 'Real',
#  424: 'Recall',
#  425: 'Recently',
#  426: 'Recht',
#  427: 'Recognition',
#  428: 'Reduction',
#  429: 'Regression',
#  430: 'Regret',
#  431: 'Regularized',
#  432: 'Reinforcement',
#  433: 'Related',
#  434: 'Related__Work',
#  435: 'Relationship',
#  436: 'Relative',
#  437: 'Remark',
#  438: 'Representation',
#  439: 'Research',
#  440: 'Restricted',
#  441: 'Result',
#  442: 'Results',
#  443: 'Return',
#  444: 'Reward',
#  445: 'Riemannian',
#  446: 'Right',
#  447: 'Rmn',
#  448: 'Rnn',
#  449: 'Rotation',
#  450: 'Running',
#  451: 'SGD',
#  452: 'SIFT',
#  453: 'SSUMPTION__FREE',
#  454: 'SVD',
#  455: 'SVM',
#  456: 'SVMs',
#  457: 'Sample',
#  458: 'Sampling',
#  459: 'Science',
#  460: 'Sec',
#  461: 'Second',
#  462: 'Section',
#  463: 'Sections',
#  464: 'See',
#  465: 'Segmentation',
#  466: 'Select',
#  467: 'Selection',
#  468: 'Set',
#  469: 'Setting',
#  470: 'Setup',
#  471: 'Shuﬄed',
#  472: 'Similar',
#  473: 'Similarly',
#  474: 'Simulation',
#  475: 'Since',
#  476: 'Single',
#  477: 'Size',
#  478: 'Sketch',
#  479: 'Social',
#  480: 'Solution',
#  481: 'Some',
#  482: 'Space',
#  483: 'Spain',
#  484: 'Sparse',
#  485: 'Sparsity',
#  486: 'Standard',
#  487: 'Start',
#  488: 'Statistical',
#  489: 'Step',
#  490: 'Stochastic',
#  491: 'Structure',
#  492: 'Structured',
#  493: 'Study',
#  494: 'Such',
#  495: 'Summary',
#  496: 'Supervised',
#  497: 'Supplementary',
#  498: 'Supplementary__Material',
#  499: 'Support',
#  500: 'Suppose',
#  501: 'Synthetic',
#  502: 'System',
#  503: 'Systems',
#  504: 'Table',
#  505: 'Taking',
#  506: 'Target',
#  507: 'Taylor',
#  508: 'Technology',
#  509: 'Temporal',
#  510: 'Test',
#  511: 'That',
#  512: 'Then',
#  513: 'Theorem',
#  514: 'Theorems',
#  515: 'Theoretical',
#  516: 'Theory',
#  517: 'There',
#  518: 'Therefore',
#  519: 'These',
#  520: 'This',
#  521: 'Threshold',
#  522: 'Throughout',
#  523: 'Thus',
#  524: 'Time',
#  525: 'Titan',
#  526: 'Top',
#  527: 'Total',
#  528: 'Train',
#  529: 'Training',
#  530: 'True',
#  531: 'Two',
#  532: 'UCI',
#  533: 'USA',
#  534: 'USPS',
#  535: 'Under',
#  536: 'Unfortunately',
#  537: 'Uniform',
#  538: 'University',
#  539: 'Unsupervised',
#  540: 'Update',
#  541: 'Upper',
#  542: 'Using',
#  543: 'Validation',
#  544: 'Value',
#  545: 'Var',
#  546: 'Variable',
#  547: 'Variation',
#  548: 'Variational',
#  549: 'Vector',
#  550: 'Visual',
#  551: 'Wang',
#  552: 'Weights',
#  553: 'Welling',
#  554: 'When',
#  555: 'While',
#  556: 'Williams',
#  557: 'With',
#  558: 'Work',
#  559: 'Works',
#  560: 'Xeon',
#  561: 'Xij',
#  562: 'Xt1',
#  563: 'Zhang',
#  564: 'abil',
#  565: 'abl',
#  566: 'abov',
#  567: 'absenc',
#  568: 'absolut',
#  569: 'abstract',
#  570: 'abus',
#  571: 'acceler',
#  572: 'accept',
#  573: 'access',
#  574: 'accommod',
#  575: 'accomplish',
#  576: 'accord',
#  577: 'accordingli',
#  578: 'account',
#  579: 'accu',
#  580: 'accumul',
#  581: 'accur',
#  582: 'accuraci',
#  583: 'achiev',
#  584: 'acknowledg',
#  585: 'acknowledgments__This',
#  586: 'acknowledgments__thi',
#  587: 'acquir',
#  588: 'act',
#  589: 'action',
#  590: 'activ',
#  591: 'actor',
#  592: 'actual',
#  593: 'ad-hoc',
#  594: 'ada__newton',
#  595: 'adam',
#  596: 'adapt',
#  597: 'add',
#  598: 'addi',
#  599: 'addit',
#  600: 'additive__nois',
#  601: 'address',
#  602: 'adequ',
#  603: 'adjac',
#  604: 'adjacency__matrix',
#  605: 'adjust',
#  606: 'admiss',
#  607: 'admit',
#  608: 'admm',
#  609: 'adopt',
#  610: 'advanc',
#  611: 'advantag',
#  612: 'adversari',
#  613: 'advertis',
#  614: 'affect',
#  615: 'affin',
#  616: 'affinity__graph',
#  617: 'aforement',
#  618: 'age',
#  619: 'agenc',
#  620: 'agent',
#  621: 'aggreg',
#  622: 'aggregative__gam',
#  623: 'aggress',
#  624: 'agre',
#  625: 'agreement',
#  626: 'ahead',
#  627: 'aim',
#  628: 'air',
#  629: 'akin',
#  630: 'albeit',
#  631: 'alg',
#  632: 'algebra',
#  633: 'algo',
#  634: 'algo__rithm',
#  635: 'algorithm',
#  636: 'align',
#  637: 'allevi',
#  638: 'alli',
#  639: 'alloc',
#  640: 'alon',
#  641: 'alphabet',
#  642: 'alreadi',
#  643: 'alter',
#  644: 'altern',
#  645: 'altogeth',
#  646: 'alway',
#  647: 'amazon',
#  648: 'ambigu',
#  649: 'amount',
#  650: 'anal',
#  651: 'analog',
#  652: 'analogu',
#  653: 'analys',
#  654: 'analysi',
#  655: 'analyt',
#  656: 'analyz',
#  657: 'anc',
#  658: 'anchor',
#  659: 'angl',
#  660: 'angular',
#  661: 'ani',
#  662: 'anim',
#  663: 'annot',
#  664: 'anonym',
#  665: 'anoth',
#  666: 'anr',
#  667: 'answer',
#  668: 'anymor',
#  669: 'appar',
#  670: 'appeal',
#  671: 'appendix',
#  672: 'appli',
#  673: 'applic',
#  674: 'applica',
#  675: 'appr__trsf',
#  676: 'approach',
#  677: 'appropri',
#  678: 'approx',
#  679: 'approxi',
#  680: 'approxim',
#  681: 'approxima',
#  682: 'approximate__Newton',
#  683: 'approximate__newton',
#  684: 'arbitrari',
#  685: 'arbitrarili',
#  686: 'architectur',
#  687: 'area',
#  688: 'arg',
#  689: 'arg__max',
#  690: 'arg__min',
#  691: 'argmax',
#  692: 'argmin',
#  693: 'argu',
#  694: 'arguabl',
#  695: 'argument',
#  696: 'aris',
#  697: 'arm',
#  698: 'arora',
#  699: 'array',
#  700: 'arriv',
#  701: 'arrow',
#  702: 'art',
#  703: 'articl',
#  704: 'artifici',
#  705: 'ascent',
#  706: 'asid',
#  707: 'aspect',
#  708: 'assess',
#  709: 'assign',
#  710: 'associ',
#  711: 'assum',
#  712: 'assump',
#  713: 'assumpt',
#  714: 'asymmetr',
#  715: 'asymptot',
#  716: 'ate',
#  717: 'ation',
#  718: 'ativ',
#  719: 'attach',
#  720: 'attain',
#  721: 'attempt',
#  722: 'attent',
#  723: 'attention__map',
#  724: 'attract',
#  725: 'attribut',
#  726: 'atur',
#  727: 'auc',
#  728: 'audio',
#  729: 'augment',
#  730: 'author',
#  731: 'auto',
#  732: 'autoencod',
#  733: 'automat',
#  734: 'autoregress',
#  735: 'auxiliari',
#  736: 'avail',
#  737: 'averag',
#  738: 'avg',
#  739: 'avoid',
#  740: 'awar',
#  741: 'award',
#  742: 'axe',
#  743: 'axi',
#  744: 'bach',
#  745: 'back',
#  746: 'back-propag',
#  747: 'background',
#  748: 'backpropag',
#  749: 'backward',
#  750: 'bad',
#  751: 'bag',
#  752: 'bag-of',
#  753: 'balanc',
#  754: 'ball',
#  755: 'band',
#  756: 'bandit',
#  757: 'bandwidth',
#  758: 'bar',
#  759: 'barrier',
#  760: 'base',
#  761: 'baselin',
#  762: 'basi',
#  763: 'basic',
#  764: 'batch',
#  765: 'bay',
#  766: 'bayes__classifi',
#  767: 'bayesian',
#  768: 'baﬄe',
#  769: 'beach',
#  770: 'becaus',
#  771: 'becom',
#  772: 'bed',
#  773: 'befor',
#  774: 'begin',
#  775: 'behav',
#  776: 'behavior',
#  777: 'behaviour',
#  778: 'belief',
#  779: 'believ',
#  780: 'bellman',
#  781: 'bellman__error',
#  782: 'belong',
#  783: 'benchmark',
#  784: 'benefici',
#  785: 'benefit',
#  786: 'bengio',
#  787: 'ber',
#  788: 'bernoulli',
#  789: 'besid',
#  790: 'bet',
#  791: 'beta',
#  792: 'bfg',
#  793: 'bia',
#  794: 'bias',
#  795: 'big',
#  796: 'bigger',
#  797: 'biliti',
#  798: 'bin',
#  799: 'binar',
#  800: 'binari',
#  801: 'bind',
#  802: 'binomi',
#  803: 'biolog',
#  804: 'bipartit',
#  805: 'bipartite__rank',
#  806: 'bit',
#  807: 'black',
#  808: 'black-box',
#  809: 'ble',
#  810: 'block',
#  811: 'blood',
#  812: 'blue',
#  813: 'bodi',
#  814: 'bold',
#  815: 'boltzmann',
#  816: 'boost',
#  817: 'bottleneck',
#  818: 'bottom',
#  819: 'bound',
#  820: 'boundari',
#  821: 'bounding__box',
#  822: 'box',
#  823: 'bracket',
#  824: 'brain',
#  825: 'brain__connect',
#  826: 'brain__region',
#  827: 'branch',
#  828: 'break',
#  829: 'breviti',
#  830: 'briefli',
#  831: 'bring',
#  832: 'broad',
#  833: 'broader',
#  834: 'broadli',
#  835: 'broken',
#  836: 'brought',
#  837: 'brownian__mot',
#  838: 'budget',
#  839: 'build',
#  840: 'built',
#  841: 'burden',
#  842: 'bution',
#  843: 'buy',
#  844: 'cal',
#  845: 'calcul',
#  846: 'call',
#  847: 'calli',
#  848: 'camera',
#  849: 'cancel',
#  850: 'candid',
#  851: 'canon',
#  852: 'cap',
#  853: 'capabl',
#  854: 'capac',
#  855: 'capit',
#  856: 'captur',
#  857: 'car',
#  858: 'cardin',
#  859: 'care',
#  860: 'career',
#  861: 'carri',
#  862: 'cartesian',
#  863: 'case',
#  864: 'cast',
#  865: 'cat',
#  866: 'categor',
#  867: 'categori',
#  868: 'cation',
#  869: 'caus',
#  870: 'causal',
#  871: 'causal__graph',
#  872: 'cdf',
#  873: 'celebr',
#  874: 'cell',
#  875: 'cent',
#  876: 'center',
#  877: 'central',
#  878: 'certainli',
#  879: 'cess',
#  880: 'chain',
#  881: 'challeng',
#  882: 'chanc',
#  883: 'chang',
#  884: 'channel',
#  885: 'chapter',
#  886: 'char',
#  887: 'charact',
#  888: 'character',
#  889: 'characterist',
#  890: 'cheap',
#  891: 'cheaper',
#  892: 'check',
#  893: 'chen',
#  894: 'chine',
#  895: 'choic',
#  896: 'choice__prob',
#  897: 'choos',
#  898: 'chose',
#  899: 'chosen',
#  900: 'cial',
#  901: 'cifar',
#  902: 'cifar-10',
#  903: 'circl',
#  904: 'circuit',
#  905: 'circumv',
#  906: 'cite',
#  907: 'cla',
#  908: 'claim',
#  909: 'clarifi',
#  910: 'clariti',
#  911: 'class',
#  912: 'classi',
#  913: 'classic',
#  914: 'classif',
#  915: 'classifi',
#  916: 'classifica',
#  917: 'clean',
#  918: 'clear',
#  919: 'clearli',
#  920: 'clinic',
#  921: 'cliqu',
#  922: 'close',
#  923: 'closed-form',
#  924: 'closed__form',
#  925: 'closely__rel',
#  926: 'closer',
#  927: 'closest',
#  928: 'cluster',
#  929: 'clutter',
#  930: 'cnn',
#  931: 'co-occurr',
#  932: 'coars',
#  933: 'coarser',
#  934: 'code',
#  935: 'coeffici',
#  936: 'cognit',
#  937: 'coher',
#  938: 'coincid',
#  939: 'col',
#  940: 'cold__start',
#  941: 'collabor',
#  942: 'collaps',
#  943: 'collect',
#  944: 'color',
#  945: 'column',
#  946: 'combin',
#  947: 'combina',
#  948: 'combinatori',
#  949: 'comment',
#  950: 'common',
#  951: 'commonli',
#  952: 'commun',
#  953: 'compact',
#  954: 'compactli',
#  955: 'compani',
#  956: 'compar',
#  957: 'comparison',
#  958: 'compat',
#  959: 'compens',
#  960: 'compet',
#  961: 'competit',
#  962: 'competitor',
#  963: 'complement',
#  964: 'complementari',
#  965: 'complet',
#  966: 'complex',
#  967: 'complex__cel',
#  968: 'complic',
#  969: 'compo',
#  970: 'compon',
#  971: 'compos',
#  972: 'composit',
#  973: 'comprehens',
#  974: 'compress',
#  975: 'compris',
#  976: 'compu',
#  977: 'comput',
#  978: 'computa',
#  979: 'computational__complex',
#  980: 'computationally__effici',
#  981: 'computer__vis',
#  982: 'con',
#  983: 'concaten',
#  984: 'concav',
#  985: 'concentr',
#  986: 'concept',
#  987: 'conceptu',
#  988: 'concern',
#  989: 'conclud',
#  990: 'conclus',
#  991: 'concret',
#  992: 'condi',
#  993: 'condit',
#  994: 'conduct',
#  995: 'cone',
#  996: 'confer',
#  997: 'confid',
#  998: 'configur',
#  999: 'confirm',
#  ...}

# %% [markdown]
# Moreover, The vocabulary_index file can be opened and edited to store `vocabulary:index`

# %%
## vocabulary and inex
with open('Group023_vocab.txt','w+',encoding='UTF-8') as vocafile:
    for i in vocab_index.keys():
        vocafile.write(vocab_index[i] + ':' + str(i) + '\n')

# %% [markdown]
# Now we need to get the word count for each token, and each token should match one unique index. `Counter function` is easy to use to get the word count. Finally wirte them into file.

# %%
def vocab_to_index(pid):
    token = tokenizebody(pid)[1]##get the token
    ## replace word to index
    for index in range(len(token)):
        for i in vocab_index.keys():
            if token[index] == vocab_index[i]:
                token[index] = i
    ##filter the tokens who is satisfactory
    token = [str(x) for x in token]
    token = [num for num in token if num.isdigit() == True]##because just matched token has transformed to number
    token = [int(x) for x in token]
    ##word count
    word_fre = Counter(token)
    
    return word_fre
vocab_to_index('PP7260')
# Out:
# Counter({2779: 15,
#          2791: 1,
#          2085: 2,
#          2441: 1,
#          3070: 1,
#          2736: 1,
#          2086: 22,
#          824: 26,
#          2479: 1,
#          870: 4,
#          1379: 3,
#          2346: 2,
#          1257: 4,
#          1609: 4,
#          2143: 16,
#          1158: 5,
#          2508: 9,
#          2253: 1,
#          1919: 1,
#          676: 6,
#          1081: 1,
#          1016: 1,
#          2458: 2,
#          1097: 27,
#          2810: 5,
#          1378: 1,
#          1971: 2,
#          2329: 14,
#          2278: 8,
#          95: 1,
#          345: 1,
#          240: 1,
#          397: 1,
#          503: 1,
#          332: 1,
#          286: 1,
#          49: 1,
#          533: 1,
#          1086: 1,
#          2045: 2,
#          2084: 9,
#          1849: 4,
#          238: 1,
#          86: 1,
#          22: 3,
#          233: 1,
#          1182: 1,
#          3015: 2,
#          1870: 2,
#          1432: 4,
#          1150: 1,
#          2503: 1,
#          2769: 2,
#          2700: 13,
#          1721: 3,
#          1955: 1,
#          3069: 1,
#          1401: 2,
#          2280: 1,
#          763: 1,
#          2268: 1,
#          2359: 1,
#          1196: 1,
#          2799: 1,
#          795: 1,
#          1953: 1,
#          2739: 3,
#          2545: 6,
#          950: 2,
#          601: 3,
#          776: 1,
#          1370: 2,
#          969: 1,
#          377: 4,
#          2664: 23,
#          2597: 2,
#          1509: 9,
#          1304: 1,
#          1540: 1,
#          1473: 3,
#          2763: 1,
#          2621: 4,
#          987: 1,
#          1489: 4,
#          1916: 2,
#          2019: 38,
#          1406: 30,
#          1055: 1,
#          2546: 1,
#          2984: 6,
#          1020: 7,
#          2230: 1,
#          2688: 3,
#          1920: 2,
#          2740: 1,
#          323: 1,
#          226: 2,
#          1399: 1,
#          2535: 1,
#          2978: 11,
#          1220: 2,
#          3184: 15,
#          173: 1,
#          1843: 3,
#          2456: 2,
#          1102: 15,
#          899: 5,
#          832: 1,
#          2681: 1,
#          1911: 1,
#          174: 6,
#          155: 1,
#          550: 2,
#          884: 3,
#          2693: 5,
#          380: 2,
#          1155: 1,
#          918: 1,
#          712: 1,
#          2154: 3,
#          1883: 2,
#          202: 12,
#          2374: 5,
#          1885: 1,
#          322: 3,
#          1791: 16,
#          1793: 1,
#          2821: 1,
#          2361: 1,
#          462: 15,
#          1780: 2,
#          3187: 6,
#          747: 3,
#          2467: 2,
#          966: 4,
#          256: 1,
#          378: 1,
#          2224: 2,
#          2191: 5,
#          2044: 1,
#          1745: 3,
#          1790: 1,
#          2151: 1,
#          1542: 1,
#          423: 1,
#          1941: 18,
#          2883: 3,
#          755: 5,
#          1147: 1,
#          1371: 2,
#          1237: 1,
#          3032: 1,
#          2451: 4,
#          356: 2,
#          1046: 1,
#          2234: 2,
#          2761: 2,
#          2521: 1,
#          1504: 3,
#          2206: 1,
#          2377: 1,
#          2161: 4,
#          371: 1,
#          2304: 2,
#          2139: 1,
#          1860: 1,
#          1249: 2,
#          1826: 7,
#          2924: 3,
#          2210: 1,
#          1482: 1,
#          1018: 3,
#          3183: 2,
#          123: 1,
#          1133: 1,
#          1949: 2,
#          1945: 3,
#          1174: 1,
#          239: 1,
#          1854: 1,
#          3206: 1,
#          1834: 2,
#          3123: 2,
#          695: 1,
#          2999: 2,
#          1877: 3,
#          2557: 1,
#          764: 1,
#          1549: 1,
#          1154: 1,
#          635: 1,
#          7: 2,
#          1415: 1,
#          187: 1,
#          1479: 1,
#          203: 2,
#          3174: 1,
#          1643: 1,
#          2945: 8,
#          2708: 1,
#          1917: 1,
#          2989: 1,
#          1716: 1,
#          1938: 1,
#          2340: 1,
#          2942: 5,
#          1332: 1,
#          1876: 1,
#          707: 1,
#          1890: 5,
#          1629: 1,
#          2832: 2,
#          1508: 2,
#          1077: 3,
#          1442: 1,
#          1909: 1,
#          1944: 1,
#          1820: 1,
#          1291: 1,
#          1910: 1,
#          171: 4,
#          510: 4,
#          2630: 5,
#          814: 2,
#          1534: 3,
#          1598: 3,
#          3055: 3,
#          812: 1,
#          2497: 1,
#          3002: 1,
#          2806: 1,
#          2216: 1,
#          442: 1,
#          501: 1,
#          112: 2,
#          3037: 5,
#          504: 3,
#          255: 2,
#          1934: 1,
#          1011: 2,
#          1979: 2,
#          982: 1,
#          2808: 1,
#          1859: 1,
#          1987: 2,
#          2171: 2,
#          2917: 2,
#          2351: 1,
#          1847: 1,
#          103: 1,
#          1330: 1,
#          1466: 1,
#          2867: 1,
#          1981: 1,
#          2316: 1,
#          916: 1,
#          2: 1,
#          3: 1,
#          79: 1,
#          2270: 1,
#          2052: 1,
#          1828: 1,
#          957: 1,
#          436: 1,
#          2238: 1,
#          3105: 1,
#          2689: 1,
#          3003: 1,
#          1582: 2,
#          1502: 1,
#          1743: 1,
#          863: 1,
#          2083: 1,
#          1222: 1,
#          842: 1,
#          3019: 1,
#          2301: 2,
#          2964: 2,
#          125: 1,
#          92: 1,
#          1199: 2,
#          1187: 1,
#          736: 1,
#          2731: 1,
#          2158: 1,
#          1730: 1,
#          1751: 1,
#          2475: 1,
#          1381: 1,
#          2518: 1,
#          1029: 1,
#          2133: 1,
#          2879: 1,
#          1464: 1,
#          3193: 1,
#          687: 1,
#          1970: 1,
#          1073: 1,
#          1523: 1,
#          2383: 1,
#          107: 1,
#          2380: 1,
#          2985: 1,
#          1554: 1,
#          186: 1})

# %%
## Write count_vectors file
with open('Group023_count_vectors.txt','w+',encoding='UTF-8') as outputfile:
    for paper_id in all_pid:
        count_vectors = str(paper_id) + ',' + str(vocab_to_index(paper_id))[9:-2] +'\n'##[9:-2]to get vector and its frequency
        count_vectors = count_vectors.replace(' ','')
        outputfile.write(count_vectors)

# %% [markdown]
# ## 5. Statistics Generation

# %% [markdown]
# ## 5.1 Match Data

# %% [markdown]
# After opening the original file, we altered all special markers to space bars. Specially, in the original file, finding that some special characters cannot match ‘regular expression' package, so we changed these special characters to normal characters. Then, we could locate the needed files from the beginning of `abstract` to the end of `Paper Body` in the file and utilize regular expression to group .

# %%
def get_abs(url):
    txt_name = get_txt_name(url)
    with open(txt_name,'r',encoding='UTF-8') as content:
        text = content.read()
    
    text = text.replace('\n',' ')
    text = text.replace('?','')
    text = text.replace('¿','')
    text = text.replace('ﬃ','ffi')
    text = text.replace('ﬂ','fl')
    text = text.replace('ﬀ','ff')
    text = text.replace('ﬁ','fi')
    
    abs_pattern = 'Abstract(.*)1\sPaper\sBody'
    abstract = re.search(abs_pattern,text)
    abstract = abstract.group(1)
    return abstract

get_abs(inputfile[0])
# Out:
# '  We present the first truly polynomial algorithm for learning the struc- ture of bounded-treewidth junction trees – an attractive subclass of prob- abilistic graphical models that permits both the compact representation of probability distributions and efficient exact inference. For a constant treewidth, our algorithm has polynomial time and sample complexity, and provides strong theoretical guarantees in terms of $KL$ divergence from the true distribution. We also present a lazy extension of our approach that leads to very significant speed ups in practice, and demonstrate the viability of our method empirically, on several real world datasets. One of our key new theoretical insights is a method for bounding the con- ditional mutual information of arbitrarily large sets of random variables with only a polynomial number of mutual information computations on fixed-size subsets of variables, when the underlying distribution can be approximated by a bounded treewidth junction tree.  '

# %% [markdown]
# Locate the needed files from the beginning to the end of `Authored by` in the file and utilize regular expression to group .

# %%
def get_title(url):
    txt_name = get_txt_name(url)
    with open(txt_name,'r',encoding='UTF-8') as content:
        text = content.read()
    
    text = text.replace('\n',' ')
    text = text.replace('?','')
    text = text.replace('¿','')
    text = text.replace('ﬃ','ffi')
    text = text.replace('ﬂ','fl')
    text = text.replace('ﬀ','ff')
    text = text.replace('ﬁ','fi')

    title_pattern = '(.*)\sAuthored by'
    title = re.search(title_pattern,text)
    title = title.group(1)
    return title
get_title(inputfile[0])
# Out:
# 'Efficient Principled Learning of Thin Junction  Trees '

# %% [markdown]
# Locate the needed files from the beginning of `Authored by` to the end of `Abstract` in the file and utilize regular expression to group .

# %%
def get_author(url):
    txt_name = get_txt_name(url)
    with open(txt_name,'r',encoding='UTF-8') as content:
        text = content.read()
    
    text = text.replace('\n',',')
    text = text.replace('?','')
    text = text.replace('¿','')
    text = text.replace('ﬃ','ffi')
    text = text.replace('ﬂ','fl')
    text = text.replace('ﬀ','ff')
    text = text.replace('ﬁ','fi')
    
    author_pattern = 'Authored by:,(.*),Abstract'
    author = re.search(author_pattern,text)
    
    author = author.group(1)
    author = author.strip(',')
    
    author = author.split(',')
    while '' in author:
        author.remove('')
    return author
get_author(inputfile[5])
# Out:
# ['Manfred Opper',
#  'Dan Cornford',
#  'John S. Shawe-taylor',
#  'Cdric Archambeau',
#  'Yuan Shen']

# %% [markdown]
# ## 5.2 Filter Data

# %% [markdown]
# Then, I counted abstracts from extracts. Due to the statistics needs, I had to transcribe the content of article into lower case. Firstly, I put the matched files into the training model, the file could be recognized whether these are a sentence or not through the training model. And then, these matched files would be transcribed to lower case, and I used `regular expression` to match the article which had been trained. Because of the question asking us to delete the sentence less 3 words, I adopted `stop_word` to match `regular expression` from the deleted sentences less than three words.

# %%
def abs_stats(url):
    abstract = get_abs(url)
    
    ##lower casing the first charater of a sentence(abstract)
    tokenizer = PunktSentenceTokenizer(trainer.get_params())
    sentences = tokenizer.tokenize(abstract)
    sentences_lower = [s[0].lower()+s[1:] for s in sentences]
    abstract = "".join(sentences_lower)
    
    ##unigram
    tokenizer = RegexpTokenizer(r"[A-Za-z]\w+(?:[-'?]\w+)?")
    abs_tokens = tokenizer.tokenize(abstract)
    
    ##remove tokens with the length less than 3
    stopped_abs_tokens = [w for w in abs_tokens if w not in stopwords_set]
    
    return stopped_abs_tokens

abs_stats(inputfile[0])[0:10]
# Out:
# ['We',
#  'present',
#  'polynomial',
#  'algorithm',
#  'learning',
#  'struc',
#  'ture',
#  'bounded-treewidth',
#  'junction',
#  'trees']

# %% [markdown]
# Put the title's data which used `regular expression` into the training model., Then。we adopted `stop_word` to match `regular expression` from the deleted sentences less than three words.

# %%
def title_stats(url):
    
    title = get_title(url)
    ##lower case title
    title = title.lower()
    
    ##unigram
    tokenizer = RegexpTokenizer(r"[A-Za-z]\w+(?:[-'?]\w+)?")
    title_token = tokenizer.tokenize(title)
    
    ##remove tokens with the length less than 3
    stopped_title_tokens = [w for w in title_token if w not in stopwords_set]
    return stopped_title_tokens

title_stats(inputfile[0])
# Out:
# ['efficient', 'principled', 'learning', 'thin', 'junction', 'trees']

# %% [markdown]
# ## 5.3 Statistic Data

# %% [markdown]
# Finally, we ranked the data which had been analyzed. According to the ask from the question, we would rank the top ten of `Abstract`, `Title` and `Author`. First of all, we built a list, put the analyzed data into the loop and used `Collections package` to count the frequency of characters showing up in the data. Then, after ranking it, we recorded the Abstract of top ten into the list.

# %%
## top 10 terms in abstract
abstract = []
for i in range(len(inputfile)):
    abstract.extend(abs_stats(inputfile[i]))
abstract_count = collections.Counter(abstract)
abstract_count = sorted(abstract_count.items(), key=lambda d: d[1], reverse=True)

top_abstract = []
for i in abstract_count[0:10]:
    top_abstract.append(i[0])
top_abstract
# Out:
# ['learning',
#  'data',
#  'model',
#  'algorithm',
#  'show',
#  'method',
#  'problem',
#  'models',
#  'algorithms',
#  'based']

# %% [markdown]
# Used `Collections package` to count the frequency of characters showing up in the data. Then, after ranking it, we recorded the Titles of top ten into the list.

# %%
## top 10 terms in title
title = []
for i in range(len(inputfile)):
    title.extend(title_stats(inputfile[i]))
title_count = collections.Counter(title)
title_count = sorted(title_count.items(), key=lambda d: d[1], reverse=True)
title_count[0:11]

top_title = []
for i in title_count[0:10]:
    top_title.append(i[0])
top_title
# Out:
# ['learning',
#  'models',
#  'inference',
#  'regression',
#  'networks',
#  'deep',
#  'stochastic',
#  'neural',
#  'variational',
#  'analysis']

# %% [markdown]
# Used `Collections package` to count the frequency of characters showing up in the data. Then, after ranking it, we recorded the Authors of top ten into the list.

# %%
## top 10 authors
author = []
for i in range(len(inputfile)):
    author.extend(get_author(inputfile[i]))
author_count = collections.Counter(author)
author_count = sorted(author_count.items(), key=lambda d: d[1], reverse=True)

top_author = []
for i in author_count[0:10]:
    top_author.append(i[0])
top_author
# Out:
# ['Jan R. Peters',
#  'Rong Jin',
#  'Tianbao Yang',
#  'Franois Fleuret',
#  'Elad Hazan',
#  'Manfred Opper',
#  'Eric P. Xing',
#  'Gerhard Neumann',
#  'Shie Mannor',
#  'Huan Xu']

# %%
## create stats dataframe and output to csv file
stats = pd.DataFrame([top_abstract,top_title,top_author])
stats = stats.T
stats.columns = ['top10_terms_in_abstracts', 'top10_terms_in_titles', 'top10_authors']
stats.to_csv("Group023_stats.csv",index = False)
stats
# Out:
#   top10_terms_in_abstracts top10_terms_in_titles    top10_authors
# 0                 learning              learning    Jan R. Peters
# 1                     data                models         Rong Jin
# 2                    model             inference     Tianbao Yang
# 3                algorithm            regression  Franois Fleuret
# 4                     show              networks       Elad Hazan
# 5                   method                  deep    Manfred Opper
# 6                  problem            stochastic     Eric P. Xing
# 7                   models                neural  Gerhard Neumann
# 8               algorithms           variational      Shie Mannor
# 9                    based              analysis          Huan Xu

# %% [markdown]
# ## 6. Summary

# %% [markdown]
# This assessment measured the understanding of basic text file processing techniques in the Python programming language and extracted data into a proper format suitable for a downstream modelling task.
# - **Extraction** Defining function is a clear and user friendly way to parse these patent features. [regex101](https://regex101.com/) is a very useful online tool to check the regular expression. And also it can show which part is the group of regular expression. The `re.search` and `re.sub` is used frequently in this part to extract the particular text from main file. Then by using basic funtion like `if else` and `loop` to make judgment and appending function.
#
#
# - **Sparse Feature Generation** Firstly, using `tokenization` function to identify the file sentence segmentation. Then, define a `RegexTokenizer` to tokenize all words from paper. Secondly, due to removed vocabularys, put the data into the stop words. Check the difference between th output of `MWEtokenizer` and `RegexpTokenizer` by adpating the following code to make sure we get the right collocation. Rare tokens (with the threshold set to 3%) and meaningless tokens (with the threshold set to 95%) must be removed from the vocab. Thirdly, Using `Porter stemmer` to stem Unigram tokens. Finaly, output vocabulary_index file and count_vector file respectively.
#
#
# - **Statistics Generation** First of all, altering all special markers to space bars. Specially, in the original file, finding that some special characters cannot match `regular expression` package, so we changed these special characters to normal characters. According assignment requirement, the word tokenization must use the following regular expression, `r"[A-Za-z]\w+(?:[-'?]\w+)?"`. Then, put the matched files into the training model, the file could be recognized whether these are a sentence or not through the training model. Finally,  put the analyzed data into the loop and used `Collections package` to count the frequency of characters showing up in the data.

# %% [markdown]
# # 7. References

# %% [markdown]
# - The `pandas` Project. (2016a). *pandas 0.19.2 documentation: pandas.DataFrame.to_csv*. Retrieved from http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_csv.html#pandas.DataFrame.to_csv
# - tokenize — Tokenizer for Python source*. Retrieved from https://docs.python.org/3/library/tokenize.html#module-tokenize
# - Python | Stemming words with NLTK*. Retrieved from https://www.geeksforgeeks.org/python-stemming-words-with-nltk/
